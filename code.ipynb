# %% [markdown]
# ## Import needed tools

# %%
import bson
from neo4j import GraphDatabase
from datetime import datetime, timedelta
from pprint import pprint
from pymongo import MongoClient

# %% [markdown]
# ## Define constants

# %%
#Define labels for nodes:
l_user = "user"
l_tweet = "tweet"
l_hashtag = "hashtag"
l_url = "url"
#Define relationships:
r_tweeted = "tweeted"
r_retweeted = "retweeted"
r_has_url = "has_url"
r_has_hashtag = "has_hashtag"
r_used_url = "used_url"
r_used_hashtag = "used_hashtag"
r_mentioned = "mentioned"
#Define list of properties for nodes to gather from data to be read:
p_user = ["screen_name","followers_count"]
p_user_key = "screen_name"
p_tweet = ["id","text","favorite_count","retweet_count","reply_count"]
p_tweet_key = "id"

# %% [markdown]
# ## Some custom tools used in the code

# %%
class Node:
    '''
    This class is used to group node data together and define a node object
    '''
    def __init__(self,label,properties,propertiesKey):
        self.label = label
        self.properties = properties
        self.propertiesKey = propertiesKey

class Graph:
    '''
    This class is used to start a connection with neo4j and create nodes and relationships
    '''
    def __init__(self,uri,username,password):
        self.graph = GraphDatabase.driver(uri, auth=(username, password))
        self.session = self.graph.session()
    def execute(self,cypher):
        '''
        Execute cypher script
        '''
        return self.session.run(cypher)
    def find (self,label,propertiesKey, propertiesKeyValue) -> Node:
        '''
        Finds an existing node using the node key (we assume single property keys and expect at most one result)
        '''
        c_node = 'n' #Node variable used in queries
        match = self.session.run(f"match ({c_node}:{label}) where {c_node}.{propertiesKey} = '{propertiesKeyValue}' return {c_node}").data()
        if len(match) > 0:
            return Node(label,match[0][c_node],propertiesKey)
        else:
            return None
    def upsertNode(self, node:Node, allowUpdate = True):
        '''
        Update or insert a node. If not already existing it inserts a new node else it updates the existing one.
        We assume that we has a single property as a key (a key is a way to uniquely identify the node).
        The value of the properties key is always stored as string
        '''
        c_node = 'n' #Node variable used in queries
        #Check for existing node :
        match = self.session.run(f"match ({c_node}:{node.label}) where {c_node}.{node.propertiesKey} = '{node.properties[node.propertiesKey]}' return {c_node}").data()
        updateNode = False #<= This flag is set to true only when there is an existing node with different data that those given
        #Convert given properties to a string to be used along with the query :
        propertiesString = ""
        for key in node.properties:
            value = node.properties[key]
            if type(value) == str: value = value.replace("\\","\\\\").replace("'","\\'")
            if len(match) > 0:
                if key not in match[0][c_node]: updateNode = True
                elif value != match[0][c_node][key]: updateNode = True
                propertiesString += " " + c_node +"." + key + "=" + ((str(value))if type(value) != str and key != node.propertiesKey else "'" + str(value) + "'" ) + ","
            else:
                propertiesString += key + ":" + ((str(value))if type(value) != str and key != node.propertiesKey else "'" + str(value) + "'" ) + ","
        propertiesString = propertiesString[:-1]
        #Execute query :
        if len(match) <= 0:         #Create new node
            propertiesString = "{" + propertiesString + "}"
            self.session.run(f"create ({c_node}:{node.label} {propertiesString})")
        elif updateNode == True and allowUpdate == True:    #Update existing node if there is any changed value
            self.session.run(f"match ({c_node}:{node.label}) where {c_node}.{node.propertiesKey} = '{node.properties[node.propertiesKey]}' SET {propertiesString}");

    def upsertRelationship(self,node1:Node,relationship:str,node2:Node,properties, allowUpdate = True):
        '''
        Update or insert a relationship. If not already existing it creates a new relationship else it updates the existing one
        We assume that we has a single property as a key (a key is a way to uniquely identify the node).
        The value of the properties key is always stored as string
        '''
        c_relationship = 'r'
        matchQuery = f"MATCH (a:{node1.label})-[{c_relationship}:{relationship}]->(b:{node2.label}) WHERE a.{node1.propertiesKey} = '{node1.properties[node1.propertiesKey]}' AND b.{node2.propertiesKey} = '{node2.properties[node2.propertiesKey]}'"
        #Check for existing relationship :
        match = self.session.run(f"{matchQuery} return {c_relationship}").value()
        updateRelationship = False #<= This flag is set to true only when there is an existing node with different data that those given
        #Convert given properties to a string to be used along with the query :
        propertiesString = ""
        for key in properties:
            value = properties[key]
            if type(value) == str: value = value.replace("\\","\\\\").replace("'","\\'")
            if len(match) > 0:
                if key not in match[0]._properties: updateRelationship = True
                elif value != match[0]._properties[key]: updateRelationship = True
                propertiesString += " " + c_relationship +"." + key + "=" + ((str(value))if type(value) != str else "'" + value + "'" ) + ","
            else:
                propertiesString += key + ":" + ((str(value))if type(value) != str else "'" + value + "'" ) + ","
        propertiesString = propertiesString[:-1]
        if len(match) <= 0:         #Create new node
            propertiesString = "{" + propertiesString + "}"
            matchQuery = f"MATCH (a:{node1.label}), (b:{node2.label}) WHERE a.{node1.propertiesKey} = '{node1.properties[node1.propertiesKey]}' AND b.{node2.propertiesKey} = '{node2.properties[node2.propertiesKey]}'"
            query = f"{matchQuery} CREATE (a)-[{c_relationship}:{relationship} {propertiesString}]->(b)"
            self.session.run(query)
        elif updateRelationship == True and allowUpdate == True:    #Update existing node if there is any changed value
            matchQuery = f"MATCH (a:{node1.label}), (b:{node2.label}) WHERE a.{node1.propertiesKey} = '{node1.properties[node1.propertiesKey]}' AND b.{node2.propertiesKey} = '{node2.properties[node2.propertiesKey]}'"
            query = f"MATCH (a:{node1.label})-[{c_relationship}:{relationship}]->(b:{node2.label}) WHERE a.{node1.propertiesKey} = '{node1.properties[node1.propertiesKey]}' AND b.{node2.propertiesKey} = '{node2.properties[node2.propertiesKey]}'"
            self.session.run(f"{query} SET {propertiesString}")

# %% [markdown]
# ## Open connection with Neo4J DBMS

# %%
graph = Graph("bolt://localhost:7687","neo4j","1234")

# %% [markdown]
# ## Create Graph

# %% [markdown]
# #### Read Data From BSON File

# %%
bson_file = open('data\citizenScience.bson', 'rb')
data = bson.decode_all(bson_file.read())
bson_file.close()

# %% [markdown]
# #### Read data From MongoDB Database - Alternative

# %%
client = MongoClient(port=27017)
data=[item for item in client.data.citizenScience.find()]
client.close()
#This can be improved by quering from MongoDB only the needed data but further time would be required to learn the quering language of MongoDB
#The implemented solution is working independently from the data gathering method and we consider it to be sufficient for the amount of data we need to handle

# %% [markdown]
# #### Create Graph from loaded data

# %%
#A function to gather the device from the data:
def getDevice(tweetItem):
    if "source" in tweetItem:
        if ">" in tweetItem["source"] and "<" in tweetItem["source"]:
            tweetDevice = (tweetItem["source"].split(">")[1]).split("<")[0]
        else:
            tweetDevice = tweetItem["source"]
    return tweetDevice

#Sort data from oldest to latest:
data = sorted(data,key=lambda x: datetime.strptime(x["created_at"],"%a %b %d %H:%M:%S %z %Y"), reverse=False)

for item in data:
    # Create User node:
    user = Node(l_user,{p : (item["user"][p] if p in item["user"] else None) for p in p_user},p_user_key)
    graph.upsertNode(user)
    retweet = False
    originalTweetUser = None #<= In case of retweet, who created the tweet originally
    if "retweeted_status" in item:
        #This is a retweet
        tweetItem = item["retweeted_status"]
        originalTweetUser = Node(l_user,{p : (tweetItem["user"][p] if p in tweetItem["user"] else None) for p in p_user}, p_user_key)
        graph.upsertNode(originalTweetUser)
        retweet = True
        retweetDevice = getDevice(item)
        #Get retweet timestamp
        if "created_at" in item:
            date = datetime.strptime(item["created_at"],"%a %b %d %H:%M:%S %z %Y")
            retweetTimestamp = date.strftime("%Y%m%d%H%M%S")
    else:
        #This is a tweet
        tweetItem = item

    #Get the tweet device :
    tweetDevice = getDevice(tweetItem)
    if "created_at" in tweetItem:
        date = datetime.strptime(tweetItem["created_at"],"%a %b %d %H:%M:%S %z %Y")
        tweetTimestamp = date.strftime("%Y%m%d%H%M%S")

    # Create tweet node:
    tweet = Node(l_tweet,{p: (tweetItem[p] if p in tweetItem else None) for p in p_tweet},p_tweet_key)
    graph.upsertNode(tweet)

    #Create user tweet relationship :
    graph.upsertRelationship(user,r_retweeted if retweet else r_tweeted,tweet,{'timestamp':retweetTimestamp if retweet else tweetTimestamp, 'source': retweetDevice  if retweet else tweetDevice})
    if originalTweetUser != None:
        graph.upsertRelationship(originalTweetUser,r_tweeted,tweet,{'timestamp':tweetTimestamp, 'source':tweetDevice})

    #Get tweet entities:
    tweetEntities = []
    hasExtendedEntity = False #Determines if we do have an extended entity in our tweet
    #Get data from entities on root
    if "entities" in tweetItem:
        tweetEntities.append([tweetItem["entities"],"root"])
    #Get data from entities in extended tweet
    if "extended_tweet" in tweetItem:
        if "entities" in tweetItem["extended_tweet"]:
            tweetEntities.append([tweetItem["extended_tweet"]["entities"],"extended_tweet"])
            hasExtendedEntity = True
    for item in tweetEntities:
        entity = item[0]
        if "hashtags" in entity:
            for hashtag in entity["hashtags"]:
                if not "text" in hashtag: continue
                hashtagNode = Node(l_hashtag,{"text":hashtag['text'].lower()},"text")
                graph.upsertNode(hashtagNode)
                graph.upsertRelationship(user,r_used_hashtag,hashtagNode,{'timestamp':tweetTimestamp})
                graph.upsertRelationship(tweet,r_has_hashtag,hashtagNode,{'timestamp':tweetTimestamp})
        if "urls" in entity:
            for url in entity["urls"]:
                if (hasExtendedEntity) and item[1] == "root": break #In case we have an extended tweet don't get the URLs from root only from extended tweet
                if not "expanded_url" in url: continue
                urlNode = Node(l_url,{"url":url["expanded_url"]},'url')
                graph.upsertNode(urlNode)
                graph.upsertRelationship(user,r_used_url,urlNode,{'timestamp':tweetTimestamp})
                graph.upsertRelationship(tweet,r_has_url,urlNode,{'timestamp':tweetTimestamp})
        if "user_mentions" in entity:
            for usr in entity["user_mentions"]:
                if not p_user_key in usr: continue
                existingUser = graph.find(l_user,p_user_key,usr[p_user_key])
                if existingUser == None:
                    existingUser = Node(l_user,{p : (usr[p] if p in usr else 0) for p in p_user},p_user_key)
                    graph.upsertNode(existingUser,allowUpdate=False)
                graph.upsertRelationship(user,r_mentioned,existingUser,{'timestamp':tweetTimestamp},allowUpdate=False)

# %% [markdown]
# ## Questions & Answers

# %% [markdown]
# #### 1. Get the total number of tweets

# %%
print(graph.execute(f"match (tweets:{l_tweet}) return count(tweets) as Number_of_tweets").data())
# Out:
# [{'Number_of_tweets': 9409}]

# %% [markdown]
# #### 2. Get the total number of retweets

# %%
print(graph.execute(f"match (:{l_user})-[retweets:{r_retweeted}]->(:{l_tweet}) return count(retweets) as Number_of_retweets").data())
# Out:
# [{'Number_of_retweets': 20745}]

# %% [markdown]
# #### 3. Get the total number of hashtags (case insensitive)

# %%
print(graph.execute(f"match (hashtags:{l_hashtag}) return count(toLower(hashtags.text)) as Number_of_hashtags").data())
# Out:
# [{'Number_of_hashtags': 5324}]

# %% [markdown]
# #### 4. Get the 20 most popular hashtags (case insensitive) in descending order

# %%
pprint(graph.execute(f"match (hashtags:{l_hashtag}) return distinct toLower(hashtags.text) as hashtag, size((:{l_user})-[:{r_used_hashtag}]->(hashtags)) as indegree order by indegree descending limit 20").data())
# Out:
# [{'hashtag': 'openscience', 'indegree': 4492},
#  {'hashtag': 'citizenscience', 'indegree': 2506},
#  {'hashtag': 'openaccess', 'indegree': 641},
#  {'hashtag': 'scicomm', 'indegree': 562},
#  {'hashtag': 'opendata', 'indegree': 433},
#  {'hashtag': 'publicengagement', 'indegree': 427},
#  {'hashtag': 'crowdsourcing', 'indegree': 385},
#  {'hashtag': 'opensource', 'indegree': 369},
#  {'hashtag': 'datascience', 'indegree': 299},
#  {'hashtag': 'bioinformatics', 'indegree': 267},
#  {'hashtag': 'sb19', 'indegree': 257},
#  {'hashtag': 'stanworld', 'indegree': 255},
#  {'hashtag': 'westanpeace', 'indegree': 255},
#  {'hashtag': 'research', 'indegree': 255},
#  {'hashtag': 'westanlove', 'indegree': 255},
#  {'hashtag': 'citsci', 'indegree': 253},
#  {'hashtag': 'ukraine', 'indegree': 245},
#  {'hashtag': 'machinelearning', 'indegree': 234},
#  {'hashtag': 'covid19', 'indegree': 231},
#  {'hashtag': 'biodiversity', 'indegree': 222}]

# %% [markdown]
# #### 5. Get the total number of URLs

# %%
print(graph.execute(f"match (urls:{l_url}) return count(urls) as Number_Of_URLs").data())
# Out:
# [{'Number_Of_URLs': 3915}]

# %% [markdown]
# #### 6. Get the 20 most popular URLs in descending order

# %%
pprint(graph.execute(f"match (urls:{l_url}) return urls.url as url, size((:{l_user})-[:{r_used_url}]->(urls)) as indegree order by indegree descending limit 20").data())
# Out:
# [{'indegree': 433, 'url': 'http://apne.ws/CCCiUpB'},
#  {'indegree': 212, 'url': 'http://www.nairaworkers.com'},
#  {'indegree': 163, 'url': 'https://www.cisa.gov/shields-up'},
#  {'indegree': 105, 'url': 'https://osf.io/preprints/metaarxiv/zry2u'},
#  {'indegree': 95,
#   'url': 'https://plantfunctionaltraitscourses.w.uib.no/pftc6-norway-sign-up-now/'},
#  {'indegree': 75, 'url': 'https://www.nature.com/articles/d41586-022-00402-1'},
#  {'indegree': 72,
#   'url': 'https://ceh-online-surveys.onlinesurveys.ac.uk/pollinator-citizen-science-across-europe'},
#  {'indegree': 64,
#   'url': 'https://employment.ku.edu/postdoctoral-researcher/21278br'},
#  {'indegree': 64,
#   'url': 'https://apnews.com/article/f2c4960e48b8022a567780f3602b54e2'},
#  {'indegree': 60,
#   'url': 'https://www.atlanticcouncil.org/blogs/ukrainealert/new-crowdsourcing-campaign-can-help-save-ukraine/'},
#  {'indegree': 58,
#   'url': 'https://www.humboldt-foundation.de/fileadmin/Bewerben/Programme/Philipp-Schwartz-Initiative/PSI_Special_provisions_Ukraine_25_Feb._2022.pdf'},
#  {'indegree': 51, 'url': 'https://osf.io/preprints/metaarxiv/b9qaw'},
#  {'indegree': 51, 'url': 'https://raspberryshake.org'},
#  {'indegree': 50,
#   'url': 'https://www.ajtmh.org/view/journals/tpmd/aop/article-10.4269-ajtmh.21-1010/article-10.4269-ajtmh.21-1010.xml?rskey=63sqBe&result=2'},
#  {'indegree': 49, 'url': 'https://bit.ly/3kihpmP'},
#  {'indegree': 49,
#   'url': 'https://www.outreachy.org/blog/2022-02-04/may-2022-initial-applications-open/'},
#  {'indegree': 48, 'url': 'https://osec2022.eu/program'},
#  {'indegree': 44, 'url': 'http://dx.doi.org/10.1098/rsos.211042'},
#  {'indegree': 43, 'url': 'https://www.ecsa.sa.gov.au/enrolment'},
#  {'indegree': 43, 'url': 'https://rdcu.be/cltoT'}]

# %% [markdown]
# #### 7. Get the followers count of each user

# %%
pprint(graph.execute(f"match (users:{l_user}) return sum(users.{p_user[1]}) as Total_followers_count").data())
pprint(graph.execute(f"match (users:{l_user}) return users.{p_user[0]} as User, users.{p_user[1]} as followers").data())
# Out:
# [{'Total_followers_count': 118603522}]
# [{'User': 'AndGenomics', 'followers': 2369},
#  {'User': '_lewtun', 'followers': 2195},
#  {'User': 'Raamana_', 'followers': 2997},
#  {'User': 'JayHeltzer', 'followers': 1305},
#  {'User': 'Canada_CEBCEM', 'followers': 456},
#  {'User': 'OutTeachEd', 'followers': 2222},
#  {'User': 'zehavoc', 'followers': 4667},
#  {'User': 'EcoPol_Arg', 'followers': 642},
#  {'User': 'AvilaLovera', 'followers': 266},
#  {'User': 'seed_ball', 'followers': 52582},
#  {'User': 'bigmeadowsearch', 'followers': 465},
#  {'User': 'LicenceProDist', 'followers': 205},
#  {'User': 'TheJulieBenson', 'followers': 18156},
#  {'User': 'MyriamHirt', 'followers': 60},
#  {'User': 'jenjohnston74', 'followers': 32},
#  {'User': 'zaibatsu', 'followers': 0},
#  {'User': 'CondeNast', 'followers': 0},
#  {'User': 'WIRED', 'followers': 0},
#  {'User': 'ArtsJournalNews', 'followers': 0},
#  {'User': 'harrisonstephen', 'followers': 0},
#  {'User': 'alanmillerNLP', 'followers': 0},
#  {'User': 'MattNavarra', 'followers': 114127},
#  {'User': 'reggiewatts', 'followers': 0},
#  {'User': 'DisinfoIndex', 'followers': 0},
#  {'User': 'GiladEdelman', 'followers': 0},
#  {'User': 'CindyOtis_', 'followers': 0},
#  {'User': 'AdiGaskell', 'followers': 0},
#  {'User': 'gezgintrk', 'followers': 0},
#  {'User': 'Jules_T_', 'followers': 0},
#  {'User': 'raju', 'followers': 52009},
#  {'User': 'Wikimedia', 'followers': 0},
#  {'User': 'Wikipedia', 'followers': 0},
#  {'User': 'MaddyOsman', 'followers': 0},
#  {'User': 'RebeccaRambar', 'followers': 0},
#  {'User': 'IvetaKazoka', 'followers': 0},
#  {'User': 'Elexonic', 'followers': 0},
#  {'User': 'DaveBathur', 'followers': 2347},
#  {'User': 'TweetAurora', 'followers': 8484},
#  {'User': 'LAMP_rocket', 'followers': 0},
#  {'User': 'BMWUSA', 'followers': 636812},
#  {'User': 'falconhamada_90', 'followers': 2345},
#  {'User': 'Mohamedhog24', 'followers': 34},
#  {'User': 'tobioworks', 'followers': 1542},
#  {'User': 'polarbear0627', 'followers': 1297},
#  {'User': 'birdemergency', 'followers': 1701},
#  {'User': 'dauerstoerung', 'followers': 119},
#  {'User': 'SafaaMo38665785', 'followers': 394},
#  {'User': 'Hannahbella_nel', 'followers': 2771},
#  {'User': 'RaybellRocky', 'followers': 6},
#  {'User': 'bellewitch66', 'followers': 1446},
#  {'User': 'LachDonna', 'followers': 520},
#  {'User': 'NHMU', 'followers': 5750},
#  {'User': 'SwanerPreserve', 'followers': 0},
#  {'User': 'JordanRiverComm', 'followers': 0},
#  {'User': 'TracyAviary', 'followers': 0},
#  {'User': 'IndieAngles', 'followers': 3196},
#  {'User': 'BarbzTingzzz', 'followers': 287},
#  {'User': 'mikemorrison', 'followers': 11958},
#  {'User': 'UFollowtheOcean', 'followers': 5324},
#  {'User': 'peternooteboom', 'followers': 0},
#  {'User': 'peterbijlWilkes', 'followers': 0},
#  {'User': 'DJKylix', 'followers': 0},
#  {'User': 'ErikvanSebille', 'followers': 0},
#  {'User': 'UUClumpIsotopes', 'followers': 0},
#  {'User': 'geomatlab', 'followers': 944},
#  {'User': 'YourOnlyONEofcl', 'followers': 46},
#  {'User': 'AcademicMeming', 'followers': 0},
#  {'User': 'HutchinsBI', 'followers': 48},
#  {'User': 'ASAPbio_', 'followers': 0},
#  {'User': 'LibSkrat', 'followers': 5228},
#  {'User': 'ColdBloodedJ', 'followers': 183},
#  {'User': 'TPAIN', 'followers': 0},
#  {'User': 'Ludacris', 'followers': 0},
#  {'User': 'gunjansinha2017', 'followers': 490},
#  {'User': 'LeAnnaJCarey', 'followers': 4721},
#  {'User': 'JocelynRish', 'followers': 4499},
#  {'User': 'LJAmstutz', 'followers': 4234},
#  {'User': 'AlbertWhitman', 'followers': 0},
#  {'User': 'vselvaggio1', 'followers': 0},
#  {'User': 'SteamTeamBooks', 'followers': 0},
#  {'User': 'BevForte', 'followers': 945},
#  {'User': 'Bec_Chirps', 'followers': 5248},
#  {'User': 'seekbyinat', 'followers': 0},
#  {'User': 'RutgersSEBS', 'followers': 3484},
#  {'User': 'InnesFrances', 'followers': 238},
#  {'User': 'PracheeAC', 'followers': 19291},
#  {'User': 'biorxivpreprint', 'followers': 0},
#  {'User': 'ArcadiaScience', 'followers': 0},
#  {'User': 'japecake', 'followers': 268},
#  {'User': 'HeerJeet', 'followers': 0},
#  {'User': 'jessesingal', 'followers': 0},
#  {'User': 'Edwards_evoeco', 'followers': 841},
#  {'User': 'jesseSeeEm', 'followers': 1086},
#  {'User': 'ShadowpawPress', 'followers': 110},
#  {'User': 'Kickstarter', 'followers': 0},
#  {'User': 'Sputnik6400', 'followers': 215},
#  {'User': 'ewillett', 'followers': 1533},
#  {'User': 'AuthorECBlake', 'followers': 525},
#  {'User': 'TheWorldshapers', 'followers': 359},
#  {'User': 'amandalbradford', 'followers': 1003},
#  {'User': 'NOAAFish_PIRO', 'followers': 1551},
#  {'User': 'salonium', 'followers': 21149},
#  {'User': '02import_update', 'followers': 123},
#  {'User': 'Sarah17325183', 'followers': 0},
#  {'User': 'Paulintoronto47', 'followers': 0},
#  {'User': 'SethMacFarlane', 'followers': 0},
#  {'User': 'kjfeeley', 'followers': 1674},
#  {'User': 'Julianne_SF', 'followers': 1912},
#  {'User': 'Javier_DiazNido', 'followers': 1756},
#  {'User': 'KathNovotny', 'followers': 900},
#  {'User': 'RachidBARRY15', 'followers': 27},
#  {'User': 'PappyFitz', 'followers': 242},
#  {'User': 'jhski', 'followers': 0},
#  {'User': 'BianchiOfficial', 'followers': 0},
#  {'User': 'Paris_Roubaix', 'followers': 0},
#  {'User': 'WinterPark', 'followers': 0},
#  {'User': 'mikew627', 'followers': 59},
#  {'User': 'kyliesoanes', 'followers': 3083},
#  {'User': 'robdashworth', 'followers': 146},
#  {'User': 'BrainEvolutionN', 'followers': 1582},
#  {'User': 'shouldomythesis', 'followers': 73},
#  {'User': 'HighOnField', 'followers': 903},
#  {'User': 'buckster_rudy', 'followers': 199},
#  {'User': 'BioLumbee', 'followers': 1394},
#  {'User': 'NeedhiBhalla', 'followers': 13492},
#  {'User': '_CLACSO', 'followers': 0},
#  {'User': 'ErnestoFilippe1', 'followers': 9},
#  {'User': 'xmateul', 'followers': 328},
#  {'User': 'MU_Peter', 'followers': 2004},
#  {'User': 'GreeneScientist', 'followers': 7965},
#  {'User': 'WomensPowerCen', 'followers': 2952},
#  {'User': 'AmandaHay13', 'followers': 991},
#  {'User': 'pawel_szudarski', 'followers': 679},
#  {'User': 'EduFirst', 'followers': 955},
#  {'User': 'e_borer', 'followers': 2507},
#  {'User': 'crzacynpat', 'followers': 42},
#  {'User': 'Csar67044020', 'followers': 96},
#  {'User': 'nodexl', 'followers': 10601},
#  {'User': 'INOSproject', 'followers': 354},
#  {'User': 'fifestarr', 'followers': 55},
#  {'User': 'EngageNS', 'followers': 3246},
#  {'User': 'TrishKurralinga', 'followers': 3637},
#  {'User': 'preachinmoose', 'followers': 523},
#  {'User': 'kosinerri', 'followers': 16},
#  {'User': 'jeffbouwman', 'followers': 880},
#  {'User': 'WeatherSTEM', 'followers': 0},
#  {'User': 'emansouri', 'followers': 0},
#  {'User': 'GibraltarWx', 'followers': 0},
#  {'User': 'PGLocal4', 'followers': 0},
#  {'User': 'AndrewHumphrey', 'followers': 10424},
#  {'User': 'stefhaustein', 'followers': 2858},
#  {'User': 'CanYaSeeMeNow3', 'followers': 738},
#  {'User': 'wipinsanity', 'followers': 1724},
#  {'User': 'EurNetBrainEvoR', 'followers': 197},
#  {'User': 'MozakCGS', 'followers': 0},
#  {'User': 'UWGameScience', 'followers': 0},
#  {'User': 'niespika', 'followers': 136},
#  {'User': 'MichaelProulx', 'followers': 1673},
#  {'User': 'Alabama_Bubba', 'followers': 26},
#  {'User': 'citnatchallenge', 'followers': 2624},
#  {'User': 'lizbethdsantana', 'followers': 1412},
#  {'User': 'HernanO33422013', 'followers': 792},
#  {'User': 'maquinarock1', 'followers': 0},
#  {'User': 'horlatomide08', 'followers': 141},
#  {'User': 'snet_jklump', 'followers': 387},
#  {'User': 'AndreaKGrover', 'followers': 2629},
#  {'User': 'makotortilla', 'followers': 238},
#  {'User': 'OpenNMN', 'followers': 458},
#  {'User': 'DA0_DA0', 'followers': 0},
#  {'User': 'juiceboxETH', 'followers': 0},
#  {'User': 'DA0_Up', 'followers': 0},
#  {'User': 'PravdaOrNot', 'followers': 0},
#  {'User': 'stracma', 'followers': 10960},
#  {'User': 'ai6yrham', 'followers': 32442},
#  {'User': 'RebelGeo', 'followers': 0},
#  {'User': 'SeijaPaasonen', 'followers': 0},
#  {'User': 'StormHour', 'followers': 0},
#  {'User': 'Ecology_Andrea', 'followers': 183},
#  {'User': 'Teetoms__', 'followers': 1},
#  {'User': 'estuaryDNA', 'followers': 73},
#  {'User': 'MargyMacLibrary', 'followers': 5003},
#  {'User': 'SIChrisMannix', 'followers': 199206},
#  {'User': 'JimAberdale', 'followers': 0},
#  {'User': 'josh_daniel_lee', 'followers': 105},
#  {'User': 'wb_jennings', 'followers': 1083},
#  {'User': 'PreciousOsazen1', 'followers': 0},
#  {'User': '_KarenPalmer', 'followers': 327},
#  {'User': 'luisindic1', 'followers': 1757},
#  {'User': 'TheTradingBlvd', 'followers': 2975},
#  {'User': 'StayCalmAndCode', 'followers': 6},
#  {'User': 'Luispapion', 'followers': 905},
#  {'User': 'jambina', 'followers': 3392},
#  {'User': 'SoleneLejosne', 'followers': 292},
#  {'User': 'Udadisi', 'followers': 96015},
#  {'User': 'TheFerrariLab', 'followers': 5338},
#  {'User': 'billieeilish', 'followers': 0},
#  {'User': 'Coral_Watch', 'followers': 0},
#  {'User': 'ChambiChachage', 'followers': 899},
#  {'User': 'KeithPiccard', 'followers': 2248},
#  {'User': 'creekthinker', 'followers': 0},
#  {'User': 'nigronia', 'followers': 0},
#  {'User': 'CreekConnection', 'followers': 0},
#  {'User': 'voisupreme', 'followers': 857},
#  {'User': 'N_youall', 'followers': 351},
#  {'User': 'theWeatherboy', 'followers': 17338},
#  {'User': 'sbmaruf', 'followers': 96},
#  {'User': 'DrVeronikaCH', 'followers': 6649},
#  {'User': 'CarringtonKL', 'followers': 8989},
#  {'User': 'CrimJustJournal', 'followers': 0},
#  {'User': 'CriminologyOpen', 'followers': 3694},
#  {'User': 'SeagrassLiz', 'followers': 885},
#  {'User': 'RichardMcLellan', 'followers': 0},
#  {'User': 'gilbertspotoroo', 'followers': 595},
#  {'User': 'gpag', 'followers': 0},
#  {'User': 'CadetChimp', 'followers': 76},
#  {'User': 'MaryFernandez', 'followers': 0},
#  {'User': 'AnneArandall', 'followers': 0},
#  {'User': 'julie_kelly2', 'followers': 0},
#  {'User': 'Elias_Hallaj', 'followers': 4532},
#  {'User': 'pivottwistdev', 'followers': 100},
#  {'User': 'dgweissman', 'followers': 0},
#  {'User': 'ACT_Parks', 'followers': 0},
#  {'User': 'MarieColemanAO', 'followers': 5992},
#  {'User': 'DrLilon', 'followers': 1064},
#  {'User': 'LindsayMpls', 'followers': 1261},
#  {'User': 'AlisonSBarrett', 'followers': 508},
#  {'User': 'WePublicHealth', 'followers': 15229},
#  {'User': 'Neurons_AI', 'followers': 3188},
#  {'User': 'DoomsdaysCW', 'followers': 3739},
#  {'User': 'remaerdyaD', 'followers': 406},
#  {'User': 'CAIS_ACSI', 'followers': 283},
#  {'User': 'orchid00', 'followers': 2065},
#  {'User': 'BlueCorellian', 'followers': 1254},
#  {'User': 'scicodes1', 'followers': 14},
#  {'User': 'ResearchSoft', 'followers': 1024},
#  {'User': 'byrd_nick', 'followers': 3473},
#  {'User': 'jam_wbsn', 'followers': 15},
#  {'User': 'kuroosh521', 'followers': 6477},
#  {'User': 'iSudatta', 'followers': 5025},
#  {'User': 'makratofil', 'followers': 291},
#  {'User': 'd_y_o_s_a', 'followers': 119},
#  {'User': 'shovas', 'followers': 274},
#  {'User': 'UPlantATree', 'followers': 1592},
#  {'User': 'iran14433109', 'followers': 2155},
#  {'User': '_Duck_Tweeting', 'followers': 991},
#  {'User': 'BlueberryJane', 'followers': 2402},
#  {'User': 'RachelMWalker', 'followers': 619},
#  {'User': 'WendyMoyle2', 'followers': 2263},
#  {'User': 'ff_pena', 'followers': 208},
#  {'User': 'suburblightskin', 'followers': 834},
#  {'User': 'LA1UZZ', 'followers': 0},
#  {'User': 'nmadhurima', 'followers': 98},
#  {'User': 'pimpo1206', 'followers': 26},
#  {'User': 'FadedNord', 'followers': 28},
#  {'User': 'AdamPitre3', 'followers': 0},
#  {'User': 'BEPC22087964', 'followers': 0},
#  {'User': 'drawingablank10', 'followers': 0},
#  {'User': 'Evan_Hadfield', 'followers': 0},
#  {'User': 'RealCamHigby', 'followers': 0},
#  {'User': 'fund_my_startup', 'followers': 116},
#  {'User': 'adilbhatti_', 'followers': 1088},
#  {'User': 'Suot_Co', 'followers': 20},
#  {'User': 'CivictechL', 'followers': 17},
#  {'User': 'lilypeder', 'followers': 2480},
#  {'User': 'action_brain', 'followers': 4794},
#  {'User': 'anyamanquiquisx', 'followers': 701},
#  {'User': 'SarahJadeHunter', 'followers': 400},
#  {'User': 'fflursia', 'followers': 1297},
#  {'User': 'personalityeng', 'followers': 29},
#  {'User': '1OregonPatriot', 'followers': 6549},
#  {'User': 'Jim56777434', 'followers': 0},
#  {'User': 'HamillHimself', 'followers': 0},
#  {'User': 'RodrigoVeas10', 'followers': 147},
#  {'User': 'AllPlanets', 'followers': 7152},
#  {'User': 'That_Astro_Chic', 'followers': 25256},
#  {'User': 'Crippsy1969', 'followers': 3312},
#  {'User': 'oscargangas', 'followers': 1528},
#  {'User': 'killer8983', 'followers': 8},
#  {'User': 'EMDworak', 'followers': 317},
#  {'User': 'SaraLHalpern', 'followers': 0},
#  {'User': 'scott_saleska', 'followers': 1276},
#  {'User': 'Prometheus_Bot', 'followers': 2321},
#  {'User': 'aeintae', 'followers': 1284},
#  {'User': 'MBarrettoGarcia', 'followers': 889},
#  {'User': 'diegovogeid', 'followers': 132},
#  {'User': 'bigbrotherteej', 'followers': 1218},
#  {'User': 'slrutledge27', 'followers': 176},
#  {'User': 'rishima_', 'followers': 953},
#  {'User': 'RBXRetweetBot', 'followers': 3871},
#  {'User': 'RightBlight', 'followers': 40},
#  {'User': 'steakneggss', 'followers': 0},
#  {'User': 'ibuje_melvin', 'followers': 3},
#  {'User': 'CivicUnam', 'followers': 2844},
#  {'User': 'butactually', 'followers': 282},
#  {'User': 'Nockit1', 'followers': 682},
#  {'User': 'gregggonsalves', 'followers': 0},
#  {'User': 'chio_ikechukwu', 'followers': 338},
#  {'User': 'EAHornia', 'followers': 974},
#  {'User': 'residentesSERAM', 'followers': 0},
#  {'User': 'SERAM_RX', 'followers': 0},
#  {'User': 'kyna62', 'followers': 491},
#  {'User': '1000dayscodingb', 'followers': 469},
#  {'User': 'RousseauAgnes', 'followers': 5725},
#  {'User': 'PecqueuxA', 'followers': 2564},
#  {'User': 'FR_Conversation', 'followers': 0},
#  {'User': 'Talent2Employer', 'followers': 0},
#  {'User': 'in_stemm', 'followers': 4729},
#  {'User': 'BotKoshur', 'followers': 502},
#  {'User': 'PythonExpertBot', 'followers': 2876},
#  {'User': 'MiningGenome', 'followers': 96},
#  {'User': 'UAPx2', 'followers': 1564},
#  {'User': 'ImageAltText', 'followers': 7446},
#  {'User': 'UQ_Library', 'followers': 3835},
#  {'User': 'alien_ask', 'followers': 418},
#  {'User': 'maxxdavids', 'followers': 42},
#  {'User': 'Flash', 'followers': 0},
#  {'User': 'Sanveanis', 'followers': 0},
#  {'User': 'ibn_baidha', 'followers': 0},
#  {'User': 'ikwilson', 'followers': 0},
#  {'User': 'richardzussman', 'followers': 0},
#  {'User': 'stephen_fricker', 'followers': 414},
#  {'User': 'omoaug2014', 'followers': 15},
#  {'User': 'ITalkParanormal', 'followers': 7461},
#  {'User': 'UniversitySA', 'followers': 0},
#  {'User': 'pha', 'followers': 0},
#  {'User': 'UTAS_MPH', 'followers': 0},
#  {'User': 'JDarbro', 'followers': 104},
#  {'User': 'meg_zadow', 'followers': 237},
#  {'User': 'tinyklaus', 'followers': 1333},
#  {'User': 'alesarrett', 'followers': 798},
#  {'User': 'FredOswald', 'followers': 1835},
#  {'User': 'OIBR_UGA', 'followers': 0},
#  {'User': 'UGAResearch', 'followers': 0},
#  {'User': 'ugapsychology', 'followers': 0},
#  {'User': 'IOatUGA', 'followers': 298},
#  {'User': 'sprint_code', 'followers': 1119},
#  {'User': 'swilly78', 'followers': 40},
#  {'User': 'noreasonspec', 'followers': 0},
#  {'User': 'CaseyBriggs', 'followers': 0},
#  {'User': 'DRJViollet', 'followers': 41},
#  {'User': 'AndreaTECScot', 'followers': 792},
#  {'User': 'adlife_project', 'followers': 152},
#  {'User': '4Gerhard', 'followers': 78},
#  {'User': 'BetterworldEs', 'followers': 0},
#  {'User': 'janjoeotto', 'followers': 0},
#  {'User': 'ElaineEDO', 'followers': 10258},
#  {'User': 'Edgaroficial02', 'followers': 506},
#  {'User': 'matureflesh', 'followers': 0},
#  {'User': 'ItsJayC88', 'followers': 53},
#  {'User': 'WeDoWTK', 'followers': 548},
#  {'User': 'SimplifiedIct', 'followers': 413},
#  {'User': 'Shyamu_Bot', 'followers': 14},
#  {'User': 'dura_lex_lex', 'followers': 82},
#  {'User': 'full_bugs', 'followers': 506},
#  {'User': 'krista_natasha', 'followers': 350},
#  {'User': 'SerHerLlor', 'followers': 106},
#  {'User': 'ADezetter', 'followers': 660},
#  {'User': 'da_herbert8', 'followers': 33},
#  {'User': 'hiroshiii13', 'followers': 106},
#  {'User': 'isidroaguillo', 'followers': 8499},
#  {'User': 'bacterialchem', 'followers': 146},
#  {'User': 'martin_deborah', 'followers': 97},
#  {'User': 'burohfreiburg', 'followers': 166},
#  {'User': 'Starslikepinhol', 'followers': 122},
#  {'User': 'CoDailychalleng', 'followers': 1180},
#  {'User': 'RMU_Ukraine', 'followers': 30},
#  {'User': 'ElectraSif', 'followers': 176},
#  {'User': 'GWFWater', 'followers': 13410},
#  {'User': 'fmrwhy', 'followers': 1764},
#  {'User': 'MaiSarauta02', 'followers': 47},
#  {'User': 'FibroidNetwork', 'followers': 2679},
#  {'User': 'SabinTaranu', 'followers': 22},
#  {'User': 'AlettaBonn', 'followers': 1314},
#  {'User': 'chrisfrench83', 'followers': 298},
#  {'User': 'aiprendi', 'followers': 147},
#  {'User': 'vetswithpets00', 'followers': 304},
#  {'User': 'RadiologiaBcn', 'followers': 1781},
#  {'User': 'enricofrasca3g3', 'followers': 273},
#  {'User': '100dayscode', 'followers': 452},
#  {'User': 'geraldmuvengei2', 'followers': 1875},
#  {'User': 'gertrudix', 'followers': 1098},
#  {'User': 'Firm2Tech', 'followers': 3},
#  {'User': 'Judy_Dunlop', 'followers': 6911},
#  {'User': 'ev_essouza', 'followers': 2},
#  {'User': 'bernardrentier', 'followers': 5965},
#  {'User': 'SarayGGordillo', 'followers': 71},
#  {'User': 'newsaxes', 'followers': 497},
#  {'User': 'redings2', 'followers': 56},
#  {'User': 'Biblio_FUBerlin', 'followers': 1117},
#  {'User': 'inscico', 'followers': 1678},
#  {'User': 'UniofOxford', 'followers': 0},
#  {'User': 'IMLR_News', 'followers': 3703},
#  {'User': 'CSDisseminate', 'followers': 1174},
#  {'User': 'EU_shipping', 'followers': 1332},
#  {'User': 'EUNAVFOR', 'followers': 17922},
#  {'User': 'KamounLab', 'followers': 22994},
#  {'User': 'mirkoschaefer', 'followers': 2969},
#  {'User': 'Neurons2Nirvana', 'followers': 54},
#  {'User': 'WeCOMPAIR', 'followers': 103},
#  {'User': 'Iot_MDPI', 'followers': 82},
#  {'User': 'Incubimpulse', 'followers': 717},
#  {'User': 'JillRei02047399', 'followers': 0},
#  {'User': 'hjdraper8', 'followers': 2135},
#  {'User': 'Renee77652843', 'followers': 75},
#  {'User': 'AlePalmi82', 'followers': 661},
#  {'User': 'ahb108', 'followers': 0},
#  {'User': 'eliasdan', 'followers': 752},
#  {'User': 'LottiesLoaves', 'followers': 514},
#  {'User': 'DaniArosMualin', 'followers': 222},
#  {'User': 'SofieMeeus', 'followers': 151},
#  {'User': 'TripleEU', 'followers': 686},
#  {'User': 'OPERASEU', 'followers': 2445},
#  {'User': 'SalmonTroutCons', 'followers': 9682},
#  {'User': 'Corrado_Ruscica', 'followers': 456},
#  {'User': 'fossasia', 'followers': 7145},
#  {'User': '3_sriram', 'followers': 4},
#  {'User': 'lejano_sur', 'followers': 7},
#  {'User': 'Albocoder', 'followers': 52},
#  {'User': 'cyb3rops', 'followers': 0},
#  {'User': 'BinghamElla', 'followers': 193},
#  {'User': 'ForschDatenInfo', 'followers': 907},
#  {'User': 'BERD_NFDI', 'followers': 243},
#  {'User': 'P_Ensarguet', 'followers': 2131},
#  {'User': 'dev_discourse', 'followers': 0},
#  {'User': 'g8ge', 'followers': 0},
#  {'User': 'torreon', 'followers': 0},
#  {'User': 'ozapro18', 'followers': 1288},
#  {'User': 'ThePossumParty1', 'followers': 135},
#  {'User': 'ymvageesh', 'followers': 37},
#  {'User': 'HarvardBiz', 'followers': 0},
#  {'User': 'WSJ', 'followers': 0},
#  {'User': 'philriris', 'followers': 1740},
#  {'User': 'wrurestore', 'followers': 1441},
#  {'User': 'cedrickrier', 'followers': 1018},
#  {'User': 'reTweeetBots', 'followers': 1},
#  {'User': 'libschumm', 'followers': 49},
#  {'User': 'CSIUS_Brighton', 'followers': 102},
#  {'User': 'DriesDaems', 'followers': 495},
#  {'User': 'RDM4LUH', 'followers': 270},
#  {'User': 'crypto_condom', 'followers': 16243},
#  {'User': 'blocmatesdotcom', 'followers': 0},
#  {'User': 'Darrenlautf', 'followers': 0},
#  {'User': 'LeverhulmeTrust', 'followers': 33227},
#  {'User': 'dhgermany', 'followers': 4902},
#  {'User': 'jeroenbosman', 'followers': 5806},
#  {'User': 'subhi_darajat', 'followers': 97},
#  {'User': 'GeniusXG', 'followers': 405},
#  {'User': 'mn5hk', 'followers': 281},
#  {'User': 'MsPhelps', 'followers': 5684},
#  {'User': 'geosources', 'followers': 242},
#  {'User': 'acadsby_BLKD', 'followers': 1091},
#  {'User': 'UKEyeGenetics', 'followers': 448},
#  {'User': 'PatriCanto', 'followers': 328},
#  {'User': 'MimarRamis', 'followers': 598},
#  {'User': 'turkubioimaging', 'followers': 894},
#  {'User': 'AllFishOnTheFly', 'followers': 539},
#  {'User': 'navratansingh', 'followers': 464},
#  {'User': 'scale_at', 'followers': 556},
#  {'User': 'LeonXiaoY', 'followers': 437},
#  {'User': 'QMSchoolofLaw', 'followers': 0},
#  {'User': 'ccgritu', 'followers': 0},
#  {'User': 'ITUkbh', 'followers': 0},
#  {'User': 'Mael_Crepy', 'followers': 479},
#  {'User': 'RonnyRoewert', 'followers': 747},
#  {'User': 'lomecreu', 'followers': 529},
#  {'User': 'XoceQp', 'followers': 309},
#  {'User': 'GoaiDev', 'followers': 1287},
#  {'User': 'thebigfatmanny', 'followers': 611},
#  {'User': 'npclgs', 'followers': 7151},
#  {'User': 'SocSciScotland', 'followers': 3633},
#  {'User': 'chichar_eon', 'followers': 4203},
#  {'User': 'OpenSci_Pasteur', 'followers': 378},
#  {'User': 'institutpasteur', 'followers': 0},
#  {'User': 'wildflower_hour', 'followers': 32178},
#  {'User': 'ubleipzig', 'followers': 3114},
#  {'User': 'Pinpoint_est', 'followers': 3006},
#  {'User': 'cbed32', 'followers': 1209},
#  {'User': 'sp8962', 'followers': 0},
#  {'User': 'openstreetmap', 'followers': 0},
#  {'User': 'platformSTEMlk', 'followers': 63},
#  {'User': 'OpenLitterMap', 'followers': 4225},
#  {'User': 'med7sportarten', 'followers': 1549},
#  {'User': 'EarthValidator', 'followers': 482},
#  {'User': 'unawe', 'followers': 6799},
#  {'User': 'leiden2022', 'followers': 0},
#  {'User': 'Csisc1994', 'followers': 876},
#  {'User': 'j_shereef', 'followers': 597},
#  {'User': 'EykensJos', 'followers': 129},
#  {'User': 'Jaydeep79248904', 'followers': 52},
#  {'User': 'opinionbureau', 'followers': 0},
#  {'User': 'BabbyJaso', 'followers': 760},
#  {'User': 'BenListyg', 'followers': 1126},
#  {'User': 'OACellBiology', 'followers': 0},
#  {'User': 'Stan_Gielen', 'followers': 1282},
#  {'User': 'FrontPolicyLabs', 'followers': 710},
#  {'User': 'BurgelmanJean', 'followers': 1289},
#  {'User': 'pebe32', 'followers': 191},
#  {'User': 'Open_Institute', 'followers': 3365},
#  {'User': 'Jessica71065677', 'followers': 81},
#  {'User': 'John_Doe1e', 'followers': 423},
#  {'User': 'AnnChristineSt2', 'followers': 1},
#  {'User': 'FrontiersIn', 'followers': 75543},
#  {'User': 'Enkidu_forever', 'followers': 22},
#  {'User': 'SusanneMHeLaven', 'followers': 134},
#  {'User': 'GlobalCtr', 'followers': 4692},
#  {'User': 'ga_unihannover', 'followers': 460},
#  {'User': 'PlanetWatchsas', 'followers': 26592},
#  {'User': 'PlanetWatcher1', 'followers': 0},
#  {'User': 'ST_Sustainable', 'followers': 0},
#  {'User': 'mRperfEcttttty', 'followers': 0},
#  {'User': 'ceciroz', 'followers': 407},
#  {'User': 'HESEngineShed', 'followers': 6217},
#  {'User': 'KuschErik', 'followers': 240},
#  {'User': 'nkule_thusini', 'followers': 0},
#  {'User': 'lesegoseabi', 'followers': 114},
#  {'User': 'PresidencyZA', 'followers': 0},
#  {'User': 'ParliamentofRSA', 'followers': 0},
#  {'User': 'Rui_FFF', 'followers': 717},
#  {'User': 'MianoTeodoro', 'followers': 27},
#  {'User': 'ticeduforum', 'followers': 309},
#  {'User': 'jaeseongnikki', 'followers': 532},
#  {'User': 'WeiyuZ', 'followers': 865},
#  {'User': 'Britnatureguide', 'followers': 66303},
#  {'User': 'StewieStewart13', 'followers': 1392},
#  {'User': 'ActiveFishing1', 'followers': 36},
#  {'User': 'css_budapest', 'followers': 142},
#  {'User': 'EEANorwayGrants', 'followers': 0},
#  {'User': 'emilynordmann', 'followers': 3850},
#  {'User': 'MOSAIC_EU', 'followers': 199},
#  {'User': 'citscicomm', 'followers': 286},
#  {'User': 'mafimishebian', 'followers': 0},
#  {'User': 'RALeipzig', 'followers': 522},
#  {'User': 'cmDrStrange', 'followers': 171},
#  {'User': 'wonkitrolly', 'followers': 976},
#  {'User': 'PCI_Archaeology', 'followers': 1378},
#  {'User': 'StNicksFields', 'followers': 3072},
#  {'User': 'JovitaMezquita', 'followers': 473},
#  {'User': 'don_sci', 'followers': 84},
#  {'User': 'VacuumGlass', 'followers': 461},
#  {'User': 'WillPettersson', 'followers': 769},
#  {'User': 'pimpmymemory', 'followers': 5704},
#  {'User': 'checkfit', 'followers': 1429},
#  {'User': 'ICoRSA_News', 'followers': 801},
#  {'User': 'WeisserBernhard', 'followers': 1416},
#  {'User': 'kulturSPK', 'followers': 0},
#  {'User': 'pulses_increase', 'followers': 0},
#  {'User': 'LeibnizIPK', 'followers': 0},
#  {'User': 'informedbirds', 'followers': 1348},
#  {'User': 'Flewrabi', 'followers': 0},
#  {'User': 'helsinkiuni', 'followers': 0},
#  {'User': 'luomus_zoology', 'followers': 1472},
#  {'User': 'luomus', 'followers': 0},
#  {'User': 'HiLIFE_helsinki', 'followers': 0},
#  {'User': 'OEB_Helsinki', 'followers': 0},
#  {'User': 'LifeSciHelsinki', 'followers': 0},
#  {'User': 'MyPond_HU', 'followers': 11},
#  {'User': 'JosRaposo7', 'followers': 9},
#  {'User': 'thuslibrarians', 'followers': 229},
#  {'User': 'olatunike', 'followers': 260},
#  {'User': 'david_g_litvin', 'followers': 13},
#  {'User': 'lindakris99', 'followers': 1008},
#  {'User': 'InsidePMI', 'followers': 30082},
#  {'User': 'IITA_CGIAR', 'followers': 48695},
#  {'User': 'Luiz_bln', 'followers': 30},
#  {'User': 'KarloSevilla2', 'followers': 1395},
#  {'User': 'NFDI4BioDiv', 'followers': 831},
#  {'User': 'EoscPillar', 'followers': 1068},
#  {'User': 'presseunikassel', 'followers': 0},
#  {'User': 'NFDI_de', 'followers': 0},
#  {'User': 'EMBLEvents', 'followers': 18522},
#  {'User': 'felixksambu', 'followers': 1207},
#  {'User': 'PPR_Dahlem', 'followers': 1292},
#  {'User': 'RenewablesGrid', 'followers': 2084},
#  {'User': 'Bayernwerk', 'followers': 0},
#  {'User': 'NABU_de', 'followers': 0},
#  {'User': 'tetRRIS_project', 'followers': 209},
#  {'User': 'mvuleni_k', 'followers': 85},
#  {'User': 'mar_apeer', 'followers': 15},
#  {'User': 'ProjektRoadkill', 'followers': 432},
#  {'User': 'derStandardat', 'followers': 0},
#  {'User': 'SciReports', 'followers': 116256},
#  {'User': 'jonnyno89', 'followers': 22},
#  {'User': 'Patrice4020', 'followers': 3214},
#  {'User': 'metricell', 'followers': 359},
#  {'User': 'GaiaPluto', 'followers': 2524},
#  {'User': 'Le_Museum', 'followers': 0},
#  {'User': 'Jfeca1', 'followers': 108},
#  {'User': 'BLS_Schmid_G', 'followers': 947},
#  {'User': 'SeeTheAirBot', 'followers': 733},
#  {'User': 'LeandraMerz', 'followers': 0},
#  {'User': 'AudreyCulverSm1', 'followers': 0},
#  {'User': 'JesseBBorden', 'followers': 0},
#  {'User': 'BrunaLab', 'followers': 0},
#  {'User': 'Akhil_K86', 'followers': 50},
#  {'User': 'TechJose2', 'followers': 12},
#  {'User': 'AnneOsterrieder', 'followers': 5953},
#  {'User': 'moniquelvct', 'followers': 718},
#  {'User': 'engagedexplore', 'followers': 0},
#  {'User': 'Cat_Tabbner', 'followers': 0},
#  {'User': 'theGCPH', 'followers': 0},
#  {'User': 'ncfindia', 'followers': 12896},
#  {'User': 'we_made_that', 'followers': 5611},
#  {'User': 'escuewema', 'followers': 35},
#  {'User': 'GeorgiA28277670', 'followers': 0},
#  {'User': 'DrDreHistorian', 'followers': 4700},
#  {'User': 'JohEberhardt', 'followers': 325},
#  {'User': 'HDR_UK', 'followers': 9393},
#  {'User': 'LIBEReurope', 'followers': 8808},
#  {'User': 'b_ysaac', 'followers': 444},
#  {'User': 'ojodelmedio', 'followers': 0},
#  {'User': 'AliciaForsberg', 'followers': 2931},
#  {'User': 'ErynJAdams', 'followers': 0},
#  {'User': 'NelsonCowan1', 'followers': 0},
#  {'User': 'seunphat', 'followers': 606},
#  {'User': 'Flossan_', 'followers': 2577},
#  {'User': 'Library_RIA', 'followers': 8114},
#  {'User': 'katlnx', 'followers': 145},
#  {'User': 'DrinaneJohn', 'followers': 166},
#  {'User': 'PaulEfrenSantos', 'followers': 142},
#  {'User': 'newfxfs', 'followers': 2720},
#  {'User': 'AshaRaoRMIT', 'followers': 2224},
#  {'User': 'franknorman', 'followers': 2130},
#  {'User': 'natisthecure3', 'followers': 2667},
#  {'User': 'ReVeldes_VdV', 'followers': 1470},
#  {'User': 'ex_oriente_eV', 'followers': 648},
#  {'User': 'MathThyMod', 'followers': 245},
#  {'User': 'angiesaavedrag', 'followers': 1351},
#  {'User': 'connecth2020', 'followers': 176},
#  {'User': 'Thomas_SiriusV', 'followers': 75},
#  {'User': 'HugsPlatform', 'followers': 204},
#  {'User': 'Raad_Rogge', 'followers': 244},
#  {'User': '0x32BE', 'followers': 0},
#  {'User': 'precisement', 'followers': 2940},
#  {'User': 'Escritordefutu1', 'followers': 1388},
#  {'User': 'a_mahe', 'followers': 90},
#  {'User': 'myowntab', 'followers': 481},
#  {'User': 'steph_parrott', 'followers': 392},
#  {'User': 'ScienceHzla', 'followers': 903},
#  {'User': 'JackieMaybin', 'followers': 0},
#  {'User': 'cem_wave', 'followers': 51},
#  {'User': 'KirschkeSabrina', 'followers': 105},
#  {'User': 'Undergroundcou1', 'followers': 4461},
#  {'User': 'MEL_CGIAR', 'followers': 598},
#  {'User': 'davidfkane', 'followers': 397},
#  {'User': 'CatrionaAnders4', 'followers': 59},
#  {'User': 'selene_cordara', 'followers': 202},
#  {'User': 'meanmicio', 'followers': 2957},
#  {'User': 'UcheomaNwaozuru', 'followers': 298},
#  {'User': 'light4ph', 'followers': 110},
#  {'User': 'johnthackara', 'followers': 13452},
#  {'User': 'NovelEco', 'followers': 542},
#  {'User': 'AksuLehikoinen', 'followers': 2001},
#  {'User': 'RoostersLord', 'followers': 739},
#  {'User': 'EDPSciences', 'followers': 1505},
#  {'User': 'Maples46014332', 'followers': 1310},
#  {'User': 'AfricanLII', 'followers': 3319},
#  {'User': 'juliaschoenicke', 'followers': 50},
#  {'User': 'silverk_', 'followers': 170},
#  {'User': 'Politsei', 'followers': 0},
#  {'User': 'AilbheMckinney', 'followers': 492},
#  {'User': 'heath_bronte', 'followers': 228},
#  {'User': 'SharonBrennan', 'followers': 0},
#  {'User': 'meilinfung', 'followers': 2534},
#  {'User': 'CSEOLab', 'followers': 872},
#  {'User': 'barbwodecki', 'followers': 2225},
#  {'User': 'Edith_EuanDiaz', 'followers': 141},
#  {'User': 'Timchico', 'followers': 1208},
#  {'User': 'ysablegh', 'followers': 213},
#  {'User': 'Senatorpromise', 'followers': 0},
#  {'User': 'Cinnamon_Guy_', 'followers': 364},
#  {'User': 'RuuskanenSuvi', 'followers': 1503},
#  {'User': 'FIDRomanistik', 'followers': 1049},
#  {'User': 'PaulDragonwolf1', 'followers': 5577},
#  {'User': 'UofGJBoyle', 'followers': 1085},
#  {'User': 'Zayba_G', 'followers': 364},
#  {'User': 'Vlkantun_vule', 'followers': 1669},
#  {'User': 'spreadingwordon', 'followers': 543},
#  {'User': 'riccardo19811', 'followers': 37},
#  {'User': 'peterxdunn', 'followers': 672},
#  {'User': 'HiringCare', 'followers': 2371},
#  {'User': 'MicrobioCarly', 'followers': 70},
#  {'User': 'barbebert', 'followers': 287},
#  {'User': 'nilsph1', 'followers': 714},
#  {'User': 'UBiStavanger', 'followers': 889},
#  {'User': 'Libbyextra', 'followers': 4681},
#  {'User': '_CaglarDemir', 'followers': 51},
#  {'User': 'eswc_conf', 'followers': 0},
#  {'User': 'DiceResearch', 'followers': 0},
#  {'User': 'ichem_TIR', 'followers': 42},
#  {'User': 'PeterBleksley', 'followers': 0},
#  {'User': 'GBNEWS', 'followers': 0},
#  {'User': 'metpoliceuk', 'followers': 0},
#  {'User': 'ArleneFosterUK', 'followers': 0},
#  {'User': 'PaulEmbery', 'followers': 0},
#  {'User': 'Manifattura40', 'followers': 5798},
#  {'User': 'Brandt_Futurium', 'followers': 1006},
#  {'User': 'Ebh_mayra', 'followers': 148},
#  {'User': 'gnusolidario', 'followers': 1755},
#  {'User': 'pablotopo', 'followers': 751},
#  {'User': 'Thymbra_eHealth', 'followers': 560},
#  {'User': 'gnulims', 'followers': 145},
#  {'User': 'gnuhealth', 'followers': 3870},
#  {'User': 'Dr_Rob_Davis', 'followers': 6037},
#  {'User': 'puchaiinamo', 'followers': 459},
#  {'User': 'Unite_tech_univ', 'followers': 865},
#  {'User': 'Canadiandove', 'followers': 157},
#  {'User': 'MoskitoIncog', 'followers': 0},
#  {'User': 'BransfieldRob', 'followers': 0},
#  {'User': 'BroughDexter', 'followers': 0},
#  {'User': 'Investiga_SEA', 'followers': 529},
#  {'User': 'samuelstancl', 'followers': 0},
#  {'User': 'RDelinfo', 'followers': 113},
#  {'User': 'josephscien', 'followers': 856},
#  {'User': 'flybrain', 'followers': 302},
#  {'User': 'pachg5', 'followers': 17},
#  {'User': 'krukurikapu', 'followers': 45},
#  {'User': '_kendrr', 'followers': 193},
#  {'User': 'rift_app', 'followers': 372},
#  {'User': 'steven_Yjwang', 'followers': 100},
#  {'User': 'StressLab_wien', 'followers': 359},
#  {'User': 'stress_lab', 'followers': 0},
#  {'User': 'MELAGALES', 'followers': 214},
#  {'User': 'cheneydomingo', 'followers': 432},
#  {'User': 'jnnfrblgs', 'followers': 367},
#  {'User': 'joeroe90', 'followers': 483},
#  {'User': 'TGISun_Day', 'followers': 557},
#  {'User': 'Ericaaaaaf', 'followers': 333},
#  {'User': 'RealJoshBurnett', 'followers': 33},
#  {'User': 'paulvieira', 'followers': 0},
#  {'User': 'dri_ireland', 'followers': 8523},
#  {'User': 'bethknazook', 'followers': 0},
#  {'User': 'EOSCFuture', 'followers': 583},
#  {'User': 'VoteSAParty', 'followers': 57},
#  {'User': 'rk44hundred', 'followers': 79},
#  {'User': 'aaocarroll', 'followers': 1591},
#  {'User': 'CleanCoasts', 'followers': 8888},
#  {'User': 'AnTaisce', 'followers': 18624},
#  {'User': 'GreenSchoolsIre', 'followers': 11123},
#  {'User': 'BlueFlagIreland', 'followers': 0},
#  {'User': 'athinacp', 'followers': 45},
#  {'User': 'susheelvarma', 'followers': 1499},
#  {'User': 'EcoSchoolsScot', 'followers': 0},
#  {'User': 'MariePausch', 'followers': 0},
#  {'User': 'francois_jost', 'followers': 8},
#  {'User': 'libcce', 'followers': 2101},
#  {'User': 'MicrobiomeData', 'followers': 1447},
#  {'User': 'DaniLowenberg', 'followers': 0},
#  {'User': 'lizjkrz', 'followers': 0},
#  {'User': 'blacksciblog', 'followers': 13435},
#  {'User': 'UN', 'followers': 0},
#  {'User': 'Agenparl', 'followers': 6178},
#  {'User': 'aepol_bae43', 'followers': 65},
#  {'User': 'NlCOREV', 'followers': 540},
#  {'User': 'r4inedezvous', 'followers': 365},
#  {'User': 'PerissiIlaria', 'followers': 94},
#  {'User': 'IC2MP', 'followers': 0},
#  {'User': 'UCCS_8181', 'followers': 0},
#  {'User': 'INC_CNRS', 'followers': 0},
#  {'User': 'Metetelli11', 'followers': 601},
#  {'User': 'decubate', 'followers': 0},
#  {'User': 'GMIT_OAR', 'followers': 116},
#  {'User': 'suedeblush', 'followers': 631},
#  {'User': 'RoomiAziz', 'followers': 1007},
#  {'User': 'timmybash001', 'followers': 369},
#  {'User': 'VickiYE', 'followers': 335},
#  {'User': 'FinanceSpatial', 'followers': 0},
#  {'User': 'rosie_open', 'followers': 309},
#  {'User': 'weincludedorg', 'followers': 4940},
#  {'User': 'sciBot6', 'followers': 798},
#  {'User': 'amama_success', 'followers': 0},
#  {'User': 'CorradoTopi', 'followers': 926},
#  {'User': 'kobv_zt', 'followers': 415},
#  {'User': 'OpenAccess_BB', 'followers': 390},
#  {'User': 'oa_berlin', 'followers': 1348},
#  {'User': 'TH_Wildau', 'followers': 0},
#  {'User': 'purplestealerz', 'followers': 278},
#  {'User': 'sarcasticassy', 'followers': 443},
#  {'User': 'atree_org', 'followers': 7857},
#  {'User': 'itsmckentzee', 'followers': 1970},
#  {'User': 'dokusare2', 'followers': 113},
#  {'User': 'InfoMarittime', 'followers': 872},
#  {'User': 'merypoca', 'followers': 688},
#  {'User': 'spreadit_online', 'followers': 436},
#  {'User': 'visiblemagicdev', 'followers': 126},
#  {'User': 'Ideas_4_Change', 'followers': 5959},
#  {'User': 'ISGLOBALorg', 'followers': 21199},
#  {'User': 'BDMarchi', 'followers': 293},
#  {'User': 'LuciaErrandonea', 'followers': 391},
#  {'User': 'FlorenceGignac', 'followers': 80},
#  {'User': 'raultoran', 'followers': 7148},
#  {'User': 'biblioUPM', 'followers': 4167},
#  {'User': 'FIUPM', 'followers': 2131},
#  {'User': 'rojeda_ricardo', 'followers': 447},
#  {'User': 'BorisMericskay', 'followers': 3606},
#  {'User': 'm_maciasfauria', 'followers': 471},
#  {'User': 'shnmvllcrn', 'followers': 210},
#  {'User': 'jluis10', 'followers': 230},
#  {'User': 'LaVane1979', 'followers': 9939},
#  {'User': 'WiltsRivers', 'followers': 2309},
#  {'User': 'wessexwater', 'followers': 0},
#  {'User': 'CPW_Global', 'followers': 0},
#  {'User': 'vxszx', 'followers': 2641},
#  {'User': 'angeelleengg', 'followers': 816},
#  {'User': 'IYCupdates', 'followers': 2925},
#  {'User': 'andreabozen', 'followers': 46},
#  {'User': 'AIUCD', 'followers': 1463},
#  {'User': 'jabaizan', 'followers': 150},
#  {'User': 'RichardGHopf', 'followers': 372},
#  {'User': 'bewitchedmind', 'followers': 1328},
#  {'User': 'anthony_luca96', 'followers': 1109},
#  {'User': 'spreadwordonlin', 'followers': 466},
#  {'User': 'NIN_knaw', 'followers': 1573},
#  {'User': 'phaidra_org', 'followers': 67},
#  {'User': 'KevinBeynon', 'followers': 642},
#  {'User': 'CBarrozziP', 'followers': 130},
#  {'User': 'jacknunn', 'followers': 0},
#  {'User': 'ShuvarthiB', 'followers': 442},
#  {'User': 'InfoMgmtExec', 'followers': 2823},
#  {'User': 'jullyalozie', 'followers': 0},
#  {'User': 'zeevaart', 'followers': 1905},
#  {'User': 'ictjournal', 'followers': 1823},
#  {'User': 'Seba_Sismos_CL', 'followers': 1462},
#  {'User': 'charlize_krizia', 'followers': 327},
#  {'User': 'MuchWowKlvn', 'followers': 27},
#  {'User': 'ENRIITC_eu', 'followers': 406},
#  {'User': 'SpicyEva1', 'followers': 129},
#  {'User': 'ResearchDataUoE', 'followers': 347},
#  {'User': 'chris_harrod', 'followers': 6132},
#  {'User': 'qdrepository', 'followers': 0},
#  {'User': 'SourceCodeContr', 'followers': 1376},
#  {'User': 'protocol', 'followers': 0},
#  {'User': 'KarelLuyben', 'followers': 1064},
#  {'User': 'vincedeguia', 'followers': 663},
#  {'User': 'agarrett1212', 'followers': 1160},
#  {'User': 'Katie_M_Ritter', 'followers': 0},
#  {'User': 'UnivPoliMarche', 'followers': 4260},
#  {'User': 'cch_harshakumar', 'followers': 245},
#  {'User': '_j4co6', 'followers': 249},
#  {'User': 'MoorfieldsBRC', 'followers': 2182},
#  {'User': 'helenfcraig', 'followers': 787},
#  {'User': 'TIME4CS', 'followers': 302},
#  {'User': 'CrowdInnoIMW', 'followers': 44},
#  {'User': 'hhlleipzig', 'followers': 0},
#  {'User': 'riocard911', 'followers': 968},
#  {'User': 'rtItBot', 'followers': 21153},
#  {'User': 'WFSJ', 'followers': 0},
#  {'User': 'UofRegina', 'followers': 0},
#  {'User': 'MIT', 'followers': 0},
#  {'User': 'aweandmadness', 'followers': 102},
#  {'User': 'm_angeles582', 'followers': 176},
#  {'User': 'nazdls', 'followers': 428},
#  {'User': 'revistaHCSM', 'followers': 3830},
#  {'User': 'informa85320132', 'followers': 321},
#  {'User': 'cory_elowe', 'followers': 533},
#  {'User': 'BirdObserver', 'followers': 0},
#  {'User': 'kassyrol', 'followers': 535},
#  {'User': 'ZrryPttr', 'followers': 168},
#  {'User': 'MalawiLII', 'followers': 411},
#  {'User': 'evamen', 'followers': 3804},
#  {'User': 'A_Panagopoulou', 'followers': 0},
#  {'User': 'jmcgx', 'followers': 539},
#  {'User': 'lorcanD', 'followers': 7353},
#  {'User': 'danbri', 'followers': 10901},
#  {'User': 'manjizoo', 'followers': 486},
#  {'User': 'billatnapier', 'followers': 11047},
#  {'User': 'JohannesvV', 'followers': 76},
#  {'User': 'Drones_MDPI', 'followers': 979},
#  {'User': 'EoscLife', 'followers': 1321},
#  {'User': 'LibraryITU', 'followers': 4320},
#  {'User': 'ankostr', 'followers': 0},
#  {'User': 'SwafSwafs', 'followers': 228},
#  {'User': 'Noah58209493', 'followers': 108},
#  {'User': 'AfflatusNft', 'followers': 0},
#  {'User': 'BR_0569', 'followers': 1983},
#  {'User': 'Tron454512', 'followers': 8},
#  {'User': 'EnigmatticNft', 'followers': 0},
#  {'User': 'James94767516', 'followers': 26},
#  {'User': 'CharismaNfts', 'followers': 0},
#  {'User': 'sirjLab', 'followers': 142},
#  {'User': 'mdhDuBois', 'followers': 2646},
#  {'User': 'katbprz', 'followers': 351},
#  {'User': 'DBHayhow', 'followers': 679},
#  {'User': 'the_marketeers', 'followers': 459765},
#  {'User': 'FreshEyesonIce', 'followers': 0},
#  {'User': 'NFTjoker2', 'followers': 0},
#  {'User': 'InfluentiallNft', 'followers': 0},
#  {'User': 'oacore', 'followers': 2452},
#  {'User': 'Pamelamb10', 'followers': 17},
#  {'User': 'astrosnat', 'followers': 1865},
#  {'User': 'simonstuartSE', 'followers': 3078},
#  {'User': 'deepa_sena', 'followers': 806},
#  {'User': 'KewScience', 'followers': 0},
#  {'User': 'bgci', 'followers': 9008},
#  {'User': 'Love_plants', 'followers': 0},
#  {'User': 'ARochaUK', 'followers': 4593},
#  {'User': 'dawnbazely', 'followers': 10255},
#  {'User': 'YUFAyorku', 'followers': 1100},
#  {'User': 'WhoCouldYouTell', 'followers': 994},
#  {'User': 'OceanOculus', 'followers': 2881},
#  {'User': 'PantelSarah', 'followers': 295},
#  {'User': 'EwanFenelon', 'followers': 85},
#  {'User': 'djdavidsonlab', 'followers': 1957},
#  {'User': 'MicahEHirsch', 'followers': 449},
#  {'User': 'spectroag', 'followers': 4078},
#  {'User': 'sebkrier', 'followers': 1294},
#  {'User': 'KateJMason', 'followers': 4965},
#  {'User': 'nyahcape', 'followers': 238},
#  {'User': 'lancexasperated', 'followers': 388},
#  {'User': 'J_Cruz2279', 'followers': 467},
#  {'User': 'TencentGlobal', 'followers': 0},
#  {'User': 'IheUgochi', 'followers': 65},
#  {'User': 'AlyssaSpurling', 'followers': 89},
#  {'User': 'psykanot', 'followers': 244},
#  {'User': 'ximegabri', 'followers': 125},
#  {'User': 'emese_szilagyi', 'followers': 92},
#  {'User': 'NFTWannabe3', 'followers': 52},
#  {'User': '1963Fjpa', 'followers': 61},
#  {'User': 'cont_int', 'followers': 9},
#  {'User': 'Indeqks', 'followers': 296},
#  {'User': 'InaOpitz', 'followers': 90},
#  {'User': 'hella_von_unger', 'followers': 0},
#  {'User': 'screencomposer2', 'followers': 1366},
#  {'User': 'jialanw', 'followers': 2786},
#  {'User': 'NextGenLC', 'followers': 12392},
#  {'User': 'subhobrata1', 'followers': 485},
#  {'User': 'snac_fr', 'followers': 1291},
#  {'User': 'spreadwordson', 'followers': 1262},
#  {'User': 'OSCGroningen', 'followers': 967},
#  {'User': 'EHULearnService', 'followers': 3047},
#  {'User': 'EdgeHill_Psych', 'followers': 3300},
#  {'User': 'EHU_Geo', 'followers': 0},
#  {'User': 'BiologyEHU', 'followers': 0},
#  {'User': 'EHUSportandPA', 'followers': 0},
#  {'User': 'EHU_FHSCM', 'followers': 0},
#  {'User': 'IPHC_Strasbourg', 'followers': 0},
#  {'User': 'isalacuerva', 'followers': 1127},
#  {'User': 'CjShruti', 'followers': 30},
#  {'User': 'KathTyl1', 'followers': 1570},
#  {'User': 'smrabd', 'followers': 326},
#  {'User': 'Adam_Oss', 'followers': 153},
#  {'User': 'vyancelibrarian', 'followers': 483},
#  {'User': 'ENJOIproject', 'followers': 632},
#  {'User': 'HannesThiemann', 'followers': 44},
#  {'User': 'growing_seller', 'followers': 9},
#  {'User': 'DuquesneLight', 'followers': 6770},
#  {'User': 'CRGenomica', 'followers': 18752},
#  {'User': 'jtedds', 'followers': 2644},
#  {'User': 'CumdumpBoyPh', 'followers': 7282},
#  {'User': 'CfE_UoM', 'followers': 680},
#  {'User': 'BenBlaiszik', 'followers': 616},
#  {'User': 'DebsEThorpe', 'followers': 1743},
#  {'User': 'EuraxessCat', 'followers': 1321},
#  {'User': 'kenskeldon', 'followers': 1005},
#  {'User': 'KITKarlsruhe', 'followers': 32433},
#  {'User': 'Forbes', 'followers': 17519323},
#  {'User': 'martmc88b', 'followers': 185},
#  {'User': 'mary_hoyt', 'followers': 163},
#  {'User': 'martingugino', 'followers': 0},
#  {'User': 'lxpatwork', 'followers': 153},
#  {'User': 'AmilaSumanapala', 'followers': 707},
#  {'User': 'elaphrornis', 'followers': 805},
#  {'User': 'ThilinaHA', 'followers': 418},
#  {'User': 'Mazi_Highpriest', 'followers': 599},
#  {'User': 'MarieMaduemezi1', 'followers': 4946},
#  {'User': 'shiu_aminath', 'followers': 275},
#  {'User': 'PortalPortuario', 'followers': 15234},
#  {'User': 'TPLM_Officiel', 'followers': 6877},
#  {'User': 'stabi_erlangen', 'followers': 0},
#  {'User': 'Dr_NinonFrank', 'followers': 0},
#  {'User': 'Bedstuyflyty', 'followers': 761},
#  {'User': 'BirdBotASA', 'followers': 2510},
#  {'User': 'StevenCravis', 'followers': 0},
#  {'User': 'MindTheBridge', 'followers': 0},
#  {'User': 'tombernr', 'followers': 332},
#  {'User': 'keytseu', 'followers': 0},
#  {'User': 'DirkLangolf', 'followers': 1067},
#  {'User': 'treecomp', 'followers': 244},
#  {'User': 'mrjoewalker', 'followers': 1816},
#  {'User': 'chemlibcam', 'followers': 851},
#  {'User': 'OionOiOi', 'followers': 802},
#  {'User': 'KareAnderson', 'followers': 20198},
#  {'User': 'Biggy1883', 'followers': 10234},
#  {'User': 'lisamgriffith', 'followers': 1542},
#  {'User': 'pedroprincipe', 'followers': 1684},
#  {'User': 'proanimalrightz', 'followers': 25},
#  {'User': 'collend', 'followers': 0},
#  {'User': 'UniversiteLyon', 'followers': 0},
#  {'User': 'chickpeaman', 'followers': 1340},
#  {'User': 'ChrisWyver33', 'followers': 0},
#  {'User': 'DaBoom66', 'followers': 212},
#  {'User': 'C3DTI', 'followers': 898},
#  {'User': 'planbox', 'followers': 2099},
#  {'User': 'M_J_Spasojevic', 'followers': 1634},
#  {'User': 'nimmamukund', 'followers': 0},
#  {'User': 'AAPKarnataka', 'followers': 0},
#  {'User': 'sriramulubjp', 'followers': 0},
#  {'User': 'AAPBangalore', 'followers': 0},
#  {'User': 'aapkaprithvi', 'followers': 0},
#  {'User': 'KSRSA_GoK', 'followers': 0},
#  {'User': 'tdkarnataka', 'followers': 0},
#  {'User': 'MohanDasari_', 'followers': 0},
#  {'User': 'ShivAroor', 'followers': 0},
#  {'User': 'ferli90', 'followers': 2724},
#  {'User': 'jasmith_yorku', 'followers': 1947},
#  {'User': 'shoshanahjacobs', 'followers': 6748},
#  {'User': 'OA_INVOLVE', 'followers': 505},
#  {'User': 'PCIEvolBiol', 'followers': 2233},
#  {'User': 'edhollox', 'followers': 0},
#  {'User': 'uniofleicester', 'followers': 0},
#  {'User': 'PCIgenomics', 'followers': 0},
#  {'User': 'Mich_Lakes', 'followers': 882},
#  {'User': 'thesgconline', 'followers': 2987},
#  {'User': 'target2035', 'followers': 176},
#  {'User': 'alexabernardog', 'followers': 1124},
#  {'User': 'DavidSilvaParr3', 'followers': 47},
#  {'User': 'JoviNomas', 'followers': 0},
#  {'User': 'MikeElgan', 'followers': 42696},
#  {'User': 'phirabu', 'followers': 241},
#  {'User': 'bioDGPs_DGPA', 'followers': 2341},
#  {'User': 'CollabraOA', 'followers': 4563},
#  {'User': 'templeton_fdn', 'followers': 0},
#  {'User': 'improvingpsych', 'followers': 10745},
#  {'User': 'UmbrellaDF', 'followers': 20},
#  {'User': 'TribalAffairsIn', 'followers': 0},
#  {'User': 'TribalArmy', 'followers': 0},
#  {'User': 'NatureIsWater', 'followers': 454},
#  {'User': 'rachmjohnston', 'followers': 159},
#  {'User': 'randzonen', 'followers': 357},
#  {'User': 'SonjaHaerkoenen', 'followers': 262},
#  {'User': 'AnnaJaneL', 'followers': 2227},
#  {'User': 'paul_royall', 'followers': 1055},
#  {'User': 'GrundyLibrary', 'followers': 404},
#  {'User': 'kjewett2', 'followers': 339},
#  {'User': 'AcadiaNPS', 'followers': 0},
#  {'User': 'imaginatik', 'followers': 6845},
#  {'User': 'Anitive', 'followers': 25},
#  {'User': 'ajspadial', 'followers': 813},
#  {'User': 'lkortbutler', 'followers': 441},
#  {'User': 'rholienrhoii', 'followers': 1315},
#  {'User': 'VizCrim', 'followers': 1},
#  {'User': 'frbrando', 'followers': 105},
#  {'User': 'Nigeblue', 'followers': 1100},
#  {'User': 'emandificent', 'followers': 499},
#  {'User': 'sule_tomkinson', 'followers': 2552},
#  {'User': 'm_cragin', 'followers': 293},
#  {'User': 'SociologyKB', 'followers': 30},
#  {'User': 'DivingGalway', 'followers': 58},
#  {'User': 'PhilippConzett', 'followers': 425},
#  {'User': 'storenorske', 'followers': 0},
#  {'User': 'ddvnunez', 'followers': 350},
#  {'User': 'NuyddMu', 'followers': 34},
#  {'User': 'TheAUSSDA', 'followers': 881},
#  {'User': 'DublinFOE', 'followers': 710},
#  {'User': 'Daliakhojely', 'followers': 1484},
#  {'User': 'Crimsonrage9', 'followers': 30},
#  {'User': 'uwcdis', 'followers': 645},
#  {'User': 'cjackso3', 'followers': 0},
#  {'User': 'UWMadiSchool', 'followers': 1920},
#  {'User': 'almostinfamous', 'followers': 2776},
#  {'User': 'NVSData', 'followers': 8379},
#  {'User': 'ESA_org', 'followers': 42728},
#  {'User': 'dominik_hagmann', 'followers': 540},
#  {'User': 'rsilvia77', 'followers': 382},
#  {'User': 'MishiChoudhary', 'followers': 6417},
#  {'User': 'UoMMskResearch', 'followers': 1460},
#  {'User': 'wadakashiho', 'followers': 5980},
#  {'User': '_yassssssmin', 'followers': 12},
#  {'User': 'GeoHeroITC', 'followers': 12},
#  {'User': 'MarkusKonkol', 'followers': 0},
#  {'User': 'OSCTwente', 'followers': 328},
#  {'User': 'LHoltonLee', 'followers': 1816},
#  {'User': 'PeteEcology', 'followers': 2959},
#  {'User': 'my_plants_dance', 'followers': 408},
#  {'User': 'SaluniG', 'followers': 103},
#  {'User': 'Mio_Yokoi', 'followers': 1871},
#  {'User': 'MontseS1', 'followers': 700},
#  {'User': 'JeremysNeck', 'followers': 0},
#  {'User': 'audreyjosssh', 'followers': 356},
#  {'User': 'ruthlady', 'followers': 1351},
#  {'User': 'Yoenoes_Mohd', 'followers': 237},
#  {'User': 'OpenResLeeds', 'followers': 4838},
#  {'User': 'ShobaDawson', 'followers': 1186},
#  {'User': 'TO_dpr', 'followers': 2516},
#  {'User': 'KDCobey', 'followers': 975},
#  {'User': 'toupinak', 'followers': 0},
#  {'User': 'ProulxLaurie', 'followers': 1782},
#  {'User': 'martinusdewit', 'followers': 0},
#  {'User': 'NIHRinvolvement', 'followers': 0},
#  {'User': 'GlobalPPINet', 'followers': 1155},
#  {'User': 'CIHR_IRSC', 'followers': 0},
#  {'User': 'CABI_News', 'followers': 10704},
#  {'User': 'TF_Ecosperity', 'followers': 0},
#  {'User': 'SkaFolding_One', 'followers': 131},
#  {'User': '_M_Dey', 'followers': 1306},
#  {'User': 'SATYAJIT1910', 'followers': 2141},
#  {'User': 'mbreichenbach', 'followers': 302},
#  {'User': 'CMHA_NTL', 'followers': 43973},
# ...
#  {'User': 'Sarri', 'followers': 0},
#  {'User': 'HeRC_Tweets', 'followers': 0},
#  {'User': 'UoMPankhurst', 'followers': 0},
#  {'User': 'ManchesterBRC', 'followers': 0},
#  {'User': 'PonderosaMstrys', 'followers': 643},
#  {'User': 'Maria_Trivino_C', 'followers': 468},
#  {'User': 'vicky_ig', 'followers': 4534},
#  {'User': 'Brinchekscience', 'followers': 461},
#  {'User': 'AudubonNC', 'followers': 0},
#  {'User': 'WCPSSElemScie', 'followers': 0},
#  {'User': 'lizditz', 'followers': 9897},
#  {'User': 'houseimaginatn', 'followers': 4476},
#  {'User': 'eacomer', 'followers': 48},
#  {'User': 'league_navy', 'followers': 18},
#  {'User': 'SeapowerMag', 'followers': 5209},
#  {'User': 'matg20', 'followers': 1764},
#  {'User': 'csugimoto', 'followers': 3818},
#  {'User': 'StellenboschUni', 'followers': 0},
#  {'User': 'IsabelBasson', 'followers': 0},
#  {'User': 'lariviev', 'followers': 2969},
#  {'User': 'copdeb', 'followers': 846},
#  {'User': 'AnjaHerwig', 'followers': 52},
#  {'User': 'ABomb88', 'followers': 283},
#  {'User': 'Brandulinks', 'followers': 4258},
#  {'User': 'AlterBusiness', 'followers': 0},
#  {'User': 'Mo_Safavi', 'followers': 625},
#  {'User': 'socmdm', 'followers': 0},
#  {'User': 'rhta16', 'followers': 0},
#  {'User': 'InnovationCA', 'followers': 0},
#  {'User': 'HlthResearchBC', 'followers': 0},
#  {'User': 'PeerModels', 'followers': 447},
#  {'User': 'aminadibi', 'followers': 366},
#  {'User': 'newsvava', 'followers': 460},
#  {'User': 'ruminatus', 'followers': 651},
#  {'User': 'DjPopFunk', 'followers': 343},
#  {'User': 'Mortisache', 'followers': 0},
#  {'User': 'LPTN1776', 'followers': 9254},
#  {'User': 'jeanne_cleve', 'followers': 0},
#  {'User': 'RepThomasMassie', 'followers': 0},
#  {'User': 'UAZBIO5', 'followers': 3967},
#  {'User': 'rywilwrite', 'followers': 1092},
#  {'User': 'AlexNaderWrites', 'followers': 0},
#  {'User': 'NEMAlgarve', 'followers': 50},
#  {'User': 'greentechdon', 'followers': 4745},
#  {'User': 'YaneValdezT', 'followers': 2393},
#  {'User': 'oriolripoll', 'followers': 4880},
#  {'User': 'BetterSSw', 'followers': 53},
#  {'User': 'ryanyoungwriter', 'followers': 854},
#  {'User': 'SmithDryGoods', 'followers': 2832},
#  {'User': 'piperewan', 'followers': 0},
#  {'User': 'ASchieberle', 'followers': 80},
#  {'User': 'kat_vessel', 'followers': 433},
#  {'User': 'JKamens', 'followers': 5849},
#  {'User': 'Vero_Zepeda_', 'followers': 323},
#  {'User': 'ProfDewey', 'followers': 570},
#  {'User': 'MaxReuterEvo', 'followers': 671},
#  {'User': 'JEvBio', 'followers': 1737},
#  {'User': 'UU_GCSC', 'followers': 908},
#  {'User': 'DogAgingProject', 'followers': 3041},
#  {'User': 'MGBennett', 'followers': 513},
#  {'User': 'SharpRandom', 'followers': 53},
#  {'User': 'PaulRobustelli', 'followers': 1853},
#  {'User': 'Bowercpcman', 'followers': 1027},
#  {'User': 'heritagedaisy', 'followers': 708},
#  {'User': 'melanieganzben1', 'followers': 263},
#  {'User': 'Transkribus', 'followers': 0},
#  {'User': 'ScanTent', 'followers': 0},
#  {'User': 'ResearchGenome', 'followers': 2164},
#  {'User': 'CarenzaLewis', 'followers': 16303},
#  {'User': 'Eilonwy24', 'followers': 542},
#  {'User': 'helios_h2020', 'followers': 77},
#  {'User': 'AlexAmoSfC', 'followers': 238},
#  {'User': 'NGRREC', 'followers': 463},
#  {'User': 'IL_RiverWatch', 'followers': 0},
#  {'User': 'weersprookjes', 'followers': 269},
#  {'User': '_frank_k_', 'followers': 214},
#  {'User': 'rezak121212', 'followers': 6675},
#  {'User': 'Moeinafshari', 'followers': 600},
#  {'User': 'crowdsourcin', 'followers': 476},
#  {'User': 'FairImaging', 'followers': 69},
#  {'User': 'thepromptmag', 'followers': 10201},
#  {'User': 'saltysaguaro', 'followers': 113},
#  {'User': 'FibiNode', 'followers': 90},
#  {'User': 'kev__en', 'followers': 107},
#  {'User': 'sethrogenszn', 'followers': 598},
#  {'User': 'JosephTumber', 'followers': 1115},
#  {'User': 'radanirani11', 'followers': 1105},
#  {'User': 'jhelebrant', 'followers': 167},
#  {'User': 'joshbard', 'followers': 829},
#  {'User': 'Gossamer_Sound', 'followers': 647},
#  {'User': 'LajeunesseLab', 'followers': 1302},
#  {'User': 'SpaceArtSAE', 'followers': 2573},
#  {'User': 'MillChannel', 'followers': 0},
#  {'User': 'HeyyyItsEricM', 'followers': 22},
#  {'User': 'Sozae_', 'followers': 1292},
#  {'User': 'doubi3__', 'followers': 935},
#  {'User': 'culturebroker', 'followers': 1202},
#  {'User': 'KahaliaM', 'followers': 430},
#  {'User': 'isaisgo', 'followers': 0},
#  {'User': 'freedomgang', 'followers': 0},
#  {'User': 'Tincala', 'followers': 299},
#  {'User': 'misssarahrazner', 'followers': 733},
#  {'User': 'riikka_kevo', 'followers': 1626},
#  {'User': 'NinjaDevBot', 'followers': 115},
#  {'User': 'mkaeberlein', 'followers': 7518},
#  {'User': 'nahlikcj', 'followers': 1861},
#  {'User': 'ObserverParafox', 'followers': 599},
#  {'User': 'Kelaine', 'followers': 1283},
#  {'User': 'cabbageleek', 'followers': 1035},
#  {'User': 'trias_project', 'followers': 0},
#  {'User': 'jamesmccrary', 'followers': 5274},
#  {'User': 'TechySewell', 'followers': 0},
#  {'User': 'RiittaAK', 'followers': 639},
#  {'User': 'rwforest', 'followers': 1183},
#  {'User': 'ua_ahpcc', 'followers': 132},
#  {'User': 'DP_JEDI', 'followers': 302},
#  {'User': 'BioPolyMet', 'followers': 126},
#  {'User': 'evilanova', 'followers': 1044},
#  {'User': 'HWWPotts', 'followers': 1322},
#  {'User': 'SRMA_SIG', 'followers': 499},
#  {'User': 'justjossn', 'followers': 212},
#  {'User': 'Chris_Bell_TO', 'followers': 163},
#  {'User': 'cmaconthehill', 'followers': 0},
#  {'User': 'glen_mcgregor', 'followers': 0},
#  {'User': 'OSCGalway', 'followers': 371},
#  {'User': 'rtArtBoost', 'followers': 2354},
#  {'User': '100DaysOfWriter', 'followers': 1577},
#  {'User': 'jennydavison_', 'followers': 144},
#  {'User': 'islandmageeps', 'followers': 0},
#  {'User': 'HannahBrown290', 'followers': 22},
#  {'User': 'CornubiaGeol', 'followers': 3057},
#  {'User': 'LabsCatsHorses', 'followers': 98},
#  {'User': 'jillfnugent', 'followers': 4972},
#  {'User': 'I_Y_S', 'followers': 521},
#  {'User': 'seanrussell311', 'followers': 140},
#  {'User': 'martinnorgaard_', 'followers': 132},
#  {'User': 'nnlmregion4', 'followers': 406},
#  {'User': 'akritiko', 'followers': 1771},
#  {'User': 'Sandbird_', 'followers': 793},
#  {'User': 'TinaTs2', 'followers': 1462},
#  {'User': 'TheodoreLytras', 'followers': 0},
#  {'User': 'NyrrosC', 'followers': 0},
#  {'User': 'stel67pi', 'followers': 0},
#  {'User': 'iMEdDLab', 'followers': 0},
#  {'User': 'tsadilas_g', 'followers': 0},
#  {'User': 'HelenMartiroso1', 'followers': 0},
#  {'User': 'RussoMaryj', 'followers': 49},
#  {'User': 'nihil_enigma', 'followers': 23},
#  {'User': 'AsbeAtash45', 'followers': 3834},
#  {'User': 'dededawson', 'followers': 714},
#  {'User': 'theAGU', 'followers': 76059},
#  {'User': 'ThrivingEarth', 'followers': 2031},
#  {'User': 'WisCounties', 'followers': 0},
#  {'User': 'LeagueWIMunis', 'followers': 0},
#  {'User': 'STSCH_', 'followers': 884},
#  {'User': 'fevasqueznm', 'followers': 3274},
#  {'User': 'jacintodavila', 'followers': 1504},
#  {'User': 'AndreRovai', 'followers': 337},
#  {'User': 'victorysunday2k', 'followers': 367},
#  {'User': 'WomenCodersBot', 'followers': 6974},
#  {'User': 'DisscoFlanders', 'followers': 43},
#  {'User': 'insanedevbot', 'followers': 316},
#  {'User': 'arv_bot_', 'followers': 47},
#  {'User': 'SchmuckiReto', 'followers': 307},
#  {'User': 'marina_arbetman', 'followers': 201},
#  {'User': 'CaroMorales_eco', 'followers': 0},
#  {'User': 'CONICETDialoga', 'followers': 0},
#  {'User': 'art_DJsmiles', 'followers': 2053},
#  {'User': 'crowdsourcingfn', 'followers': 352},
#  {'User': 'TheCuriousLuke', 'followers': 6887},
#  {'User': 'Sheldrake', 'followers': 4961},
#  {'User': 'yoyehudi', 'followers': 2622},
#  {'User': 'BS_ScalesPhD', 'followers': 49},
#  {'User': 'DNARNADan', 'followers': 966},
#  {'User': 'IZWE_DRONES', 'followers': 4},
#  {'User': 'DebrisTracker', 'followers': 6029},
#  {'User': 'sciencewiscedu', 'followers': 0},
#  {'User': 'UWMadGSEd', 'followers': 0},
#  {'User': 'sclehdorn', 'followers': 776},
#  {'User': 'vijesti_tv', 'followers': 79},
#  {'User': 'PalMaurovich', 'followers': 578},
#  {'User': 'ArimaGenomics', 'followers': 1013},
#  {'User': 'ArleneLop', 'followers': 112},
#  {'User': 'ckrabb', 'followers': 588},
#  {'User': 'OtautauT', 'followers': 2925},
#  {'User': 'juliesquid', 'followers': 4872},
#  {'User': 'DiederikStrubbe', 'followers': 454},
#  {'User': 'JR48237144', 'followers': 258},
#  {'User': 'ESAEcology', 'followers': 11414},
#  {'User': 'figshare', 'followers': 0},
#  {'User': 'GlacierNPS', 'followers': 0},
#  {'User': 'NIEHS_PEPH', 'followers': 1452},
#  {'User': 'nihseed', 'followers': 0},
#  {'User': 'Stephen_Curry', 'followers': 21444},
#  {'User': 'lmb_berlin', 'followers': 1818},
#  {'User': 'TheRarestDao', 'followers': 300},
#  {'User': 'ResearchHub', 'followers': 3266},
#  {'User': 'ConstitutionDAO', 'followers': 0},
#  {'User': 'SwartzDAO', 'followers': 0},
#  {'User': 'RunningCardinal', 'followers': 671},
#  {'User': 'austoniatweets', 'followers': 41330},
#  {'User': 'jordanmansell4', 'followers': 171},
#  {'User': 'debbierachlis', 'followers': 1909},
#  {'User': 'iangoldmansa', 'followers': 2219},
#  {'User': 'GirlsWhoCodeBot', 'followers': 63},
#  {'User': 'avnishnanda', 'followers': 7120},
#  {'User': 'biologyFran', 'followers': 1488},
#  {'User': 'cvila_museum', 'followers': 2254},
#  {'User': 'Betty_Luwa25', 'followers': 4},
#  {'User': 'samyar45472518', 'followers': 1864},
#  {'User': 'belspo', 'followers': 2324},
#  {'User': 'naturejule', 'followers': 169},
#  {'User': 'BzGEO', 'followers': 7400},
#  {'User': 'connector_erin', 'followers': 1737},
#  {'User': 'NASAEarthData', 'followers': 31923},
#  {'User': 'EmmaN11xx', 'followers': 248},
#  {'User': 'dutchangles', 'followers': 0},
#  {'User': '_llebrun', 'followers': 0},
#  {'User': 'LasembraC', 'followers': 323},
#  {'User': 'cairns_na', 'followers': 596},
#  {'User': 'Happe', 'followers': 10},
#  {'User': 'NickBan47647569', 'followers': 145},
#  {'User': 'JamesEarlSchier', 'followers': 152},
#  {'User': 'kendraekaiser', 'followers': 992},
#  {'User': 'LocaLaughs', 'followers': 65},
#  {'User': 'VitalikButerin', 'followers': 0},
#  {'User': 'lexfridman', 'followers': 0},
#  {'User': 'MC_SAPPlings', 'followers': 49},
#  {'User': 'EcoSchools_TW', 'followers': 927},
#  {'User': 'JMBonzom', 'followers': 1152},
#  {'User': 'famartinez2001', 'followers': 8253},
#  {'User': 'KaptivateGroup', 'followers': 451},
#  {'User': 'EvoMRI', 'followers': 4628},
#  {'User': 'NeftalyCM', 'followers': 1402},
#  {'User': 'cobrafinch', 'followers': 72},
#  {'User': 'LorienneW', 'followers': 170},
#  {'User': 'WoodlandTrust', 'followers': 264241},
#  {'User': 'EOchatBot', 'followers': 621},
#  {'User': '4BnEyVphNSnaOZf', 'followers': 272},
#  {'User': 'mvugt', 'followers': 2781},
#  {'User': 'pipsterb', 'followers': 2781},
#  {'User': 'Phenoweb_Scot', 'followers': 523},
#  {'User': 'mirembemabel2', 'followers': 17},
#  {'User': 'BrookieMcG', 'followers': 269},
#  {'User': 'dominicdeecoco', 'followers': 446},
#  {'User': 'nmzumpano', 'followers': 3603},
#  {'User': 'doutorleonardo', 'followers': 732},
#  {'User': 'LauraMKoenig', 'followers': 3242},
#  {'User': 'KatharinaWeiss_', 'followers': 27},
#  {'User': 'unibt', 'followers': 0},
#  {'User': 'fMRI_guy', 'followers': 16405},
#  {'User': 'quinnslayton', 'followers': 168},
#  {'User': 'DisturbedDendro', 'followers': 1851},
#  {'User': 'OfficeofEdTech', 'followers': 144267},
#  {'User': 'SCienceSophs', 'followers': 1898},
#  {'User': 'wisskomm', 'followers': 866},
#  {'User': 'ricecakebb', 'followers': 117},
#  {'User': 'lupitamiamour', 'followers': 739},
#  {'User': 'cadj0506', 'followers': 37},
#  {'User': 'OfficialDLDay', 'followers': 24336},
#  {'User': 'talithamuusse', 'followers': 0},
#  {'User': 'EU_Startups', 'followers': 0},
#  {'User': 'FinnovaEU', 'followers': 0},
#  {'User': 'ealmirall', 'followers': 0},
#  {'User': 'mem_somerville', 'followers': 6349},
#  {'User': 'BostonGlobe', 'followers': 0},
#  {'User': 'cai2r', 'followers': 1076},
#  {'User': 'HBSmktg', 'followers': 0},
#  {'User': 'trikosh', 'followers': 0},
#  {'User': 'elleallever', 'followers': 345},
#  {'User': 'ausbutterflies', 'followers': 0},
#  {'User': 'savebutterflies', 'followers': 0},
#  {'User': 'Kyukimasa', 'followers': 0},
#  {'User': 'PaquitoBernard', 'followers': 756},
#  {'User': 'dagendresen', 'followers': 572},
#  {'User': 'LizDolphinfluff', 'followers': 2802},
#  {'User': 'MMxCommunity', 'followers': 656},
#  {'User': 'Boavista_Ludwig', 'followers': 899},
#  {'User': 'GBIF', 'followers': 11963},
#  {'User': 'CraigCorbet', 'followers': 106},
#  {'User': 'designcrowdfun1', 'followers': 402},
#  {'User': 'SumeyyeEtlec', 'followers': 42},
#  {'User': 'BioGeoMacro', 'followers': 1718},
#  {'User': 'BadRitalin', 'followers': 20},
#  {'User': 'Josemalucenas', 'followers': 69},
#  {'User': 'BioGeoKreft', 'followers': 1690},
#  {'User': 'BiotecnologiaF', 'followers': 908},
#  {'User': 'DianeG83034940', 'followers': 1002},
#  {'User': 'prutter_pat', 'followers': 589},
#  {'User': 'MyPawsGo', 'followers': 1407},
#  {'User': 'ankostis', 'followers': 815},
#  {'User': 'anaritagsimoes', 'followers': 838},
#  {'User': 'thisburie', 'followers': 1104},
#  {'User': 'TrickyHannigram', 'followers': 0},
#  {'User': 'msandstr', 'followers': 1907},
#  {'User': 'firstsmurfmama', 'followers': 196},
#  {'User': 'CourtneyOnstad', 'followers': 425},
#  {'User': 'environmentca', 'followers': 425298},
#  {'User': 'CoCoRaHSCanada', 'followers': 0},
#  {'User': 'bitcoinagile', 'followers': 64769},
#  {'User': 'zsi_fe', 'followers': 1453},
#  {'User': 'NZScienceLearn', 'followers': 8568},
#  {'User': 'NZGetReady', 'followers': 0},
#  {'User': 'NZScienceTeachr', 'followers': 0},
#  {'User': 'EducationGovtNZ', 'followers': 0},
#  {'User': 'EQCNZ', 'followers': 0},
#  {'User': 'BioFascinates', 'followers': 183},
#  {'User': 'paul_offa', 'followers': 156},
#  {'User': 'suhas_prameela', 'followers': 1937},
#  {'User': '_evso', 'followers': 5901},
#  {'User': 'NasDaddy2', 'followers': 31},
#  {'User': 'Lidy_Monteiro', 'followers': 2069},
#  {'User': 'RodAG_', 'followers': 1213},
#  {'User': 'Chaaootic', 'followers': 680},
#  {'User': 'BrandonVolosen', 'followers': 68},
#  {'User': 'antonsantos00', 'followers': 137},
#  {'User': 'gawbul', 'followers': 4217},
#  {'User': 'DonaldVinh', 'followers': 4150},
#  {'User': 'IPKW_univie', 'followers': 765},
#  {'User': 'AthinaZampara', 'followers': 3332},
#  {'User': 'kennedytcooper', 'followers': 7819},
#  {'User': 'queiruga', 'followers': 2071},
#  {'User': 'Erst_Officer', 'followers': 1524},
#  {'User': 'nataliamanola', 'followers': 441},
#  {'User': 'MVFoundation', 'followers': 0},
#  {'User': 'heallinkgr', 'followers': 0},
#  {'User': 'GSRT_GR', 'followers': 0},
#  {'User': 'krisvdam', 'followers': 1298},
#  {'User': 'amai', 'followers': 0},
#  {'User': 'mopenshaw', 'followers': 1682},
#  {'User': 'DavidAnber', 'followers': 0},
#  {'User': 'mkhammer', 'followers': 0},
#  {'User': 'Newsweek', 'followers': 0},
#  {'User': 'InCollaboratory', 'followers': 42},
#  {'User': 'lisafeldstein', 'followers': 2524},
#  {'User': 'Anu_L_Goswami', 'followers': 250},
#  {'User': 'AlanSheehan18', 'followers': 4},
#  {'User': 'RedBird725', 'followers': 47},
#  {'User': 'NeuroGem', 'followers': 979},
#  {'User': 'ClementDelangue', 'followers': 15987},
#  {'User': 'MSFTResearch', 'followers': 0},
#  {'User': 'GoogleAI', 'followers': 0},
#  {'User': 'nvidia', 'followers': 0},
#  {'User': 'OpenAI', 'followers': 0},
#  {'User': 'BigscienceW', 'followers': 4284},
#  {'User': 'stefan_it_', 'followers': 393},
#  {'User': 'Nils_Reimers', 'followers': 3401},
#  {'User': 'Bindikannan963', 'followers': 868},
#  {'User': 'betatrash', 'followers': 0},
#  {'User': 'Mrs_Delecto', 'followers': 8077},
#  {'User': 'tmoreperez', 'followers': 724},
#  {'User': 'DylanWRE', 'followers': 481},
#  {'User': 'noehernandezcor', 'followers': 2978},
#  {'User': 'SiccodeKnecht', 'followers': 3125},
#  {'User': 'TheZachMueller', 'followers': 5237},
#  {'User': 'sab_original', 'followers': 1327},
#  {'User': 'AusElectoralCom', 'followers': 34301},
#  {'User': 'SAElectoralCom', 'followers': 884},
#  {'User': 'MorrienElly', 'followers': 1635},
#  {'User': 'robbo_1962', 'followers': 1363},
#  {'User': 'Lilaceve666', 'followers': 0},
#  {'User': 'BurntTo63443766', 'followers': 1036},
#  {'User': 'StasBekman', 'followers': 2023},
#  {'User': 'HazelHenri', 'followers': 305},
#  {'User': 'scossfunding', 'followers': 695}]

# %% [markdown]
# #### 8. Get the 20 users with most followers in descending order

# %%
query = f"match (users:{l_user}) return users.{p_user[0]} as user, users.{p_user[1]} as followers order by followers descending limit 20"
pprint(graph.execute(query).data())
# Out:
# [{'followers': 17519323, 'user': 'Forbes'},
#  {'followers': 15630637, 'user': 'AP'},
#  {'followers': 4897983, 'user': 'coinbase'},
#  {'followers': 4286962, 'user': 'marcorubio'},
#  {'followers': 3048702, 'user': 'NWS'},
#  {'followers': 2940260, 'user': 'verge'},
#  {'followers': 1882525, 'user': 'britishlibrary'},
#  {'followers': 1751550, 'user': 'BoredElonMusk'},
#  {'followers': 1333989, 'user': 'TheRickWilson'},
#  {'followers': 1262006, 'user': 'zeerajasthan_'},
#  {'followers': 1227496, 'user': 'NSF'},
#  {'followers': 1027275, 'user': 'deray'},
#  {'followers': 893280, 'user': 'thidakarn'},
#  {'followers': 802165, 'user': 'NASAGoddard'},
#  {'followers': 784534, 'user': 'campbellclaret'},
#  {'followers': 763029, 'user': 'NASAJuno'},
#  {'followers': 744498, 'user': 'NASASun'},
#  {'followers': 721944, 'user': 'UNESCOarabic'},
#  {'followers': 643790, 'user': 'nrc'},
#  {'followers': 636812, 'user': 'BMWUSA'}]

# %% [markdown]
# #### 9. Get the number of tweets & retweets per hour

# %%
#A function used to convert the output duration from the cypher query into hours:
def duration_in_hours(duration):
    # Unit-based form: P[nY][nM][nW][nD][T[nH][nM][nS]]   (P is prefix for duration)
    years=months=weeks=days=hours=minutes=seconds = 0
    duration=str(duration)
    if "T" in duration:
        x,y = duration.split("T",1)
    else:
        x = str(duration)
    _,x = x.split("P",1)
    if 'Y' in x:
        years,x = x.split("Y",1)
    if 'M' in x:
        months,x = x.split("M",1)
    if 'W' in x:
        weeks,x = x.split("W",1)
    if 'D' in x:
        days,x = x.split("D",1)

    if y:
        if 'H' in y:
            hours,y = (y.split("H",1))
        if 'M' in y:
            minutes,y = (y.split("M",1))
        if 'S' in y:
            seconds,y = (y.split("S",1))
    if int(minutes) > 30:
        return (int(years)*8760) + (int(months)*730) + (int(weeks)*168) + (int(days)*24)  + int(hours) + 1
    else:
        return (int(years)*8760) + (int(months)*730) + (int(weeks)*168) + (int(days)*24) + int(hours)

#Calculate tweets per hour :
tweet_result = graph.execute(f"MATCH ()-[r:{r_tweeted}]->() RETURN distinct count(r) as tweets").data()
for row in tweet_result:
    tweets = row["tweets"]
tweet_result = graph.execute(f"MATCH (:{l_user})-[r:{r_tweeted}]->() RETURN min(toInteger(r.timestamp)) as min, max(toInteger(r.timestamp)) as max").data()
for row in tweet_result:
    min_date = datetime.strptime(str(row["min"]),"%Y%m%d%H%M%S").strftime("%Y-%m-%dT%H:%M:%S.000")
    max_date = datetime.strptime(str(row["max"]),"%Y%m%d%H%M%S").strftime("%Y-%m-%dT%H:%M:%S.000")
tweet_result = graph.execute(f"UNWIND [ duration.inSeconds(localdatetime('{min_date}'), localdatetime('{max_date}')) ] AS aDuration RETURN aDuration")
for row in tweet_result:
    duration=row["aDuration"]
hours = duration_in_hours(duration)
tweets_per_hour = tweets / hours
print("Tweets per hour: ", tweets_per_hour)

#Calculate retweets per hour :
retweet_result = graph.execute(f"MATCH ()-[r:{r_retweeted}]->() RETURN distinct count(r) as retweets").data()
for row in retweet_result:
    retweets = row["retweets"]
retweet_result = graph.execute(f"MATCH (:{l_user})-[r:{r_retweeted}]->(:{l_tweet}) RETURN min(toInteger(r.timestamp)) as min, max(toInteger(r.timestamp)) as max").data()
for row in retweet_result:
    min_date = datetime.strptime(str(row["min"]),"%Y%m%d%H%M%S").strftime("%Y-%m-%dT%H:%M:%S.000")
    max_date = datetime.strptime(str(row["max"]),"%Y%m%d%H%M%S").strftime("%Y-%m-%dT%H:%M:%S.000")
retweet_result = graph.execute(f"UNWIND [ duration.inSeconds(localdatetime('{min_date}'), localdatetime('{max_date}')) ] AS aDuration RETURN aDuration")
for row in retweet_result:
    duration=row["aDuration"]
hours = duration_in_hours(duration)
retweets_per_hour = retweets / hours
print("Retweets per hour: ", retweets_per_hour)
# Out:
# Tweets per hour:  0.23174306051575083
# Retweets per hour:  58.436619718309856

# %% [markdown]
# #### 10. Get the hour with the most tweets and retweets

# %%
min = datetime.strptime("000000","%H%M%S")
max = datetime.strptime("235959","%H%M%S")
results = []
while min <= max:
    prevHour = min.strftime("%H0000")
    min += timedelta(hours=1) #Next hour
    currentHour = min.strftime("%H0000")
    results.append({
        'hour':prevHour[:2] + "-" + currentHour[:2],
        'tweets':graph.execute(f"match (:user)-[relationships]->(:tweet) where substring(relationships.timestamp,8,6) >= '{prevHour}' and substring(relationships.timestamp,8,6) <= '{currentHour}' return count(relationships) as c").data()[0]["c"]
        })
pprint(results)
popularHour = 0
mostTweetsPerHour = 0
for item in results:
    if mostTweetsPerHour < item["tweets"]:
        mostTweetsPerHour = item["tweets"]
        popularHour = item["hour"]
print(f"\nHour with most tweets & retweets : {popularHour}")
# Out:
# [{'hour': '00-01', 'tweets': 765},
#  {'hour': '01-02', 'tweets': 749},
#  {'hour': '02-03', 'tweets': 807},
#  {'hour': '03-04', 'tweets': 809},
#  {'hour': '04-05', 'tweets': 1005},
#  {'hour': '05-06', 'tweets': 828},
#  {'hour': '06-07', 'tweets': 880},
#  {'hour': '07-08', 'tweets': 1151},
#  {'hour': '08-09', 'tweets': 1441},
#  {'hour': '09-10', 'tweets': 1632},
#  {'hour': '10-11', 'tweets': 1531},
#  {'hour': '11-12', 'tweets': 1455},
#  {'hour': '12-13', 'tweets': 1422},
#  {'hour': '13-14', 'tweets': 1520},
#  {'hour': '14-15', 'tweets': 1710},
#  {'hour': '15-16', 'tweets': 1669},
#  {'hour': '16-17', 'tweets': 1777},
#  {'hour': '17-18', 'tweets': 1755},
#  {'hour': '18-19', 'tweets': 1478},
#  {'hour': '19-20', 'tweets': 1445},
#  {'hour': '20-21', 'tweets': 1318},
#  {'hour': '21-22', 'tweets': 1076},
#  {'hour': '22-23', 'tweets': 1098},
#  {'hour': '23-00', 'tweets': 0}]
#
# Hour with most tweets & retweets : 16-17

# %% [markdown]
# #### 11. Get the device that most users are tweeting from (top 5 devices)

# %%
query = f"match (:{l_user})-[tweeted]->(:{l_tweet}) return distinct tweeted.source as device, count(tweeted.source) as times_used order by times_used descending limit 5"
pprint(graph.execute(query).data())
# Out:
# [{'device': 'Twitter Web App', 'times_used': 9508},
#  {'device': 'Twitter for Android', 'times_used': 5975},
#  {'device': 'Twitter for iPhone', 'times_used': 5962},
#  {'device': 'OpenSciTalk', 'times_used': 1852},
#  {'device': 'TweetDeck', 'times_used': 841}]

# %% [markdown]
# #### 12. Get the users, in descending order, that have been mentioned the most

# %%
results = graph.execute(f"MATCH ()-[r:{r_mentioned}]->(u:{l_user})  RETURN u.screen_name as user, count(r) as mentions ORDER BY count(r) DESC limit 20").data()
pprint(results)
# Out:
# [{'mentions': 257, 'user': 'SB19Official'},
#  {'mentions': 217, 'user': 'TheRickWilson'},
#  {'mentions': 116, 'user': 'doctorow'},
#  {'mentions': 116, 'user': 'zittrain'},
#  {'mentions': 110, 'user': 'CitSciOZ'},
#  {'mentions': 96, 'user': 'PFTCourses'},
#  {'mentions': 95, 'user': 'raspishake'},
#  {'mentions': 79, 'user': 'NIH'},
#  {'mentions': 75, 'user': 'FORRTproject'},
#  {'mentions': 70, 'user': 'inaturalist'},
#  {'mentions': 68, 'user': 'OPERASEU'},
#  {'mentions': 68, 'user': 'Flavio_Azevedo_'},
#  {'mentions': 67, 'user': 'cOAlitionS_OA'},
#  {'mentions': 64, 'user': 'AGUecohydro'},
#  {'mentions': 64, 'user': 'LandonMarston'},
#  {'mentions': 61, 'user': 'UniLeipzig'},
#  {'mentions': 61, 'user': 'SueReviews'},
#  {'mentions': 61, 'user': 'AutismINSAR'},
#  {'mentions': 59, 'user': 'AvHStiftung'},
#  {'mentions': 58, 'user': 'ScienceEurope'}]

# %% [markdown]
# #### 13. Get the most active users (users that have posted most tweets)

# %%
results = graph.execute(f"MATCH (u:{l_user})-[r:{r_tweeted}]-() RETURN count(r) as tweets , u.screen_name as user order by count(r) DESC limit 20").data()
pprint(results)
# Out:
# [{'tweets': 698, 'user': 'Aalst_Waalre'},
#  {'tweets': 101, 'user': 'RobotRrid'},
#  {'tweets': 98, 'user': 'OpenSci_News'},
#  {'tweets': 90, 'user': 'raspishakEQ'},
#  {'tweets': 66, 'user': 'Primary_Immune'},
#  {'tweets': 65, 'user': 'DG_Rand'},
#  {'tweets': 42, 'user': 'moneynetlink'},
#  {'tweets': 38, 'user': 'DocCrenau'},
#  {'tweets': 33, 'user': 'egonwillighagen'},
#  {'tweets': 32, 'user': 'AlanSheehan18'},
#  {'tweets': 32, 'user': 'citizenskies'},
#  {'tweets': 30, 'user': 'HeidiProject'},
#  {'tweets': 30, 'user': 'MDDelahunty'},
#  {'tweets': 28, 'user': 'for_designer'},
#  {'tweets': 28, 'user': 'CreativeSage'},
#  {'tweets': 22, 'user': 'Treadstone71LLC'},
#  {'tweets': 22, 'user': 'pivottwistdev'},
#  {'tweets': 22, 'user': 'CitieSHealthEU'},
#  {'tweets': 21, 'user': 'BitcoinORama'},
#  {'tweets': 21, 'user': 'fdmhildesheim'}]

# %% [markdown]
# #### 14. Get the top 20 tweets that has been retweeted the most and the persons that posted them

# %%
query = f"match (tweet:{l_tweet})<-[:{r_tweeted}]-(users:{l_user}) return distinct tweet.id as tweet_id, users.{p_user[0]} as user,size((tweet)<-[:{r_retweeted}]-()) as times_retweeted order by times_retweeted descending limit 20"
pprint(graph.execute(query).data())
# Out:
# [{'times_retweeted': 934,
#   'tweet_id': '1499064794829131779',
#   'user': 'PigsAndPlans'},
#  {'times_retweeted': 428, 'tweet_id': '1499959375536001025', 'user': 'AP'},
#  {'times_retweeted': 252,
#   'tweet_id': '1500684178114760706',
#   'user': 'acetwtts'},
#  {'times_retweeted': 243,
#   'tweet_id': '1499579773382967296',
#   'user': 'commissionsbyk'},
#  {'times_retweeted': 212,
#   'tweet_id': '1307603562206244864',
#   'user': 'nairaworkers'},
#  {'times_retweeted': 203,
#   'tweet_id': '1497580495533711362',
#   'user': 'paulUKcoder'},
#  {'times_retweeted': 200,
#   'tweet_id': '1303357058134278146',
#   'user': 'nairaworkers'},
#  {'times_retweeted': 191,
#   'tweet_id': '1497647768109830146',
#   'user': 'JasonPLowery'},
#  {'times_retweeted': 162,
#   'tweet_id': '1498839559290994695',
#   'user': 'marcorubio'},
#  {'times_retweeted': 118,
#   'tweet_id': '1499421562117709834',
#   'user': 'mcclure111'},
#  {'times_retweeted': 113,
#   'tweet_id': '1497375254313791491',
#   'user': 'fredbenenson'},
#  {'times_retweeted': 105, 'tweet_id': '1496860019857543172', 'user': 'sharoz'},
#  {'times_retweeted': 98,
#   'tweet_id': '1497600362118893572',
#   'user': 'ChardineTaylor'},
#  {'times_retweeted': 94,
#   'tweet_id': '1496112618213621760',
#   'user': 'bjenquist'},
#  {'times_retweeted': 77,
#   'tweet_id': '1497644861733941250',
#   'user': 'DAlperovitch'},
#  {'times_retweeted': 67,
#   'tweet_id': '1497780257046204424',
#   'user': 'Cheng_yi_Huang'},
#  {'times_retweeted': 64,
#   'tweet_id': '1495800733886660608',
#   'user': 'ZipperSam'},
#  {'times_retweeted': 63, 'tweet_id': '1499895088297746439', 'user': 'fbajak'},
#  {'times_retweeted': 60,
#   'tweet_id': '1500797338381656065',
#   'user': 'CManningPhD'},
#  {'times_retweeted': 57,
#   'tweet_id': '1498215413456510976',
#   'user': 'Rsc4Earth'}]

# %% [markdown]
# #### 15.Get the top-20 hashtags that co-occur with the hashtag that has been used the most

# %%
most_popular = graph.execute(f"MATCH ()-[r:{r_used_hashtag}]->(h:{l_hashtag}) RETURN h.text AS most_popular, count(r) order by count(r) DESC LIMIT 1").data()[0]['most_popular']
results = graph.execute(f'''MATCH (t:{l_tweet})-[r:{r_has_hashtag}]->(h:{l_hashtag})
                            WHERE EXISTS{{
                                MATCH (t)-[r2:{r_has_hashtag}]->(h2:{l_hashtag})
                                WHERE h2.text = '{most_popular}' }}
                            AND h.text <> '{most_popular}'
                            RETURN h.text as hashtag, count(r) as count
                            order by count desc LIMIT 20''').data()
print(f"Most used hashtag : {most_popular}")
pprint(results)
# Out:
# Most used hashtag : openscience
# [{'count': 305, 'hashtag': 'openaccess'},
#  {'count': 145, 'hashtag': 'opendata'},
#  {'count': 137, 'hashtag': 'scicomm'},
#  {'count': 101, 'hashtag': 'opensource'},
#  {'count': 96, 'hashtag': 'datascience'},
#  {'count': 93, 'hashtag': 'bigdata'},
#  {'count': 79, 'hashtag': 'bioinformatics'},
#  {'count': 67, 'hashtag': 'python'},
#  {'count': 63, 'hashtag': 'genomics'},
#  {'count': 60, 'hashtag': '100daysofcode'},
#  {'count': 60, 'hashtag': 'research'},
#  {'count': 51, 'hashtag': 'rstats'},
#  {'count': 49, 'hashtag': 'coding'},
#  {'count': 48, 'hashtag': 'machinelearning'},
#  {'count': 46, 'hashtag': 'covid19'},
#  {'count': 45, 'hashtag': 'immunology'},
#  {'count': 45, 'hashtag': 'serverless'},
#  {'count': 41, 'hashtag': 'fairdata'},
#  {'count': 39, 'hashtag': 'linux'},
#  {'count': 39, 'hashtag': 'citizenscience'}]

# %% [markdown]
# #### 16. Get the most “important” user in the dataset (use Graph algorithms: Pagerank, Betweenness centrality, etc. ). You will apply these algorithms in the mention network (which includes retweets)

# %%
userMentionsGraphExists = graph.execute(f"call gds.graph.exists('userMentionsGraph') yield graphName, exists return exists").data()[0]["exists"]
if userMentionsGraphExists:
    graph.execute(f"call gds.graph.drop('userMentionsGraph') YIELD graphName")
#Give a weight on each user -> user relationship depending on their follower count:
maxFollowersValue = graph.execute(f"match (users:{l_user}) RETURN max(users.{p_user[1]}) as max").data()[0]['max']              #Get the max value to normalize the weight between 0 and 1
graph.execute(f"match (:{l_user})-[r:{r_mentioned}]->(users:{l_user}) SET r.weight = (users.{p_user[1]} * 1.0 + 0.1) / {maxFollowersValue}")  #Set the weight to relationship

#If user userMentionsGraph graph is not stored in the catalog, create it:
graph.execute(f"call gds.graph.create('userMentionsGraph','{l_user}','{r_mentioned}',{{nodeProperties: '{p_user[1]}',relationshipProperties:'weight'}})")
#Get important users with PageRank:
importantUsers = graph.execute(f'''CALL gds.pageRank.stream('userMentionsGraph', {{ relationshipWeightProperty: 'weight' }})
                                    YIELD nodeId, score
                                    RETURN gds.util.asNode(nodeId).{p_user[0]} AS user, score
                                    ORDER BY score DESC, user ASC limit 5''').data()
print("Most important user: " + importantUsers[0]['user'])
print("Top 5 users:")
pprint([usr['user'] for usr in importantUsers])
# Out:
# Most important user: inaturalist
# Top 5 users:
# ['inaturalist', 'doctorow', 'SueReviews', 'WHCEQ', 'PLOSONE']

# %% [markdown]
# #### 17. For the 5th most important user, get the list of hashtags and URLs that have been posted

# %%
if not 'importantUsers' in vars():
    raise Exception("Execute the answer to question 16 first to get the most important users")
selectedUser = importantUsers[4]["user"] #Get 5th most important user
results = graph.execute(f"match (user:{l_user})-[r]->(nodes) where (nodes:{l_hashtag} or nodes:{l_url}) and user.{p_user[0]} = '{selectedUser}' return  nodes.text as hashtag, nodes.url as url").data()
print(f"5th Most important user:\n{selectedUser}")
print("Hashtags used:")
pprint([r['hashtag'] for r in results if r['hashtag'] != None ])
print("Urls used:")
pprint([r['url'] for r in results if r['url'] != None ])
# Out:
# 5th Most important user:
# PLOSONE
# Hashtags used:
# ['openscience']
# Urls used:
# []

# %% [markdown]
# #### 18. Get the users that post tweets with hashtags most similar to those used by the most important user

# %%
if not 'importantUsers' in vars():
    raise Exception("Execute the answer to question 16 first to get the most important users")
hashtags = []
user = []
selectedUser = importantUsers[0]['user']
result = graph.execute(f"MATCH (u:{l_user})-[r:{r_used_hashtag}]->(h:{l_hashtag}) where u.{p_user[0]} = '{selectedUser}' return h.text as hashtag")
for row in result:
    hashtags.append(row["hashtag"])
    #get users that used most the most similar hashtags (but not the same) with most important user
    for hashtag in hashtags:
        result = graph.execute(f'''MATCH (u)-[r:{r_used_hashtag}]->(h:{l_hashtag})
                                    with apoc.text.sorensenDiceSimilarity('{hashtag}', h.text) as similarity, u.{p_user[0]} as screen_name, h.text as hashtag
                                    where similarity > 0.8 and similarity <> 1
                                    return screen_name, hashtag, similarity LIMIT 5''')
        for row in result:
            user.append([row["screen_name"],row["hashtag"],hashtag,row["similarity"]])
user.sort(key=lambda x: x[2], reverse=True)
user.insert(0,['User','Hashtag','Hashtag used by important user','Similarity'])
pprint(user)
# Out:
# [['User', 'Hashtag', 'Hashtag used by important user', 'Similarity'],
#  ['KeithPiccard', 'scienceed', 'science', 0.8571428571428571],
#  ['nettie087', 'sciences', 'science', 0.9230769230769231],
#  ['OpenSciTalk', 'sciences', 'science', 0.9230769230769231],
#  ['amarois', 'sciences', 'science', 0.9230769230769231],
#  ['oxygenases', 'myscience', 'science', 0.8571428571428571],
#  ['CitSciOZ', 'citizensciencekits', 'citizenscience', 0.8666666666666667],
#  ['CitSciWA', 'citizensciencekits', 'citizenscience', 0.8666666666666667],
#  ['SciStarter', 'citizensciencekits', 'citizenscience', 0.8666666666666667],
#  ['GrundyLibrary', 'citizensciencekits', 'citizenscience', 0.8666666666666667],
#  ['citnatchallenge', 'citizenscienceforall', 'citizenscience', 0.8125],
#  ['CitSciOZ', 'citizensciencekits', 'citizenscience', 0.8666666666666667],
#  ['CitSciWA', 'citizensciencekits', 'citizenscience', 0.8666666666666667],
#  ['SciStarter', 'citizensciencekits', 'citizenscience', 0.8666666666666667],
#  ['GrundyLibrary', 'citizensciencekits', 'citizenscience', 0.8666666666666667],
#  ['citnatchallenge', 'citizenscienceforall', 'citizenscience', 0.8125],
#  ['kyliesoanes', 'urbanbiodiversity', 'biodiversity', 0.8148148148148148],
#  ['nettie087', 'bibliodiversity', 'biodiversity', 0.88],
#  ['_open_science_', 'bibliodiversity', 'biodiversity', 0.88],
#  ['OpenSciTalk', 'bibliodiversity', 'biodiversity', 0.88],
#  ['ChristopheDony', 'bibliodiversity', 'biodiversity', 0.88],
#  ['kyliesoanes', 'urbanbiodiversity', 'biodiversity', 0.8148148148148148],
#  ['nettie087', 'bibliodiversity', 'biodiversity', 0.88],
#  ['_open_science_', 'bibliodiversity', 'biodiversity', 0.88],
#  ['OpenSciTalk', 'bibliodiversity', 'biodiversity', 0.88],
#  ['ChristopheDony', 'bibliodiversity', 'biodiversity', 0.88],
#  ['kyliesoanes', 'urbanbiodiversity', 'biodiversity', 0.8148148148148148],
#  ['nettie087', 'bibliodiversity', 'biodiversity', 0.88],
#  ['_open_science_', 'bibliodiversity', 'biodiversity', 0.88],
#  ['OpenSciTalk', 'bibliodiversity', 'biodiversity', 0.88],
#  ['ChristopheDony', 'bibliodiversity', 'biodiversity', 0.88]]

# %% [markdown]
# #### 19. Get the user communities that have been created based on the users’ interactions and visualise them (Louvain algorithm)

# %%
userMentionsGraphExists = graph.execute(f"call gds.graph.exists('GraphforLouvain') yield graphName, exists return exists").data()[0]["exists"]
if userMentionsGraphExists:
    graph.execute(f"call gds.graph.drop('GraphforLouvain') YIELD graphName")

#If user userMentionsGraph graph is not stored in the catalog, create it:
graph.execute(f"call gds.graph.create('GraphforLouvain','{l_user}',{{{r_mentioned}:{{orientation: 'UNDIRECTED'}}}},{{ nodeProperties: 'followers_count' }})")
graph.execute(f'''call gds.louvain.write('GraphforLouvain', {{writeProperty: 'community'}})''')
communities = graph.execute(f"match (users:{l_user}) return users.community as communityID, users.screen_name as user order by communityID").data()
communitiesCount = graph.execute(f"match (users:{l_user}) return count(distinct users.community) as communityCount").data()[0]['communityCount']
communitiesWithMoreThanOneUser = graph.execute(f"match (users:{l_user})-[:{r_mentioned}]-(:{l_user}) return count(distinct users.community) as communitiesWithMoreThanOneUser").data()[0]['communitiesWithMoreThanOneUser']
#Group results by communityID:
results = {}
for community in communities:
    if community['communityID'] not in results:
        results[community['communityID']] = []
    # Add users to their community id:
    results[community['communityID']].append(community['user'])
print("To visualize the communities graph, execute the query bellow in Neo4J Browser (single user groups are excluded):")
print("\n-----(Start >)-----")
print(f"match (users:{l_user})-[:{r_mentioned}]-(:{l_user}) return users.community as communityID, users as user order by communityID")
print("-----( < End )-----\n")
print(f"Total number of communities: {communitiesCount}")
print(f"Communities with more than one users: {communitiesWithMoreThanOneUser}")
print("\nAll communities:")
print("{communityID:[users in community]}")
pprint(results)
# Out:
# To visualize the communities graph, execute the query bellow in Neo4J Browser (single user groups are excluded):
#
# -----(Start >)-----
# match (users:user)-[:mentioned]-(:user) return users.community as communityID, users as user order by communityID
# -----( < End )-----
#
# Total number of communities: 10189
# Communities with more than one users: 1111
#
# All communities:
# {communityID:[users in community]}
# {5: ['hebbianloop'],
#  9: ['ChronList'],
#  12: ['realitycrafter'],
#  19: ['mina_radman'],
#  20: ['cgonzagaj'],
#  22: ['Sunny2daySunny', 'Paull2', 'TheRealKeean'],
#  27: ['MarvinSchmittML'],
#  30: ['samuelu15158272'],
#  31: ['surfkt'],
#  33: ['patrickm02L'],
#  34: ['aybajye'],
#  35: ['mikeleiyanke'],
#  38: ['tripl3check', 'fayeflam', 'mosermr'],
#  45: ['YCollaud'],
#  46: ['Jhanne45'],
#  47: ['donatas_s'],
#  52: ['EcuaCorrienteSA'],
#  53: ['kbguzzo'],
#  55: ['jorantes12'],
#  57: ['Ecsa_Enfermeras'],
#  58: ['QilinWang6'],
#  61: ['TangaroaBlue'],
#  62: ['garryd50'],
#  64: ['AnkeMLeitzgen'],
#  65: ['znjrpfelyutkl'],
#  66: ['mecee'],
#  68: ['HardtRosellen'],
#  69: ['WCSDEmpowers', 'WJHS75', 'wjhsmainoffice', 'ABPanzer', 'wjhspta'],
#  74: ['adrianh', 'markdalgarno'],
#  75: ['y2kdetective'],
#  83: ['ok_im_david'],
#  84: ['DrBalch'],
#  86: ['PFHelensburgh'],
#  87: ['ViromeHunter'],
#  90: ['_starbase_'],
#  92: ['MICSproject'],
#  95: ['MilesMolasses', 'dmreyes81', 'vcdgf555'],
#  101: ['urban_plan_b', 'LindaMSee', 'ljcastroc'],
#  103: ['MstrsObserver'],
#  104: ['marcia_petyt'],
#  105: ['MichelTdS'],
#  107: ['RosBeaumont'],
#  109: ['ClareMDaniel'],
#  111: ['CatieGill1'],
#  114: ['LoreyJeanene'],
#  117: ['Hold2LLC'],
#  118: ['Pugelliemann', 'RP131', 'CoulthardGraeme'],
#  120: ['Alejo2000999'],
#  122: ['FORCE11rescomm'],
#  134: ['MuscleSciMegan'],
#  135: ['renmo31193'],
#  137: ['karlaarz'],
#  138: ['GreekGirlsCode'],
#  141: ['RichardBGibson'],
#  144: ['royalty_ukpong'],
#  215: ['Susan29191404'],
#  217: ['kairansasha'],
#  219: ['CharlingtonEc'],
#  220: ['konzidenz'],
#  222: ['ServerlessFan'],
#  225: ['joroach', 'wearebeam'],
#  226: ['KNRXRX'],
#  234: ['AnneRose0'],
#  235: ['AlisonNeri1'],
#  237: ['Passmore_HA'],
#  239: ['lauribe'],
#  242: ['Volker36189870'],
#  244: ['bm_quintela'],
#  247: ['notsofamousray'],
#  253: ['monika76five'],
#  255: ['dude86501502', 'dreamkeeperwolf', 'Pat_Dunn32', 'CBCMeg'],
#  258: ['SwelteringCity'],
#  260: ['muralijnu1'],
#  263: ['RuckCohlchez', 'frowardworm', 'EcoSexuality', 'Russian_Starr'],
#  267: ['Wendy_Bacon'],
#  269: ['misskylie77'],
#  270: ['BBQRich'],
#  271: ['MtHoodFinds'],
#  272: ['PatriciaHaupt4'],
#  273: ['shufunooshigoto'],
#  274: ['lunarwriter75'],
#  275: ['jrjwhite'],
#  277: ['for_designer'],
#  279: ['OlafFub4Prez', 'Buffaloompa', 'HannahBuehler'],
#  283: ['jensclark',
#        'ComedyCentral',
#        'iamjohnoliver',
#        'colbertlateshow',
#        'FallonTonight'],
#  287: ['dykemartens'],
#  288: ['JoyCannabis'],
#  290: ['PsionicPsittacc'],
#  291: ['rainbowcookies_'],
#  293: ['nagi_akira5001', 'apisthoth'],
#  295: ['WWNsoc'],
#  296: ['GEGAlaska'],
#  298: ['xcutiesexyjoy'],
#  300: ['DunkenKBliths'],
#  302: ['marcrjgagnon'],
#  305: ['RoeSroe794120'],
#  306: ['BrilliantAqua'],
#  307: ['shinafelix92'],
#  308: ['StatCan_eng',
#        'BosscatK',
#        'Telefilm_Canada',
#        'CWILLBC',
#        'AskDeepikaAnand',
#        'CanadaCouncil',
#        'WahDeb',
#        'jccordero28'],
#  310: ['1776Fightr'],
#  312: ['Katiescarlet2'],
#  313: ['o_o____o_o'],
#  314: ['JanAldrin55'],
#  317: ['mikekardell'],
#  322: ['clurrrcadet'],
#  323: ['ASHUTOS80668963'],
#  324: ['AmonduulUS'],
#  327: ['LabNowicki'],
#  328: ['CICE_UV'],
#  329: ['Alison63130834'],
#  331: ['minhnh94'],
#  335: ['dorcasmatangi', 'FBaudron', 'CIMMYT', 'ClassicAgronomy', 'Rothamsted'],
#  340: ['TakashiFukushi4'],
#  345: ['TheValue_Guy'],
#  346: ['nhcharlot'],
#  347: ['AlbroLab'],
#  348: ['ManuelKRausch1'],
#  349: ['JasonWilliamsNY'],
#  350: ['jerwinlab'],
#  353: ['TrumpYeti'],
#  354: ['IANalytics2k19'],
#  355: ['mileseu_'],
#  357: ['Thrillhouse138',
#        'yourfriendpiper',
#        'fergbyrd',
#        'DeGener8Oi',
#        'Antifada161'],
#  367: ['WowAI_LLC'],
#  368: ['revealplant'],
#  370: ['WhatsUp_Canada', 'Shawn_McFarlane', 'TheoFleury14', 'partridgerhond'],
#  372: ['PuntoZamora'],
#  375: ['donovanchoy'],
#  378: ['jjohn_zag', 'DarkStarXCIV'],
#  379: ['angelicarbon'],
#  380: ['bethnoveck'],
#  385: ['timethief'],
#  387: ['and_spire'],
#  395: ['Glorthoron',
#        'justpassingby50',
#        '_4_freedom',
#        'MirthDAL',
#        'nationalpost'],
#  401: ['aniluv62'],
#  403: ['TownOfCambridge'],
#  405: ['Staceysteele_'],
#  406: ['martinrafco'],
#  407: ['greenschoolbus'],
#  409: ['shmalessia'],
#  410: ['925mlbfan'],
#  411: ['Digitalskillsp2'],
#  412: ['Bob_gamedev'],
#  413: ['SecdevB'],
#  416: ['s_soteria'],
#  417: ['BryanDeanWright'],
#  419: ['ShayTweeter'],
#  423: ['AaronCuddeback'],
#  425: ['RoboticsAINews'],
#  428: ['xbowlofsunshine'],
#  430: ['snowikuko', 'ebato_bloger'],
#  432: ['wanderngthebchs'],
#  435: ['Decoysheep'],
#  436: ['Lifeisee4me'],
#  437: ['lentilwallop'],
#  443: ['djriveraros'],
#  444: ['jnakrstljvr'],
#  445: ['kmasha022'],
#  446: ['datavizpyr'],
#  447: ['S_Starr1700'],
#  448: ['MargInnes'],
#  449: ['matteopelayo'],
#  450: ['JohnsonJava11'],
#  453: ['NadarSenpai'],
#  454: ['KezGatheca'],
#  459: ['Sci_Rio'],
#  460: ['ArchitMeta'],
#  461: ['deathrep'],
#  463: ['brintosh'],
#  473: ['notyourmaru'],
#  474: ['thegrifft'],
#  478: ['peter_brit'],
#  482: ['drnagu2008'],
#  484: ['LucieRychetnik', 'TAPPCentre', 'MelissaSweetDr'],
#  486: ['katiechelsy_'],
#  489: ['KyleBJorrey', 'brainwhistle'],
#  490: ['dumidyeypee'],
#  491: ['beige5511'],
#  492: ['vikinglogarta'],
#  493: ['wawam'],
#  494: ['aban_emz'],
#  495: ['HelenW61879763'],
#  497: ['mosbah_rasha'],
#  498: ['divinegc'],
#  499: ['svawa'],
#  500: ['ifyouseekkae'],
#  501: ['SurrealRictus'],
#  502: ['TEPcilog'],
#  503: ['AshlieMC2'],
#  504: ['JanPons10'],
#  507: ['DrSteveQuenette', 'MonasheResearch', 'ARDC_AU', 'carmelwalshardc'],
#  509: ['solenluna21'],
#  510: ['unchain_ur_mind'],
#  511: ['burkemlou'],
#  513: ['dyerbin4'],
#  514: ['macjoswaaa'],
#  515: ['iamkimleal'],
#  516: ['RainbowNasie'],
#  526: ['sanee105'],
#  528: ['JohanKardell_', 'QuinnyPig', 'awscloud'],
#  530: ['enaechaluce'],
#  533: ['SalernoSebi'],
#  534: ['karyllepoppn'],
#  537: ['KarenCookPhotos'],
#  542: ['Evenings_Star'],
#  543: ['anuveon'],
#  544: ['Timhortinz'],
#  547: ['phillbjones'],
#  551: ['a_bagaini'],
#  560: ['ByeolHaru'],
#  564: ['Adine11891662'],
#  565: ['uzh_ds'],
#  567: ['OeAD_worldwide'],
#  568: ['wbc_rri'],
#  571: ['apicstgn'],
#  575: ['FlatlanderHank'],
#  576: ['GMOfreeGinger'],
#  583: ['alina_danciu_'],
#  585: ['dufourcoppolani'],
#  588: ['Glory1Jude'],
#  589: ['VU_RDM_Support'],
#  591: ['christofdefryn'],
#  596: ['eomalea'],
#  600: ['annaguillaumet'],
#  601: ['seasonwatch_in'],
#  602: ['justinejenks'],
#  604: ['priyankasacheti'],
#  607: ['Centre_LIVES'],
#  614: ['TitoTidi'],
#  617: ['maarten_witberg'],
#  619: ['ZirkulierBar'],
#  620: ['igz_leibniz'],
#  622: ['SLLShome'],
#  624: ['mars_atlas'],
#  630: ['CSKupr'],
#  631: ['theammind'],
#  634: ['ChangingthingsS',
#        'GovernmentZA',
#        'ARamalisah',
#        'Prudencetm',
#        'nkule_thusini',
#        'PresidencyZA',
#        'ParliamentofRSA',
#        'ECSAOfficial',
#        'Eldidy',
#        'cbe_pta',
#        'cidb_sa',
#        'DepartmentPWI',
#        'PatriciaDeLille',
#        'Kgosientsho_R',
#        'ProudlySA',
#        'productivitysa'],
#  642: ['AntierSarah',
#        'ztfsurvey',
#        'LSST_France',
#        'LIGO',
#        'ego_virgo',
#        'anais_moller',
#        'samayanissanke',
#        'GRAPPAinstitute',
#        'TheAstroPhoenix',
#        'cbellh471'],
#  645: ['MaisonBalzac'],
#  649: ['_popnetwork'],
#  650: ['L0_0ney'],
#  653: ['RSAtmos_LIM'],
#  655: ['EleniVardoulaki'],
#  656: ['MariekeHeers'],
#  660: ['w1kke'],
#  668: ['Notice_Nature'],
#  670: ['umr_ESO'],
#  672: ['DASSHUK'],
#  674: ['TongZhou2017'],
#  675: ['buda_ondrej'],
#  680: ['vivalben'],
#  681: ['InhinyerongFA'],
#  683: ['reeyuuhn'],
#  690: ['Jenniferomoz4'],
#  697: ['cities4tnight'],
#  704: ['The_RRC'],
#  705: ['Frederico_FS'],
#  712: ['fukugyo2287'],
#  713: ['elemai3'],
#  718: ['CovUniResearch'],
#  721: ['Leopoldina'],
#  723: ['evagtgreen'],
#  727: ['Don_Standeford', 'ATL1seven'],
#  731: ['gillygilmore85'],
#  733: ['IHR_Library'],
#  735: ['saulo_jacques'],
#  738: ['Luke_Drury'],
#  748: ['subugoe'],
#  750: ['AstronomyUniver'],
#  763: ['jpfamorcan'],
#  764: ['NickBenCoop'],
#  765: ['KellyElizaLloyd'],
#  766: ['projectmatchph'],
#  769: ['paulajoyce1'],
#  772: ['CumbriaWeather', 'herdwick_gal', 'LBC'],
#  774: ['EUgreenresearch',
#        'Fromevalley',
#        'dominicdsmith',
#        'GrumpieKate',
#        'lupinsandmore',
#        'BEAN_ADAPT',
#        'pulses_increase',
#        'UnivPoliMarche',
#        'EPSOEurope',
#        'biomaram',
#        'EEPaul',
#        'ODIHQ',
#        'theriverstrust',
#        'Nigel_Shadbolt',
#        'gis_michelle',
#        'ClaudiaLemke90',
#        'vbuscher',
#        'ArupGroup',
#        'ColvinH2O',
#        'CropTrust',
#        'DiazDeBatalla',
#        'thangnangman',
#        'coconutz',
#        'TheRiverTrust',
#        'tomguilbert',
#        'gib_tater'],
#  775: ['huashangturkey'],
#  776: ['DocWithTheSocs'],
#  777: ['dg_classics'],
#  778: ['dg_romance'],
#  779: ['dg_history'],
#  780: ['Aqua_Sync'],
#  786: ['DianaEverglades'],
#  787: ['PhilipMorris_NL'],
#  795: ['INSU_CNRS'],
#  800: ['EbongJoyce'],
#  801: ['Sujeni'],
#  802: ['gosquad22'],
#  803: ['Morgan_L_Thomas'],
#  806: ['pmisson'],
#  811: ['EMBL_BioIT'],
#  818: ['pixelsofficials'],
#  820: ['greyhopebay'],
#  823: ['AiThority', 'drivendataorg', 'Iamherox', 'DuquesneLight'],
#  824: ['dellyranksindia'],
#  827: ['democracy_intl'],
#  831: ['valecosta83'],
#  833: ['TinaSilovic'],
#  836: ['C_Bonnamy'],
#  839: ['RandomFilThots'],
#  846: ['ForestShell'],
#  850: ['hcp4715'],
#  855: ['minhollynight'],
#  856: ['DermotLynott'],
#  860: ['malcolmblove'],
#  861: ['NnadozieRejoice'],
#  862: ['siwanonlee'],
#  863: ['minikangie'],
#  864: ['OpenScTransport'],
#  865: ['xxpersi'],
#  866: ['kmiou'],
#  869: ['samenmeten', 'rivm', 'L1'],
#  879: ['RSPB_Learning',
#        'Natures_Voice',
#        'EcoSchools',
#        'EcoSchoolsWales',
#        'RSPBCymru',
#        'Ecolelogical',
#        'HawkConservancy',
#        'birdsofprey_uk',
#        'EcoLismore',
#        'EcoSchoolsScot',
#        'EcoSchools_TW'],
#  883: ['winterhyunbin'],
#  884: ['mellozelle'],
#  885: ['CarisaCorrow'],
#  896: ['aedin_'],
#  897: ['heavenlyswirl'],
#  898: ['limeunseob'],
#  902: ['popecologist'],
#  903: ['AContestataires'],
#  905: ['Mrtrendist'],
#  906: ['bahianajournals'],
#  913: ['CoimbraGroup'],
#  915: ['CalZole'],
#  917: ['seruky096'],
#  918: ['Petroenerga1'],
#  922: ['Astro4Dev'],
#  926: ['TVERC1',
#        'PTES',
#        'hedgehogsociety',
#        'BTO_GBW',
#        'BBS_birds',
#        'Gameandwildlife',
#        'seasonlisten',
#        'NArchives422',
#        'TOE_oxon',
#        'robinfbennett',
#        'BTO_Scotland',
#        'dotworkdalek'],
#  929: ['suhodorable'],
#  930: ['hkjassal'],
#  931: ['__SimpleLiving'],
#  933: ['Labyrinth_101'],
#  934: ['AppBienDit'],
#  935: ['a_ludhiadch07'],
#  936: ['AngelHu79798669'],
#  940: ['AaltoResearch'],
#  942: ['NuriaBautista7'],
#  944: ['RLadiesDammam'],
#  948: ['batool664'],
#  949: ['TCVYork'],
#  951: ['MeiliJein'],
#  956: ['want2Ioveu'],
#  964: ['notmigueluis'],
#  966: ['RebeccaDW970'],
#  973: ['crowdfundernews'],
#  976: ['LunesDes'],
#  977: ['SAAOMEGA'],
#  978: ['Tamara0h'],
#  979: ['edc_acropolis'],
#  982: ['ValuingN'],
#  983: ['LockhartTech'],
#  984: ['HBCUDataScience'],
#  987: ['Allannoch'],
#  988: ['_Robin_C_'],
#  989: ['psicoapurada',
#        'abelladaniel',
#        'Adesvergonzadas',
#        'AlbertoRC89',
#        'jjgarciaripoll',
#        'jzamorabonilla',
#        'arielsgl',
#        'shahreeners',
#        'ClaeysVub',
#        'gentleman_toker',
#        'KAMIAN',
#        'la_santacruz',
#        'fpjindia',
#        'MapasLab',
#        'ClubesCienciaMx',
#        'ccg_unam',
#        'dev_discourse',
#        'g8ge',
#        'torreon'],
#  993: ['Kikmi'],
#  995: ['ProsaicView', 'priyashmita'],
#  998: ['besh_king'],
#  1007: ['EngagementDom',
#         'UCL_UCU',
#         'XineYaoPhD',
#         'TheBardolator',
#         'astrosadie'],
#  1008: ['Tamitamtamtamta'],
#  1009: ['chris1harris'],
#  1011: ['lesleybruinton',
#         'Tony_Tsoukalas',
#         'Bama6895',
#         'rogerpatmyers',
#         'BrianOliu'],
#  1015: ['greenhumanities'],
#  1016: ['SuhanaS38680569'],
#  1018: ['franckgiacomoni'],
#  1019: ['BoeseDr'],
#  1021: ['EngageNCL'],
#  1022: ['aybelbautista'],
#  1030: ['vertacoy'],
#  1032: ['europlanetmedia', 'EAS_meeting'],
#  1041: ['mola_oriola'],
#  1043: ['FloMontel'],
#  1051: ['polyglossapp'],
#  1052: ['laoisheritage',
#         'nore_vision',
#         'DCUEdTrust',
#         'Rethink_Ireland',
#         'DCU',
#         'DaireKeogh',
#         'ornua',
#         'swanireland',
#         'DeptRCD'],
#  1053: ['gloria_glomc'],
#  1054: ['Omid_Ghasemi21'],
#  1055: ['namita_barde'],
#  1060: ['TylerCr52643659'],
#  1061: ['connectpeople33'],
#  1065: ['B_R_50',
#         'mfnberlin',
#         'MPIWG',
#         'zflkomm',
#         'CSAustria',
#         'BOKUvienna',
#         'jan_seibert',
#         'crowd_water',
#         'NHM_Wien',
#         'mitforschen',
#         'ScienceEtCite',
#         'BBF_DIPFBerlin',
#         'AdamClarkSmith',
#         'LenaTheiler',
#         'pat_macro',
#         'S_VoigtHeucke',
#         'pwa_zurich',
#         '_condensible',
#         'wissimdialog',
#         'MeteoHautnah',
#         'AgroEcoVen',
#         'Raspi4b',
#         'fubcp',
#         'ff_nachtigall',
#         'xenocanto',
#         'SingwarteMedia',
#         'delameurthe',
#         'VivienZahs',
#         'TabeaBork',
#         'komazsofi1',
#         'sarahgoehmann',
#         'UniBremen',
#         'NaWik',
#         'Hense_F',
#         'Schepers_CJ',
#         'FuturiumD',
#         'InnoTruck',
#         'wisskomm_de',
#         'carlosguerra_pt',
#         'hfreye',
#         'OIS_Center',
#         'naturejule',
#         'KatharinaWeiss_',
#         'unibt',
#         'fMRI_guy',
#         'SCienceSophs',
#         'wisskomm',
#         'CPDN_BOINC',
#         'Doc_med_Moody',
#         'Archivalia_kg',
#         'hypothesesorg',
#         'Mareike2405',
#         'SUMMERH2020',
#         'LehnertSigrun',
#         'saxorum',
#         'Kim_Mortega',
#         'FU_Berlin',
#         'GraduateBCP',
#         'h_bonnrheinsieg',
#         'UNIC_RUB',
#         'Schoenburghist1',
#         'sanosma',
#         'AlexandraThmml1',
#         'TAllianzeV',
#         'HolgerMauelsha1',
#         'LeibnizWGL',
#         'RosiWuertz',
#         'BelenDaza69',
#         'GuentherNiklas',
#         'Senckenberg',
#         'geobiodiversity',
#         'olikuk',
#         'sushecker',
#         'Amphipodana',
#         'shelog',
#         'teambuergeruni',
#         'LaraKristiansen',
#         'jeb_140',
#         'BMBF_Bund',
#         'f_whrl',
#         'dresden_forscht',
#         'der_Allgaeuer',
#         'UniHalle',
#         'UFZ_de',
#         'idiv',
#         'campusnatur_fu',
#         'ClimateKIC_DE',
#         'BernhardHofle',
#         '3DGeoHD',
#         'kappadiversa',
#         'UniHeidelberg',
#         'IWR_HGS',
#         'PHintheDH',
#         'CoActeu',
#         'VetmeduniVienna',
#         'felinigrad',
#         'Stadt_Wien',
#         'wien_wissen',
#         'stadtdialog',
#         'StadtLinz',
#         'GrazStadt',
#         'KlagenfurtStadt',
#         'stadt_innsbruck',
#         'pavaobot',
#         'coneyvon1',
#         'HaslobHolger',
#         'LeniHauss',
#         'uwe_cantner',
#         'FHNWTechnik',
#         'ScienceVienna',
#         'gh_wisskomm',
#         'BWKI10',
#         'uni_tue',
#         'Stuttgart_IRIS',
#         'Uni_Stuttgart',
#         'alexanderbrem',
#         'bonnsusport',
#         'forschungsstrom',
#         'KKnuthHerzig',
#         'HackyScientress',
#         '5imulacrum',
#         'henningkrause',
#         'MFG_Akademie',
#         'TheOneBrack',
#         'HHZ_BB',
#         '__dr_d___',
#         'WissKon',
#         'WiMaKo_Kolleg',
#         'dnapuzzles',
#         'phyloDNApuzzles',
#         'ColonyBgame',
#         'AnnaHenschel',
#         'Die_Primel',
#         'AlettaBonn',
#         'lejano_sur',
#         'don_sci',
#         'LeibnizIPK',
#         'NFDI4BioDiv',
#         'Thomas_SiriusV',
#         'Brandt_Futurium',
#         'CrowdInnoIMW',
#         'hhlleipzig',
#         'InaOpitz',
#         'hella_von_unger',
#         'DirkLangolf',
#         'dilekfraisl1',
#         'AidinNiamir',
#         'IPBES',
#         'LeilaNiamir',
#         'SalonderZukunft',
#         'oluochodhiamboo',
#         'AlexGodoyF_',
#         'JavierValdi2',
#         'MarieStenseke',
#         'ClementVIOLET',
#         'RMkrug',
#         'HannoSeebens',
#         'KoonsLab',
#         'AliceCHughes',
#         'Cyber_Valley',
#         'realsci_DE',
#         'PKluegel',
#         'JoeyWayman',
#         'chabis_ch',
#         'caissarl',
#         '_CitizenScience',
#         'GSouchay',
#         '_lenaackermann',
#         'ecolandlab',
#         'RosettaAtHome',
#         'TheBoinc',
#         'beiter_rebecca',
#         'MilkyWayatHome',
#         'TheSingDesigns',
#         'ENHANCEAlliance',
#         'waldispuhl',
#         'the_MMOS',
#         'FuzzyLeapfrog',
#         'femgeeks',
#         'zeyror',
#         'Dr_Kaspar',
#         'ProfKlee',
#         'taetz_harrer',
#         'Rechenkraft_net',
#         'SiDockProject',
#         'MWNautilus',
#         'wirzbergerm',
#         'lassejulius',
#         'WildeNatur',
#         'aaleydarocha',
#         'oeaw',
#         'ArsElectronica',
#         'os4os_',
#         'gpugrid',
#         'Thuenen_aktuell',
#         'WaddenseaUNESCO',
#         'neumann_hermann',
#         'prxagentur',
#         'prxpragma',
#         'MarkoFreese',
#         'Loeffler_News',
#         'raumschiff_org',
#         'kleinschmidt77',
#         'MMagdowski',
#         'AlexanderLasch',
#         'kleines283',
#         'heartucate',
#         'SchulzAuguste',
#         'bjoerngruening'],
#  1067: ['manos_tsakiris'],
#  1069: ['nine_thanaa'],
#  1070: ['thidakarn'],
#  1071: ['adbarbaresi'],
#  1072: ['ennomotive'],
#  1073: ['Limor_Raviv'],
#  1076: ['DntbUkraine'],
#  1077: ['huduyakubu'],
#  1091: ['Giga_CRCivi',
#         'CHULiege',
#         'AgroBioTech',
#         'ULiegeArlon',
#         'LiegeGameLab',
#         'TransitionsUR',
#         'GIGAConscious',
#         'GHER_ULiege',
#         'SHATM_ULiege',
#         'MSLab_ULiege',
#         'Geomatics_Unit',
#         'HECLiege',
#         'PauschMarie',
#         'marindacos',
#         'recherchedatagv'],
#  1093: ['Tracelessdevil'],
#  1101: ['FinkBroker'],
#  1102: ['ILAF_OGC'],
#  1105: ['notavailawble'],
#  1106: ['IDEESpain'],
#  1107: ['emilleishida'],
#  1109: ['TCVtweets'],
#  1111: ['obsolete__units'],
#  1118: ['oceandiagnstics'],
#  1126: ['uofgmvlsengage',
#         'scotpenetwork',
#         'UofGMVLS',
#         'CVRHutchinson',
#         'GlasgowSciFest',
#         'UofGMVLSGradSch',
#         'UofGSciEngGrads',
#         'UofGPGRs',
#         'UofgI',
#         'UofGPE'],
#  1127: ['TekWildlife'],
#  1128: ['JakeYeston',
#         'ReproHack',
#         'caha42',
#         'DLR_software',
#         'highwirepress',
#         'pmarrai',
#         'ORCID_Org',
#         'RDA_Deutschland',
#         'athenaRICinfo',
#         'helmholtz_hmc',
#         'NaudetFlorian',
#         'WeilWeis',
#         'Lambo',
#         'FranzOssing',
#         'FZJ_RDM',
#         'stdruskat',
#         'fthierygeo',
#         'nasireisty',
#         'twcampus_bot',
#         'EUScienceInnov',
#         'EGI_eInfra',
#         'NCSAatIllinois',
#         'adam_sporluck',
#         'BetterSSw',
#         'RiittaAK',
#         'ua_ahpcc',
#         'I_Y_S',
#         'JR48237144',
#         'AthinaZampara',
#         'MVFoundation',
#         'heallinkgr',
#         'GSRT_GR',
#         'pcmasuzzo',
#         'ZENODO_ORG',
#         'Eurodoc',
#         'BogdanDMCocos',
#         'annette_strauch',
#         'RCollenteur',
#         'OPERAS_GER',
#         'fdmhildesheim',
#         'schymans',
#         'openaccessnet',
#         'OnMerrit',
#         'sarahderijcke',
#         'UBChemnitz',
#         'lfvopenscience',
#         'danielskatz',
#         're3data',
#         'mardi4nfdi',
#         'rcaap',
#         'OpenSciSaudi',
#         'pe_anja',
#         'ecodm_projekt',
#         'DNB_Aktuelles',
#         'pampel',
#         'helmholtz_os',
#         'StabiHH',
#         'webisblog',
#         'BMittermaier',
#         'Ianus_fdz',
#         'c_riesen',
#         'helmholtz_de',
#         'helmholtz_en',
#         'GenderedT',
#         'IcdiData',
#         'DiGiorgioSara',
#         'ida_imm',
#         'enigmaticocean',
#         'scholl_i',
#         'geschichtenpost',
#         'UniBonn',
#         'TIB_AVPortal',
#         'ub_bi',
#         'NadjaDanilenko',
#         'YERUN_EU',
#         'cl_ndf',
#         'swagunke',
#         'gaertner_anne',
#         'FAIRsFAIR_EU',
#         'bibliothekarin',
#         'Europeanaeu',
#         'MNGBS',
#         'MCA_EU',
#         'OATage',
#         'tamaraheck',
#         'JasminSchmitz12',
#         'plastik_umwelt',
#         'MP_Detektiv',
#         'turkgultekin',
#         'OpenAIRE_eu',
#         'up_joad',
#         'irene_barbers',
#         'uzh_ub',
#         'SoerenAuer',
#         'parabenstv',
#         'Tgw_Ub_Unibe',
#         'humsoc_ub_unibe',
#         'EOSC_DIH',
#         'cite_sa',
#         'Ulli42',
#         'PeterKraker',
#         'UniKonstanz',
#         'WikimediaDE',
#         'ZentrumCB',
#         'lautrusca',
#         'OKScienceDE',
#         'MMunckmark',
#         'OezcanMutlu',
#         'manuelahoefler',
#         'dhuerlimann',
#         'egiglia',
#         'ETHBildarchiv',
#         'niggegraf',
#         'chinoup',
#         'antoniamcorreia',
#         'ETHBibliothek',
#         'OxfordeResearch',
#         'DINIde',
#         'drAChiarelli',
#         'fid_geo',
#         'schutten_ev',
#         'MelanieBergma18',
#         'corinna_wil',
#         'F1000Research',
#         'diese_Sirene',
#         'PetraFi05854378',
#         'MMMarksman',
#         'RadiomicsBot',
#         'now_ocean',
#         'oucyprus',
#         'JahnaO',
#         'govdata_de',
#         'FDMThueringen',
#         'z_sazae',
#         'mebemar',
#         'LexBouter',
#         'AWI_de',
#         'poi_ki_lo_therm',
#         'HZDR_Dresden',
#         'GFZ_Potsdam',
#         'janwiebelitz',
#         'DHDarmstadt',
#         'jodageiger',
#         'innohub13',
#         'pass_stef',
#         'alexa_axtmann',
#         'FrauHelbig',
#         'yvgrossmann',
#         'Jorsua_Herrera',
#         'UCYLibrary',
#         'eebep',
#         'uoaofficial',
#         'GermanRepro',
#         'deborahpriss',
#         'KaterinaZouzou1',
#         'BU_BAArchAnth',
#         'Xaveris3',
#         'researchremix',
#         'GEOMAR_de',
#         'janinefelden',
#         'dai_weltweit',
#         'allinteract',
#         'alicia56575264',
#         'Etorras27',
#         'EngFlecha',
#         'rosavallsca',
#         'mrchristian99',
#         'tsorde',
#         'annemscheel',
#         'DH_DLA',
#         'GrupDones',
#         'carbonell_sara',
#         'SusannaASansone',
#         'RR_Oxford',
#         'FAIRsharing_org',
#         'G_LopezdeA',
#         'KalElSkywalker',
#         'vanessamonardel',
#         'JavierDiez1',
#         'olivia_denk',
#         'maikenhagemeist',
#         'bibverband',
#         'sbb_news',
#         'torstenreimer',
#         'HHchiara',
#         'hurukuta',
#         'AllianceYufe',
#         'Nancydiana',
#         'AntjeTheise',
#         'heimstaedt',
#         'UniHannover',
#         'LMU_Muenchen',
#         'BerlinerLufti',
#         'ClaudiaSittner',
#         'ARC_DU',
#         'JWI_Berlin',
#         'miguelnavasf',
#         'biblink',
#         'dipf_aktuell',
#         'andreaskirstein',
#         'DBS_20',
#         'FachportalPaed',
#         'kathberr',
#         'FahrradProf',
#         'julia_10br',
#         'jhdez32',
#         'MLRzh',
#         'teachepi',
#         'api_magazin',
#         'HAW_Hamburg',
#         'inandsight',
#         'sjh5000',
#         'miriambasagans',
#         'rmwillen',
#         'Protohedgehog',
#         'olakronkvist',
#         'Sci_for_Ukraine',
#         'S_Koukounidou',
#         'SLUBdresden',
#         'Appl_Research',
#         'apmozaffari',
#         'RDA_Europe',
#         'UNESCOEU',
#         'jgolds2',
#         'JFMartinSupagro',
#         'COPIMproject',
#         'MarjanGrootveld',
#         'SonyDeutschland',
#         'physikerwelt',
#         'Hyper_Node',
#         'andkirchner',
#         'ajspadial',
#         'm_cragin',
#         'dominik_hagmann',
#         'rsilvia77',
#         'MontseS1',
#         'elentoli',
#         'pettulda',
#         'elli_lib',
#         'ARAIreland',
#         'konradfoerstner',
#         'er_crema',
#         'EOSC_Nordic',
#         'HM_de_Jong',
#         'benmarwick',
#         'yaskondo',
#         'katja_mat',
#         'HarutaSeiro',
#         'CDWren',
#         'HelenKollai',
#         'orchid00',
#         'scicodes1',
#         'in_stemm',
#         'alesarrett',
#         'ElectraSif',
#         'Biblio_FUBerlin',
#         'inscico',
#         'UniofOxford',
#         'AlePalmi82',
#         'ahb108',
#         'eliasdan',
#         'TripleEU',
#         'ForschDatenInfo',
#         'BERD_NFDI',
#         'philriris',
#         'libschumm',
#         'DriesDaems',
#         'RDM4LUH',
#         'LeverhulmeTrust',
#         'Mael_Crepy',
#         'RonnyRoewert',
#         'ubleipzig',
#         'ga_unihannover',
#         'StewieStewart13',
#         'ICoRSA_News',
#         'WeisserBernhard',
#         'kulturSPK',
#         'EoscPillar',
#         'presseunikassel',
#         'NFDI_de',
#         'PPR_Dahlem',
#         'JohEberhardt',
#         'LIBEReurope',
#         'Library_RIA',
#         'ex_oriente_eV',
#         'davidfkane',
#         'juliaschoenicke',
#         'FIDRomanistik',
#         'barbebert',
#         'joeroe90',
#         'dri_ireland',
#         'bethknazook',
#         'EOSCFuture',
#         'aaocarroll',
#         'kobv_zt',
#         'OpenAccess_BB',
#         'oa_berlin',
#         'TH_Wildau',
#         'ENRIITC_eu',
#         'evamen',
#         'A_Panagopoulou',
#         'JohannesvV',
#         'IPHC_Strasbourg',
#         'stabi_erlangen',
#         'Dr_NinonFrank',
#         'lisamgriffith',
#         'C3DTI',
#         'ferli90',
#         'AvivaFreda',
#         'Public_MDPI',
#         'g3om4c',
#         'EOSC_synergy',
#         'NI4OS_eu',
#         'ZBW_MediaTalk',
#         'jd162a',
#         'bib_tugraz',
#         'LifeWatchERIC',
#         'LifewatchBE',
#         'Denu_Nery',
#         'ursula_loosli',
#         'IandPangurBan',
#         'LifeWatchIT',
#         'nkkumar82',
#         'vaitsap',
#         'MPutnings',
#         'dbeucke',
#         'OpenRewi',
#         'reinfie',
#         'WZB_Berlin',
#         'ktochtermann',
#         'VET_Repository',
#         'schmidt_fu',
#         'DalaiSidd',
#         'Fraunhofer',
#         'psm_os',
#         'FoDaKo_NRW',
#         'PSoemers',
#         'HZBde',
#         'TIBHannover',
#         'oa_nrw',
#         'JessButler284',
#         'rimamrahal',
#         'Suzdum',
#         'freddie2310',
#         'EllenEuler',
#         'BlasettiAle',
#         'SusanneGoettker',
#         'V_Erastova',
#         'maxi_ki',
#         'chruediger',
#         'WCRIFoundation',
#         'OSLHannover',
#         'dirkverdicchio',
#         'hsh_bib',
#         'CoreTrustSeal',
#         'ZBW_news',
#         'HWiesenmueller',
#         'opensciencebern',
#         'BoukacemZeg',
#         'RWTHUnibib',
#         'ridderjeroen',
#         'NRIN_Integrity',
#         'AKC_VU',
#         'DeJongeAkademie',
#         '_knaw',
#         'InekeSluiter',
#         'RetractionWatch',
#         'SurveyIntegrity',
#         'sops4ri',
#         'ArTi_FiCieL',
#         'DOABooks',
#         'FrauMaren',
#         'StellenBERLIN',
#         'najkoja',
#         'wmijnhardt',
#         'LizzieGadd',
#         'MetOpenResearch',
#         'fosterscience',
#         'KennethRuud',
#         'DahleSebastian',
#         'EcologicBerlin',
#         'robeirne',
#         'hannahmetzler1',
#         'JohanRooryck',
#         'LidiaBorrellDam',
#         'ExPaNDs_EU',
#         'BastianDrees',
#         'R_Flecha',
#         'analebrn',
#         'berlinnovation',
#         'dirnagl',
#         'ChariteBerlin',
#         'Ane_LAguileta',
#         'RocioCarrion81',
#         'Bf3R_centre',
#         'PedagogiaSocial',
#         'vladia_ionescu',
#         'martafont8',
#         'Lijhba',
#         'mindfuldesserts',
#         'KLenaki',
#         'NBlomberg',
#         'MariannePEIFFER',
#         'asmi_ari',
#         'ZBZuerich',
#         'SRF',
#         'dinger_p',
#         'archivdaten',
#         'tedvitek',
#         'MISSIONATLANTIC',
#         'AllAtlanticO',
#         'klebel_t',
#         'benny_de',
#         'mikaellaakso',
#         'PlickertHolger',
#         'CShillum',
#         'TOLTECATLn',
#         'josmel1',
#         'REKnupfer',
#         'F_Huonder',
#         'mycowork_space',
#         'AsturiasAEBE',
#         'xandruarmesto',
#         'MargauxKers',
#         'OpenScienceMOOC',
#         'IGDOREinstitute',
#         'aeryn_thrace',
#         'OAforClimate',
#         'cmplxtv_studies',
#         'mkrauskopf'],
#  1140: ['drccamara'],
#  1143: ['MasharosNews'],
#  1144: ['MarcosAMerinero'],
#  1149: ['tw0handt0uch1'],
#  1154: ['pepistella'],
#  1156: ['WortmannLars'],
#  1159: ['TonyMcEnery'],
#  1161: ['bjenquist',
#         'PFTCourses',
#         'VVandvik',
#         'nick_greg_smith',
#         'BenBondLamberty',
#         'Noguesbravo',
#         'DylanJCraven',
#         'ftmaestre',
#         'BeckSamBar',
#         'Ellen_BESS',
#         'eco_puni',
#         'JohannaAndrea23',
#         'lauzon1969',
#         'LohenCavieres',
#         'LNeuenkamp',
#         'Serega_XP',
#         'asifaliphd',
#         'A_MayDB',
#         'dneves_ecology',
#         'BarkerLab',
#         'MBRMark',
#         'marksandfoss',
#         'benjaminblonder',
#         'MaryHeskel',
#         'csi_micromet',
#         'exswiatek',
#         'BrianMaitner',
#         'nsvitek',
#         'jophen_ol',
#         'agonzalezLAB',
#         'MossPlants',
#         'ChrisKlausmeier',
#         'falco_nic',
#         'SeanMichaletz',
#         'Maria_Trivino_C',
#         'Vero_Zepeda_',
#         'JosephTumber',
#         'Sozae_',
#         'evilanova',
#         'AndreRovai',
#         'BS_ScalesPhD',
#         'ArleneLop',
#         'JMBonzom',
#         'DisturbedDendro',
#         'cadj0506',
#         'BioGeoMacro',
#         'BioGeoKreft',
#         'BioFascinates',
#         'tmoreperez',
#         'MorrienElly',
#         'TatianaAriasGar',
#         'HeartsatPlay',
#         'DagmarEgelkraut',
#         'SWTJolyon',
#         'SomersetWT',
#         'WildlifeTrusts',
#         'HugoSAS',
#         'enviro_educate',
#         'procm2',
#         'tswetnam',
#         'EnvironmentPlym',
#         'AvilaLovera',
#         'MyriamHirt',
#         'Edwards_evoeco',
#         'jesseSeeEm',
#         'kjfeeley',
#         'buckster_rudy',
#         'BioLumbee',
#         'e_borer',
#         'crzacynpat',
#         'Csar67044020',
#         'Ecology_Andrea',
#         'wb_jennings',
#         'RodrigoVeas10',
#         'scott_saleska',
#         'slrutledge27',
#         'Starslikepinhol',
#         'ev_essouza',
#         'SarayGGordillo',
#         'DaniArosMualin',
#         'AllFishOnTheFly',
#         'PaulEfrenSantos',
#         'Ebh_mayra',
#         'flybrain',
#         'timmybash001',
#         'merypoca',
#         'rojeda_ricardo',
#         'm_maciasfauria',
#         'chris_harrod',
#         'm_angeles582',
#         'M_J_Spasojevic',
#         'LaurenceWRT',
#         'BristolFreegle',
#         'richardjtelford',
#         'ColelliCol',
#         'WestcountryRT',
#         'B_Strawbridge',
#         'Falmouth_Buzz',
#         'RamePBeachCare',
#         'PeteEcology',
#         'my_plants_dance',
#         'obebo_me',
#         'GoraEvan',
#         'naomibschwartz',
#         'BirdWatchingMy',
#         'moniqueweemstra',
#         'blois_paleo_lab',
#         'SobehaTour',
#         'jilleen_st',
#         'Jasper44118677',
#         'one_freyja',
#         'MaureenMannion2',
#         'FriseSally',
#         'DorHulse',
#         'ChristineCave9',
#         'NERC_QNFM',
#         'pierregsy',
#         'SWTsteve',
#         'JohnHar45782426',
#         'lizziwalt',
#         'gjfry',
#         'savesydneykoala',
#         'Crystalgrzzl',
#         'Karmageddon67',
#         'ABenite01',
#         'gteasts',
#         'Sydney_Guide',
#         'CourtRum',
#         'Spencerfletch0',
#         'warreng133',
#         'cetti19',
#         'JaimeGongoraSyd',
#         'Sydney_Science',
#         'cityofsydney',
#         '7ef9db4a7c8d400',
#         'lisalmcgrath1'],
#  1164: ['F0NF0N33'],
#  1165: ['AgrimonySpikes'],
#  1166: ['Cliveref', 'CrowdWeek', 'LPlus'],
#  1170: ['IAU_Outreach', 'iau', 'IAU_org', 'KirubelMenberu'],
#  1173: ['ContributorsX1'],
#  1183: ['cefalopodo'],
#  1185: ['ZyiteGadgets'],
#  1189: ['k4tc4rl0', 'PinoyAkoBlog', 'lakwatsarah'],
#  1191: ['keeppad'],
#  1192: ['Read_Instead'],
#  1194: ['CzemborJerzyH'],
#  1195: ['coopersensei'],
#  1198: ['FinRepro'],
#  1199: ['bezwitschernd'],
#  1203: ['the_prbb'],
#  1209: ['Horlawunmy9092'],
#  1212: ['SESAR_JU'],
#  1218: ['DavidRobOwen'],
#  1219: ['_ChristinaEmery'],
#  1220: ['CorrectingMatch', 'JamesMelville', 'Out5p0ken'],
#  1222: ['leftsoccermum'],
#  1225: ['frankenduf'],
#  1226: ['eyesonmars_uk'],
#  1229: ['dginev'],
#  1233: ['juancamiload'],
#  1234: ['JcMalgieri'],
#  1236: ['ATTRACTEU'],
#  1238: ['crowdfundbacks'],
#  1239: ['karry4you'],
#  1240: ['page_gould'],
#  1243: ['Twarkowski'],
#  1245: ['MarsExplorat', 'physorg_com', 'DubnHG1', 'CornubiaGeol', 'DEskildson'],
#  1251: ['KaisaSaurio'],
#  1260: ['SemanticFolding'],
#  1262: ['0xNasa'],
#  1263: ['ArticuloAnn', 'LSL_GG', 'AxieLima'],
#  1270: ['AureliePols'],
#  1272: ['julienrossi'],
#  1279: ['Oriludic'],
#  1280: ['ckdramafiles'],
#  1281: ['LaPorres'],
#  1282: ['lizygist'],
#  1283: ['juanthesecond_'],
#  1285: ['CSchwarzkopf'],
#  1293: ['Shhrutzz'],
#  1294: ['sslevine'],
#  1296: ['Alisoconagle', 'contrib_roles', 'NISOInfo', 'ansidotorg'],
#  1298: ['assforkr', 'JoelMagnus', 'lporiginalg'],
#  1300: ['superteamup'],
#  1302: ['elsamariedsilva', '_WomenSpeakers_'],
#  1316: ['_mjastro777'],
#  1321: ['KristiFinkTXESP'],
#  1326: ['JohnyDo53419035'],
#  1328: ['lostsunset_', 'justbreathereal'],
#  1329: ['Emilian22847466'],
#  1335: ['elmaresearch'],
#  1336: ['Martinez19Sindy', 'adrisoacha', 'FelipeARoa'],
#  1341: ['opalbert'],
#  1346: ['amiramoray'],
#  1350: ['doilyboyz',
#         'UghitsAnjali',
#         'm_layton',
#         'Jayman1975Jw',
#         'theJagmeetSingh'],
#  1357: ['vinayprabhu'],
#  1358: ['SSadanad', 'Thom_Wolf', 'huggingface'],
#  1360: ['swittke1'],
#  1361: ['gmdsEV'],
#  1362: ['gentraso'],
#  1369: ['p_casarotto'],
#  1373: ['INBIOMAR_',
#         'FBiodiversidad',
#         'ReefLifeSurvey',
#         'FMELDAS',
#         'johnwturnbull',
#         'AudreyEverleigh'],
#  1376: ['OpenEnviroData', 'gwenwsmith'],
#  1377: ['DorteRiem'],
#  1389: ['crowdfundfans'],
#  1391: ['TimSDobbs'],
#  1393: ['SanjayAtPlay'],
#  1398: ['BregmanPs',
#         'Kikuyukuyu',
#         'RorshachTickler',
#         'FrontDrugDDS',
#         '_melissabasso',
#         'FrontPolSci',
#         'TPaffenholz',
#         'Anastas91641307',
#         'CedricdeConing',
#         'ICalzada',
#         'IgnacioJurado',
#         'tonirodon',
#         'FrontHDynamics',
#         'Montwitt12',
#         'LaBorocoto',
#         'LauraH_words',
#         'BurgelmanJean',
#         'FrontiersIn',
#         'Enkidu_forever',
#         'Rui_FFF',
#         'MianoTeodoro',
#         'JovitaMezquita',
#         'SpicyEva1',
#         'ciudadhiguey',
#         'nadeemhaque',
#         'malupenafiel',
#         'bida_legend',
#         'Angika1973',
#         'FrontCVMedicine',
#         'EmmaPettengale',
#         'FrontMarineSci',
#         'InclusivePeace'],
#  1399: ['drhannaha'],
#  1404: ['engageSAS'],
#  1407: ['BerLinguistin'],
#  1408: ['tjlcipriano'],
#  1409: ['ecliptiko'],
#  1410: ['miringujt'],
#  1413: ['DexiaKong',
#         'binarchya',
#         'wtgrantfdn',
#         'polarbear0627',
#         'qdrepository',
#         'lkortbutler',
#         'VizCrim',
#         'SociologyKB',
#         'SocImages',
#         'RexDouglass',
#         'crodriguezprada',
#         'Andrea_Tilstra',
#         'kbkarlson',
#         'elbersb',
#         'jm_aburto',
#         'SaidAJHassan',
#         'valdanchev',
#         'matt_haslberger',
#         'ginevra_floridi',
#         'OxfordDemSci',
#         'cbarrie',
#         'elgarteo',
#         'NuffieldLibrary',
#         'ArunFrey',
#         'ConstantinaBade',
#         'SarahCharlesNC',
#         'JamesEBartlett',
#         'Ol1909',
#         'ppraeg',
#         'LizGuzRam',
#         'erasmusuni',
#         'akadsoz',
#         'RubinPsyc',
#         'eshcc_eur',
#         'ERIMResearch',
#         'OSCRotterdam',
#         '_Alex_Horn',
#         'MethodsNET',
#         'Konstanz_Pol_PA',
#         'EXCInequality',
#         'WernerPalz',
#         'EvaThomann',
#         'aresherman',
#         'ampenner',
#         'ahyde110',
#         'carywoo',
#         'MarkDVerhagen',
#         'virtualjess',
#         'LauraUpenieks',
#         'cimness',
#         'sociojen',
#         'vilahenninge',
#         'brett_gordon',
#         'IrisVanRooij',
#         'zerdeve',
#         'thuyvytnguyen',
#         'DanielSkorich',
#         'lakens',
#         'kjpp_erasmusmc',
#         'mlopez_vicente',
#         '_MustafaFirat_',
#         'AustinVanLoon',
#         'mjskay',
#         'millard_joe',
#         'ewrigleyfield',
#         'GovindPersad',
#         'ethicsBot_',
#         'DataHorseman',
#         'olhxl',
#         'KA_Tamminen',
#         'MayaAndGonzalez',
#         'prof_goldberg',
#         'SociusJournal',
#         'c_j_pascoe',
#         'lisawade',
#         'G1Leeee',
#         'familyunequal',
#         'asociologist',
#         '45pairsofsocks',
#         'Uptheleft',
#         'flourn0',
#         '_DeStefani',
#         'tech_gabo'],
#  1414: ['ForeverFeasting'],
#  1415: ['FicoCharlaey'],
#  1432: ['HistEnvScot'],
#  1433: ['CYMotorsport'],
#  1436: ['TinaniF1'],
#  1437: ['ino_vati'],
#  1439: ['karenverst'],
#  1441: ['omicdata'],
#  1448: ['liberty_addict'],
#  1454: ['BoydHutchinson6'],
#  1455: ['BMatteau', 'ClayTravis'],
#  1456: ['Jordi42709149'],
#  1461: ['ICTKasia'],
#  1463: ['SaltwaterlifeUK'],
#  1465: ['bhayurr'],
#  1466: ['ErinMc_keown'],
#  1467: ['Astro_MikeS'],
#  1471: ['dgpuk_rezfo'],
#  1477: ['CDPConnect'],
#  1480: ['Lenafrescamente'],
#  1482: ['mrnoram', '501Awani', 'metmalaysia'],
#  1484: ['politikayl'],
#  1486: ['DynamicalSyste2'],
#  1487: ['NYU_CUSP',
#         'PorfiriMaurizio',
#         'jmirpub',
#         'J_SeriousGames',
#         'nyutandon'],
#  1492: ['drkashton42'],
#  1494: ['usnaec'],
#  1497: ['acabezas'],
#  1500: ['michaelahuey', 'HMIBisonDollars'],
#  1502: ['DiegoMaxiA1'],
#  1504: ['PaulDelano72', 'TimRunsHisMouth'],
#  1510: ['jsbagla'],
#  1515: ['boston_hoax'],
#  1518: ['Quasica', 'flleeppyy'],
#  1526: ['WCountryVoices'],
#  1527: ['PaulSloane'],
#  1528: ['tnarock'],
#  1531: ['storm_tx'],
#  1538: ['edinburghcoll',
#         'auntgilly73',
#         'PurpleKerry1969',
#         'ECSAonline',
#         'CentrePrentice',
#         'EdinChamber',
#         'colleges_data',
#         'EAUCScotland'],
#  1540: ['Amara401'],
#  1541: ['txescu'],
#  1543: ['227_MN'],
#  1551: ['crowdfundinback'],
#  1565: ['paul_a_bloom'],
#  1566: ['CNRSinRio'],
#  1597: ['DrMichaelEades'],
#  1605: ['challiewaziri'],
#  1609: ['DeepOceanObs'],
#  1632: ['ElliotCardigan'],
#  1633: ['Neanias_eu'],
#  1653: ['otanistudio'],
#  1655: ['GregoireDubois'],
#  1656: ['MasurPhil'],
#  1657: ['ILU_BadBelzig'],
#  1660: ['poem_as', 'nayibbukele'],
#  1662: ['z_rattray'],
#  1664: ['ben_dogood'],
#  1676: ['vicky_ig'],
#  1683: ['league_navy'],
#  1684: ['SeapowerMag'],
#  1691: ['AnjaHerwig'],
#  1692: ['ABomb88'],
#  1694: ['Brandulinks', 'AlterBusiness'],
#  1703: ['ruminatus'],
#  1705: ['DjPopFunk', 'Mortisache'],
#  1707: ['LPTN1776', 'jeanne_cleve', 'RepThomasMassie'],
#  1709: ['UAZBIO5'],
#  1711: ['rywilwrite', 'AlexNaderWrites', 'ryanyoungwriter'],
#  1714: ['YaneValdezT'],
#  1715: ['oriolripoll'],
#  1719: ['SmithDryGoods', 'piperewan'],
#  1721: ['kat_vessel'],
#  1724: ['ProfDewey'],
#  1728: ['DogAgingProject'],
#  1730: ['SharpRandom'],
#  1731: ['PaulRobustelli'],
#  1733: ['heritagedaisy'],
#  1738: ['CarenzaLewis'],
#  1739: ['Eilonwy24'],
#  1743: ['NGRREC', 'IL_RiverWatch'],
#  1745: ['_frank_k_'],
#  1746: ['rezak121212'],
#  1747: ['Moeinafshari'],
#  1748: ['crowdsourcin'],
#  1751: ['saltysaguaro'],
#  1753: ['kev__en'],
#  1754: ['sethrogenszn'],
#  1756: ['radanirani11'],
#  1757: ['jhelebrant'],
#  1758: ['joshbard'],
#  1759: ['Gossamer_Sound'],
#  1763: ['HeyyyItsEricM'],
#  1766: ['culturebroker'],
#  1768: ['KahaliaM', 'isaisgo', 'freedomgang', 'BlueberryJane'],
#  1771: ['misssarahrazner'],
#  1772: ['riikka_kevo'],
#  1775: ['nahlikcj'],
#  1777: ['Kelaine'],
#  1781: ['jamesmccrary', 'TechySewell'],
#  1783: ['rwforest'],
#  1790: ['justjossn'],
#  1795: ['rtArtBoost'],
#  1796: ['100DaysOfWriter'],
#  1798: ['jennydavison_', 'islandmageeps', 'HannahBrown290'],
#  1801: ['LabsCatsHorses'],
#  1806: ['nnlmregion4'],
#  1815: ['HelenMartiroso1'],
#  1817: ['nihil_enigma'],
#  1818: ['AsbeAtash45'],
#  1819: ['dededawson'],
#  1824: ['STSCH_'],
#  1828: ['victorysunday2k'],
#  1831: ['insanedevbot'],
#  1832: ['arv_bot_'],
#  1838: ['crowdsourcingfn'],
#  1840: ['Sheldrake'],
#  1843: ['DNARNADan'],
#  1844: ['IZWE_DRONES'],
#  1848: ['sclehdorn'],
#  1849: ['vijesti_tv'],
#  1850: ['PalMaurovich'],
#  1851: ['ArimaGenomics'],
#  1863: ['Stephen_Curry'],
#  1864: ['lmb_berlin'],
#  1867: ['TheRarestDao', 'ConstitutionDAO', 'SwartzDAO'],
#  1869: ['RunningCardinal'],
#  1872: ['debbierachlis'],
#  1873: ['iangoldmansa'],
#  1874: ['GirlsWhoCodeBot'],
#  1875: ['avnishnanda'],
#  1877: ['cvila_museum'],
#  1878: ['Betty_Luwa25'],
#  1879: ['samyar45472518'],
#  1884: ['Shafi864',
#         'physorg_space',
#         'DechantBenjamin',
#         'beemuench',
#         'kath_astron',
#         'nlaboni',
#         'ESIPfed',
#         'EPAresearch',
#         'openscapes',
#         'afriesz',
#         '_ileanaf',
#         'eeholm',
#         'NinjaDevBot',
#         'juliesquid',
#         'BzGEO',
#         'connector_erin',
#         'NASAEarthData',
#         'EOchatBot',
#         'elleallever',
#         'ResearchSoft',
#         'ESA_EO',
#         'NASAEarth',
#         'RyanTScott',
#         'TalkSpaceMed',
#         'tropicaIboyz',
#         'fjguerrerob',
#         'uCloudifyAI',
#         'ChelleGentemann',
#         'steadyflux',
#         'kirstie_j',
#         'mgroverwx',
#         'teuta',
#         'HayleyEversKing',
#         'adrianprw',
#         'warrickball',
#         'nuclearastroguy',
#         'OG_Nancy',
#         'SOCCOMProject',
#         'GO_BGC',
#         'sluceyfish',
#         'NOAAFish_NEFSC',
#         'Amoakoh_AO',
#         'DRNaveenChetty',
#         'BARCOD_biofilms',
#         'ScarabSheffield',
#         'etanetamene',
#         'c_werner',
#         'geocuriosity',
#         'widmer_anna',
#         'historiavocis',
#         'FvvEngineering',
#         'Topcoder',
#         'NASASun',
#         'NASASolve',
#         'AutSpaces',
#         'NIHRresearch',
#         'DHSCgovuk',
#         'indrakusuma7d',
#         'OuuneK',
#         '_penatrix',
#         'katieepickett',
#         'yangdi1031',
#         'HorionStephanie',
#         'ChidimmaUmeogu',
#         'GeospatialEmma',
#         'prial78',
#         'kudzai101',
#         'testflyjets',
#         'you_stem',
#         'NicolaWatson13',
#         'toschms',
#         'laura_pura_vida',
#         'NAEPtweets',
#         'Ana__Bastos',
#         'MagdalenaSmigaj',
#         'PublicHealthMap',
#         'Cyclogenesis_au',
#         'aramirezreyes',
#         'TobiasSchlauch',
#         'Stella_Wava',
#         'bpetrushev',
#         'ascape_h2020',
#         'athanat',
#         'Inma_Grau',
#         'Physacourses',
#         'ant_dasgupta',
#         'SistersofSAR',
#         'pop_sin',
#         'Sann442',
#         'H2020_Faith',
#         'KerrieDougherty',
#         'Ma_AbdElsalam',
#         'PLOSONE',
#         'shyduroff2',
#         'fintasticdata',
#         'astrocrawford',
#         'storybywill',
#         'universetoday',
#         'fcain',
#         'martiansoil',
#         'CaturaTravis',
#         'Sulphurcocky1',
#         'MarkMalachowski',
#         'PeLeif',
#         'TheMarsSociety',
#         'NASA',
#         '1brisket',
#         'crocusgloria201',
#         'v_bohdi',
#         'Rsc4Earth',
#         'AvHStiftung',
#         'manuczar',
#         'ludwig_antonia',
#         'baumiberlin',
#         'dmlmont',
#         'stephan_buettig',
#         'GergelSarah',
#         'hughagraham',
#         'Keiko_geo',
#         'flyingwktk',
#         'clearmapping',
#         'tmrosan',
#         'DPManchee',
#         'UniofExeter',
#         'UniofBath',
#         'BristolUni',
#         'BBCRosAtkins',
#         'YuriShendryk',
#         'cavrinceanu',
#         'syuhuhaha',
#         'BMGResearchTea1',
#         'b_kellenb',
#         'EliasSymeonakis',
#         'ancapopescu7',
#         'TFCRIL',
#         'SalimSoltani15',
#         'cryospacemukesh',
#         'jo_heisig',
#         'benjamincretois',
#         'SteffenMumme',
#         'srcreyes',
#         'SabrinaSzeto',
#         'KhaniyaSashank',
#         'Manni67799772',
#         'Bilalkhan670',
#         'mayday_ai',
#         'lilybellesweet',
#         'natashapicone',
#         'richard_lemoine',
#         'prabhakar_orsu',
#         'shwe__ta',
#         'BillurBektas',
#         'SimonMolinsky',
#         'evelyn_korn',
#         'geemurie',
#         'Thisgelisonfire',
#         'HlisUmoya',
#         'MF_Nassar',
#         'lindseeeeee',
#         'petervhale',
#         'AndreFarfan10',
#         'dev_333',
#         'GowharJan',
#         'DallasMars',
#         'CemAesa',
#         'GraeyOmaya',
#         'ML_Tweet_Bot',
#         'MaterialPionee1',
#         'tudelftlibrary',
#         '4TUResearchData',
#         'hubofml',
#         'c4d_official',
#         'sxren',
#         'UniLeipzig',
#         'ScienceArtReach',
#         'BerlinSchool_PE',
#         'Zhuo_Adam_Chen',
#         'CHPAMS',
#         'ScienceSanjee',
#         'MedicoPressTZ',
#         'bhmann',
#         'ChimpandSee',
#         'DNApesBlog',
#         'NewForestSussed',
#         'russ_schumacher',
#         'Metpy',
#         'Ananth1402'],
#  1886: ['EmmaN11xx', 'dutchangles', '_llebrun'],
#  1888: ['LasembraC'],
#  1889: ['cairns_na'],
#  1890: ['Happe'],
#  1891: ['NickBan47647569'],
#  1895: ['LocaLaughs', 'VitalikButerin', 'lexfridman'],
#  1897: ['MC_SAPPlings'],
#  1900: ['famartinez2001'],
#  1901: ['KaptivateGroup'],
#  1903: ['NeftalyCM'],
#  1904: ['cobrafinch'],
#  1908: ['4BnEyVphNSnaOZf'],
#  1914: ['dominicdeecoco'],
#  1915: ['nmzumpano'],
#  1921: ['quinnslayton'],
#  1923: ['OfficeofEdTech'],
#  1926: ['ricecakebb'],
#  1929: ['OfficialDLDay'],
#  1936: ['cai2r'],
#  1943: ['PaquitoBernard'],
#  1946: ['MMxCommunity'],
#  1947: ['Boavista_Ludwig'],
#  1949: ['CraigCorbet'],
#  1950: ['designcrowdfun1'],
#  1951: ['SumeyyeEtlec'],
#  1953: ['BadRitalin'],
#  1956: ['BiotecnologiaF'],
#  1959: ['MyPawsGo'],
#  1963: ['thisburie', 'TrickyHannigram'],
#  1967: ['environmentca'],
#  1968: ['CourtneyOnstad', 'CoCoRaHSCanada'],
#  1969: ['bitcoinagile'],
#  1972: ['NZScienceLearn',
#         'NZGetReady',
#         'NZScienceTeachr',
#         'EducationGovtNZ',
#         'EQCNZ',
#         'Welly_ED',
#         'TLRI_NZ',
#         'vykanton',
#         'nzpmsciprizes'],
#  1977: ['paul_offa'],
#  1979: ['_evso'],
#  1980: ['NasDaddy2'],
#  1981: ['Lidy_Monteiro'],
#  1982: ['RodAG_'],
#  1983: ['Chaaootic'],
#  1984: ['BrandonVolosen'],
#  1985: ['antonsantos00'],
#  1987: ['DonaldVinh'],
#  1988: ['IPKW_univie'],
#  1990: ['kennedytcooper'],
#  1992: ['Erst_Officer'],
#  1993: ['nataliamanola'],
#  1998: ['krisvdam', 'amai'],
#  2000: ['mopenshaw',
#         'DavidAnber',
#         'mkhammer',
#         'Newsweek',
#         'RedBird725',
#         'HazelHenri'],
#  2004: ['lisafeldstein'],
#  2005: ['Anu_L_Goswami'],
#  2008: ['NeuroGem'],
#  2018: ['betatrash'],
#  2019: ['Mrs_Delecto'],
#  2026: ['sab_original',
#         'AusElectoralCom',
#         'SAElectoralCom',
#         'MicheleScheffl1',
#         'giddeygirl',
#         'marie19705',
#         'libliars',
#         'Magpie1954nBird',
#         'marshall_steven',
#         '1395FIVEaa',
#         'BarrieCarter6',
#         'AnthStaltari',
#         'AmandasShirt',
#         'OzSerpent',
#         'mhgoremau357',
#         'JFAPurpleOrange',
#         'PMalinauskasMP',
#         'geoffrey_payne',
#         'WeisbeckerLab',
#         'LiberalAus',
#         'arcadiagt5',
#         'TKoutsantonisMP',
#         'MattOsborn',
#         'timhatfield87',
#         'halluci_nati0ns'],
#  2030: ['robbo_1962', 'Lilaceve666'],
#  2031: ['BurntTo63443766'],
#  2034: ['scossfunding'],
#  2038: ['thepromptmag', 'JayHeltzer'],
#  2039: ['Canada_CEBCEM'],
#  2044: ['seed_ball'],
#  2045: ['bigmeadowsearch'],
#  2046: ['LicenceProDist'],
#  2047: ['TheJulieBenson'],
#  2071: ['DaveBathur'],
#  2074: ['BMWUSA'],
#  2075: ['falconhamada_90'],
#  2076: ['Mohamedhog24'],
#  2077: ['tobioworks'],
#  2081: ['SafaaMo38665785'],
#  2085: ['LachDonna'],
#  2091: ['BarbzTingzzz'],
#  2093: ['UFollowtheOcean'],
#  2094: ['mikemorrison',
#         'peternooteboom',
#         'peterbijlWilkes',
#         'DJKylix',
#         'ErikvanSebille',
#         'UUClumpIsotopes',
#         'geomatlab'],
#  2100: ['YourOnlyONEofcl'],
#  2106: ['ColdBloodedJ', 'TPAIN', 'Ludacris'],
#  2109: ['LeAnnaJCarey'],
#  2111: ['LJAmstutz'],
#  2115: ['BevForte'],
#  2119: ['InnesFrances'],
#  2124: ['japecake', 'HeerJeet', 'jessesingal'],
#  2134: ['amandalbradford'],
#  2135: ['NOAAFish_PIRO'],
#  2136: ['salonium'],
#  2138: ['02import_update',
#         'Sarah17325183',
#         'Paulintoronto47',
#         'SethMacFarlane'],
#  2144: ['KathNovotny'],
#  2147: ['PappyFitz', 'jhski', 'BianchiOfficial', 'Paris_Roubaix', 'WinterPark'],
# ...
#          'damagedonegr',
#          'Elstar4stars',
#          'ASU_SFIS',
#          'Piers42',
#          'DisabledStem',
#          'DisabledAcadem',
#          'JADEdisjustice',
#          'the_connectory',
#          'Riverflies',
#          'EuropeanaTech',
#          'AlisaMartek',
#          'stallcatchers',
#          'girlsmoonshot',
#          'lisboncouncil',
#          'ISpotABee',
#          'RuthJepson',
#          'muredduf',
#          'alexandrelopez',
#          'Sibucsc_BSA',
#          'banksiaboy',
#          'chinese_digital',
#          'ACCTING_EU',
#          'crai_bima',
#          'hh_bruun',
#          'TokeHoye',
#          'Alicia_hgim',
#          'archaeo_lenore',
#          'BCNCiencia',
#          'hymenoptera_nev',
#          'FonsUECat',
#          'sectie_thijsse',
#          'OpenSystemsUB',
#          'm4_social',
#          'MWCapital',
#          'NIHSEPA',
#          'DeepakV56930282',
#          'informalscience',
#          'IshariAma',
#          'sven_manske',
#          'pati_santos_r',
#          'ValeSbriz',
#          'noemieelhadad',
#          'ORION_opensci',
#          'wireditalia',
#          'GlobalCitSci',
#          'GlobalChangeRL',
#          'cfe_FLOWerLab',
#          'jomagellan',
#          'FabioFeudo',
#          'polli_net',
#          'FECYT_Ciencia',
#          'Odourcollect',
#          'ConnectingNBS',
#          'LSEnews',
#          'ICMCSIC',
#          'alldominguez',
#          'smartecocity',
#          'julioRabadan',
#          '13laurichi',
#          'NHM_CitSci',
#          'RappAndrea',
#          'ceciliallull',
#          'mg19283',
#          'KSCH_ZSI',
#          'arenica2',
#          'marziuk',
#          'PatientInnov',
#          'bubblyplasma',
#          'Vincent_Ledvina',
#          'naritoshi_k',
#          'annettestr',
#          'MHagardt',
#          'hcinst',
#          'FeliuMadaula',
#          'FGBassetti',
#          'ACTION4CS',
#          'apassani',
#          'ale_for',
#          'quest_eu',
#          'MorriSuper',
#          'PaoloGiardullo1',
#          'SomethingClubUK',
#          'llazzarato',
#          'pmichelu',
#          'SN_Lab',
#          '_BrightFocus',
#          'CoalitionConGen',
#          'OBracko',
#          'CHNickerson',
#          'Verizon',
#          'iseechange',
#          'HealthcareAgg',
#          'WholeEarthCoin',
#          'CoinMarketCap',
#          'IterumRustica',
#          'HerbalLandline',
#          'SciJeanne',
#          'KWR_Water',
#          'Garcia07Anna',
#          'mjoehlerich',
#          'OlindaAnia',
#          'jenpre'],
#  20492: ['MAS_EBSI'],
#  20494: ['ProjectSplatter', 'CdfScienceFest', 'AndrewW66619812', 'amylaird_'],
#  20495: ['UOBengage'],
#  20497: ['LynnDoe4X', 'NRO', 'njhochman', 'FDRLST'],
#  20505: ['oaggimenez'],
#  20508: ['DrTomTORC', 'ScotSTEMAmb', 'mrcppu'],
#  20515: ['mvelo_2',
#          'Lesba007',
#          'LoloBee93658919',
#          'MYANC',
#          'David_Makhura',
#          'BrendaM51777950'],
#  20521: ['cranfieldlib',
#          'cranfielddesign',
#          'Mandy_stfc',
#          'ginjabookchick',
#          'cranfieldclare',
#          'Aero_Emma'],
#  20525: ['WCHN_UCL'],
#  20526: ['OneWeekBot'],
#  20527: ['absansio'],
#  20537: ['kleintob'],
#  20540: ['kholmber'],
#  20541: ['MGauffriau', 'nwb2022'],
#  20542: ['EWoodhouse7'],
#  20543: ['leeleeraider70'],
#  20547: ['souljahsingh'],
#  20548: ['BenjaminVenture'],
#  20549: ['jenreesman'],
#  20550: ['AffinitoLit'],
#  20552: ['ArturTweeting'],
#  20556: ['BeaPrezent'],
#  20558: ['CureCoin_Team'],
#  20562: ['LoveThisBar'],
#  20563: ['DebraBuenik'],
#  20565: ['MatthewHurteau'],
#  20568: ['piotelat'],
#  20570: ['EbiaCelestine'],
#  20571: ['FD2you'],
#  20573: ['OLINK_LindaSF'],
#  20575: ['elementomega1'],
#  20576: ['frankline5'],
#  20579: ['AntifascistasEc'],
#  20580: ['Sum12K'],
#  20586: ['b_penders'],
#  20587: ['UASNRE'],
#  20588: ['lishenlc'],
#  20592: ['VivirLoRaro'],
#  20597: ['riley_andrade'],
#  20599: ['me_pk'],
#  20600: ['capitalistchimp'],
#  20601: ['gracialivie'],
#  20602: ['CharlesVardeman'],
#  20623: ['research_lpi'],
#  20625: ['Fazlerabby0'],
#  20627: ['SmitBerend'],
#  20630: ['sarcastic_owljp'],
#  20633: ['OshDuffy'],
#  20644: ['daniel_huppmann'],
#  20645: ['BrucknerGroup'],
#  20649: ['THMToday'],
#  20650: ['BlebOfficial'],
#  20658: ['pillspramod', 'cjwerleman'],
#  20660: ['uni_essex_csee'],
#  20661: ['HeiCAD_HHU'],
#  20662: ['IFlck'],
#  20663: ['CiencieShadow'],
#  20665: ['HxxxKxxx'],
#  20668: ['sauer_sebastian'],
#  20669: ['HelliwellJohn'],
#  20675: ['sbmalev'],
#  20676: ['Ezragression'],
#  20677: ['UCLLifeSciences'],
#  20681: ['David_Barrado'],
#  20682: ['nicoleacrowley'],
#  20684: ['MeebitsDAO'],
#  20685: ['JamesWyl'],
#  20687: ['NeilSharpeGenes'],
#  20688: ['sriramnivas21'],
#  20690: ['acoustics_ac_uk', 'acoustimike'],
#  20691: ['YourTXRep'],
#  20694: ['electra_rhodes', 'BookwormVaught'],
#  20699: ['HP_Paul', 'hunwehol'],
#  20708: ['oz84063020'],
#  20709: ['CamAHSSResearch'],
#  20713: ['mademjac'],
#  20714: ['SingleCellMedia'],
#  20716: ['repro_t'],
#  20718: ['marathesayu', 'asuph', 'romaticize'],
#  20720: ['swamidass'],
#  20724: ['timolueke'],
#  20726: ['CFillaud'],
#  20728: ['ITRTG'],
#  20730: ['Renaino'],
#  20733: ['AbubakarMundir'],
#  20734: ['koopac7'],
#  20735: ['JetdeRanitz'],
#  20736: ['macstronach'],
#  20743: ['mementonature'],
#  20744: ['OzzieRover'],
#  20745: ['Rbio_alicia'],
#  20746: ['chimdimma_peace'],
#  20747: ['leaveittoarron'],
#  20748: ['madcow_paula'],
#  20749: ['JVos63'],
#  20750: ['GuilabertA'],
#  20751: ['sorianourban'],
#  20752: ['siawooshmn'],
#  20756: ['gwardwell', 'walkingriver'],
#  20757: ['danawanzer'],
#  20760: ['screencomposer2',
#          'TPLM_Officiel',
#          'addxlm',
#          'musiikintekijat',
#          'Creators_ECSA',
#          'fst_tonsattare',
#          'authorsocieties',
#          'TaniaGhyselinck',
#          'Net2Ayurveda',
#          'helienne',
#          'dlfkultur',
#          'gema_news',
#          'KaijaKarkinen',
#          'SoundTrack_C',
#          'NinaLith'],
#  20761: ['niggadraw'],
#  20762: ['GenevievMichaud'],
#  20764: ['ORBITAL_ITN'],
#  20765: ['Neuro_Dr_Brum',
#          'AnaFilipaMota6',
#          'dfarmausc',
#          'MSCActions',
#          'hpriorfilipe'],
#  20769: ['bpkasp'],
#  20771: ['PHstefanuto'],
#  20772: ['Sashwin_Pillai'],
#  20773: ['SjogrensForum'],
#  20784: ['Sbendi1'],
#  20787: ['VanHyningV',
#          '_FromThePage_',
#          'Taneya',
#          'AAHGSNashville',
#          'benwbrum',
#          'bethanycaye',
#          'eabenoit',
#          'anmcl001'],
#  20800: ['isabellewoerkom'],
#  20801: ['theoploeg'],
#  20802: ['scienceboarder'],
#  20810: ['rachmarsden'],
#  20826: ['RoseOfKali', 'IronHeaver', 'lacroicsz', 'CashLoopa', 'daringtospeak'],
#  20829: ['pp0196', 'fuutaanke19'],
#  20832: ['ReneeFBrown'],
#  20833: ['HeedLab'],
#  20834: ['Loffy_tea'],
#  20835: ['ApiWenuwen'],
#  20836: ['sciencepolicy'],
#  20844: ['KraeuterVerbena'],
#  20845: ['MarthaAnnBurns'],
#  20847: ['VaniChitkara'],
#  20850: ['tanjarombey'],
#  20866: ['grmammT46',
#          'Kjell52059994',
#          'BachemMacuno',
#          'leesuigeneris',
#          'DickieStone'],
#  20871: ['Wonder_Bro'],
#  20872: ['leccs09'],
#  20876: ['BirdNigeria',
#          'ncfnigeria',
#          'Vogelwarte_scie',
#          'aploritwit1',
#          'SA_birdatlas',
#          'SIR_JOE11'],
#  20886: ['_noujoum'],
#  20887: ['CPREBerkshire'],
#  20889: ['PegKeiner'],
#  20892: ['nvyoung'],
#  20893: ['geekalabama'],
#  20895: ['valentyn_bez'],
#  20896: ['theDAWNmethod', 'WCGrid', 'foldingathome'],
#  20898: ['therealGavin1'],
#  20899: ['EU_HiDALGO'],
#  20902: ['UMichECE'],
#  20903: ['UMichCSE',
#          'LtGovGilchrist',
#          'UMich',
#          'michiganalumni',
#          'UMengineering',
#          'michigan_AI'],
#  20906: ['Dendrogobbler'],
#  20911: ['gindaanis',
#          'jesswithie',
#          'Joyhenderson78',
#          'MeaghanBm',
#          'SoniaFurstenau'],
#  20922: ['OYAD09'],
#  20927: ['ZebUrsoThera'],
#  20928: ['GenzelLab'],
#  20931: ['thinkpraybot'],
#  20932: ['cathgem2000'],
#  20939: ['nursemaiden'],
#  20941: ['eye_dull'],
#  20950: ['bwildhagen'],
#  20954: ['abdullinks'],
#  20955: ['G4ZDTekTV'],
#  20957: ['sarahsmaga'],
#  20958: ['arisimpacts', 'eternagame', 'cgem_cci'],
#  20961: ['Act_mmu'],
#  20962: ['nichouta'],
#  20963: ['PeaceablyA'],
#  20966: ['eResearch_UCL'],
#  20970: ['LaurenStacho'],
#  20972: ['AdewaleaAkinola'],
#  20973: ['Ariyobolu7'],
#  20974: ['moneynetlink'],
#  20975: ['NoFakeLove14'],
#  20978: ['mikethenavyguy', 'Snowden', 'cancivlib'],
#  20982: ['NYGamer'],
#  20987: ['lawallner1'],
#  21000: ['FILMSTHESEDAYS'],
#  21001: ['stephenjwild'],
#  21003: ['1xtrachromo'],
#  21006: ['LynPritchard2'],
#  21007: ['tomhfh'],
#  21009: ['Svzamorano'],
#  21012: ['JamesSteeleII'],
#  21014: ['Andysemp'],
#  21015: ['BLADERAZE'],
#  21016: ['NailHard'],
#  21018: ['KatalinSolymosi'],
#  21021: ['proudly_dee'],
#  21024: ['owoniyilb'],
#  21025: ['JorgeCalderaSer'],
#  21026: ['_QuietLeader_'],
#  21027: ['hongtuzhu1'],
#  21030: ['christyspackman'],
#  21031: ['Anticipation22', 'ASUEmerge', 'MGBennett'],
#  21032: ['SocProf'],
#  21033: ['PhDSkills'],
#  21037: ['JnfrLTackett'],
#  21039: ['nyakundi_mike'],
#  21045: ['ianhussey'],
#  21050: ['KMKing_Psych'],
#  21052: ['polyplexors'],
#  21056: ['fusaroli'],
#  21059: ['chadjvalasek'],
#  21060: ['Ugwujach'],
#  21061: ['lnalborczyk'],
#  21063: ['addiengeorge'],
#  21065: ['rosalielack'],
#  21066: ['RoeyAngel'],
#  21068: ['IHOhydro'],
#  21069: ['CGCraigie'],
#  21070: ['dom_roche'],
#  21074: ['thekriswild'],
#  21087: ['queer_coded'],
#  21088: ['_sakusakus'],
#  21089: ['CaitlinPatler'],
#  21094: ['OndrejZika'],
#  21097: ['lateeffadeyi1'],
#  21098: ['JorgenVeisdal'],
#  21104: ['brullier7'],
#  21110: ['jamnnamdi'],
#  21111: ['meuler_',
#          'NicolaSambuco',
#          'Prof_Larson',
#          'TonyLFreitas',
#          'EuropePMC_news',
#          'CyrilRPernet',
#          'wdonald_1985',
#          'CBioinformatica',
#          'EuroBioImaging',
#          'melanieganzben1',
#          'FibiNode',
#          'Tincala',
#          'martinnorgaard_',
#          'Bindikannan963',
#          'MattJan4',
#          'igor_dgps',
#          'ZonaPellucida_',
#          'EBItraining',
#          'emblebi',
#          'CyrilPedia',
#          'EDCTP',
#          'Gemma_Lass',
#          'VictoriaYan_',
#          'H3ABioNet',
#          'the_Node',
#          'Skatiq3',
#          'In_AnkitSingla',
#          'hrhotz',
#          'TenganCharles',
#          'habarugira3',
#          'Slmorg',
#          'irenepapatheodo',
#          'brainstorm2day',
#          'sylvain_baillet',
#          'MarkusButz',
#          'MaTeFerretti',
#          'nishiokov',
#          'neurozdemir',
#          'EMBLEBIjobs',
#          'mocost',
#          'dominic_boutet',
#          'palacciv',
#          'ftoroherr',
#          'elebovidge',
#          'gabrielamarcu',
#          'mariella_n_paul',
#          'IMI2_ROADMAP',
#          'CTLSlifeScience',
#          'PrimeNordic',
#          'PursueERP',
#          'CindyMBukach',
#          'CouperusJane',
#          'laurel_joy_gd',
#          'DrVeronikaCH',
#          'turkubioimaging',
#          'EMBLEvents',
#          'EoscLife',
#          'chemlibcam',
#          'IMI2_NEURONET',
#          'Rigshospitalet',
#          'CindyBirck',
#          'IMI_AMYPAD',
#          'RedeSciELO',
#          'ChrisBintener',
#          'FicoYPlaca',
#          'jobsviatweet',
#          'richdobson',
#          'callumstew',
#          'phidatalab',
#          'covid_collab',
#          'radar_base',
#          'infovestigacion',
#          'nivemaham',
#          'clayson_peter',
#          'AcademicEEG',
#          'cj_brush',
#          'TakMedani'],
#  21113: ['sleedham', 'CryptoMaxiboy'],
#  21117: ['MarilioMeireles'],
#  21118: ['mmister'],
#  21120: ['Steve_Byra', 'kootscrutinizer'],
#  21121: ['NSERC_CRSNG'],
#  21124: ['giuliazoo'],
#  21128: ['MarekTP'],
#  21129: ['MarekBartik'],
#  21131: ['crjuenemann', 'PatrickTheGiver', 'DonorsChoose'],
#  21135: ['TomMaguire1965'],
#  21136: ['ExecGQ'],
#  21137: ['Pat300000'],
#  21138: ['mcbig_cz'],
#  21142: ['FORSresearch'],
#  21151: ['bruno_nicenboim'],
#  21152: ['li_yanxian'],
#  21154: ['SEthanMilne'],
#  21157: ['famakinwaemman2'],
#  21158: ['samnux',
#          'UZH_ch',
#          'digihistlab',
#          'itihaashtag',
#          'DennisHormuth',
#          'moritzmaehr',
#          'digigw',
#          'InfoCoV3',
#          'hrzz_science',
#          'AnaMestrovic78',
#          'SandaMartincic',
#          'IttensohnMark',
#          'GraduateCampus',
#          'SMM_News_Feed'],
#  21209: ['JPRM_editor'],
#  21211: ['watersecurity', 'WaterWired', 'ClimateAdapt'],
#  21213: ['garciavj00'],
#  21215: ['AlanWorsley1', 'Aegean888'],
#  21219: ['SanaJalili2'],
#  21223: ['Scivil_Flanders',
#          'amaivlaanderen',
#          'MediaWijsBe',
#          'KC_DaMa',
#          'Departement_EWI',
#          'imec_smit',
#          'AnnickHus',
#          'VUBrussel',
#          'RobHeyman',
#          'WtnschpBXL',
#          'Brightlab_be',
#          'weersprookjes',
#          'anneliensmets',
#          'treecomp',
#          'VeeckmanCarina'],
#  21226: ['MarianneW'],
#  21233: ['annette_burden'],
#  21235: ['KijanaMaende'],
#  21240: ['sonnolenta46'],
#  21241: ['BoomerBiotech'],
#  21250: ['PatrickCookBC',
#          'gmtord',
#          'sibilatrix',
#          'RichardFoxBC',
#          'EmilyBDennis',
#          'MarcBotham',
#          'NigelBournBC',
#          'jennygremer',
#          'varsha_khodiyar',
#          'ConTechLive',
#          'CliveSnell1',
#          'astrochunly',
#          'kait_shin',
#          'scpticastrodame',
#          'MiaDoesAstro',
#          'FutureEarthAus',
#          'TrishaCastranio',
#          'GabeFilippelli',
#          'infomorsels',
#          'boricua_geo',
#          'UWUniverCity',
#          'theAGU',
#          'ThrivingEarth',
#          'WisCounties',
#          'LeagueWIMunis',
#          'sciencewiscedu',
#          'UWMadGSEd',
#          'ESAEcology',
#          'figshare',
#          'savebutterflies',
#          'PublicLabMongol',
#          'EPICNtweet',
#          'Ajges01',
#          'ACAWestAfrica',
#          'HanoWene',
#          'lakesuper_wisg',
#          'AC_inthewater',
#          'GullahGeechee',
#          'AnthropoceneAL',
#          'NEON_sci',
#          'martinswarren',
#          'AGU_SciComm',
#          'jackiergerson',
#          'FutureEarth',
#          'USAID',
#          'WisLandInfo',
#          'NelsonInstitute',
#          'MarkHahnel',
#          'SustainUW',
#          'scandrof',
#          'AcadiaNPS',
#          'ESA_org',
#          'Yoenoes_Mohd',
#          'TheMountainInst',
#          'STEA_Trelawny',
#          'forestservice',
#          'digitalsci',
#          'NTUsg',
#          'HDR_UK'],
#  21255: ['alicelucytaylor'],
#  21258: ['_PetraRitter'],
#  21260: ['JacobLorenzotfe'],
#  21261: ['megfitz89'],
#  21266: ['LisanSpanbroek'],
#  21267: ['bertsleijster', 'Windesheiminfo', 'EmielKamman'],
#  21276: ['StefanoCoretta'],
#  21279: ['ondrejsika'],
#  21280: ['TheSahuNews'],
#  21281: ['Alexand65504397'],
#  21283: ['JasonRBradwell', 'CJ_250marketing', 'G2dotcom'],
#  21288: ['SumatiThusoo'],
#  21289: ['sciresourcebank'],
#  21290: ['CoBouillot'],
#  21296: ['ModeratelyMoco',
#          'MDHealthDept',
#          'DrHasson2',
#          'HeadwaysMatter',
#          'CrnchyMama'],
#  21299: ['CUHedgehogs'],
#  21300: ['hamid_dashti2'],
#  21307: ['AfolabiAhmed131'],
#  21312: ['LibrarianGMIT'],
#  21314: ['LuanRAguiar_'],
#  21316: ['wamoase'],
#  21321: ['PSUIncubator'],
#  21322: ['easygoingalways'],
#  21328: ['ricardovalp'],
#  21335: ['QueenDalia', 'sistadbarnes', 'John_Liberator', 'questlove'],
#  21337: ['aridideas'],
#  21340: ['Commentary', 'jamesbmeigs', 'jphoganorg', 'AgricultureEagl'],
#  21341: ['sheraldsanchez'],
#  21342: ['odsc'],
#  21344: ['DrArendt', 'realchrisrufo'],
#  21348: ['emme13astro'],
#  21351: ['asa_ipm'],
#  21353: ['EnviroSolve_US'],
#  21355: ['M45ATX'],
#  21356: ['ReedPalmer4'],
#  21366: ['streetsyourtown'],
#  21367: ['ga3fariat'],
#  21368: ['JMiller1789'],
#  21370: ['elfridedebaere'],
#  21372: ['ATXDAO',
#          'sarah_eckhardt',
#          '512mace',
#          'MasonLeeLynaugh',
#          'mason_lynaugh',
#          'RobertoTalamas',
#          'eager_crypto',
#          '0xDavila',
#          'JackJi_Hu',
#          'MxMnr',
#          'austoniatweets',
#          'AnastasiaU'],
#  21374: ['Complast_Ltd'],
#  21376: ['7Mrsjames'],
#  21377: ['mindgardensau'],
#  21379: ['AyeshaBoyce'],
#  21380: ['teknocks'],
#  21381: ['StormSkiJournal', 'WFG_DEN', 'stevejpr', 'drew_lanoue'],
#  21384: ['petersuber'],
#  21386: ['kateju9'],
#  21387: ['WhteRbbnAdvocat', 'LadyPoop2', 'alpsa'],
#  21390: ['ShilpaChheda0']}

# %% [markdown]
# #### 20. Try to visualise the subgraph of users that have used the 5th most common hashtag

# %%
# Get the 5th most common hashtag:
hashtag = graph.execute(f"match (hashtags:{l_hashtag}) return distinct toLower(hashtags.text) as hashtag, size(()-[]->(hashtags)) as indegree order by indegree descending limit 5").data()[4]["hashtag"]
print("Execute command below on neo4j Browser to visualize the selected subgraph:")
print("\n-----(Start >)-----")
print(f'''match (users:{l_user})-[r1:{r_used_hashtag}]-(hashtags:{l_hashtag}) where hashtags.text = '{hashtag}'
    CALL apoc.path.subgraphAll(users, {{maxLevel: 1}}) YIELD nodes, relationships
    return nodes,relationships''')
print("-----( < End )-----\n")
print(f"The 5th most common hashtag: '{hashtag}'")
print("\nUsers that used the 5th most common hashtag:")
pprint([res['users'] for res in graph.execute(f"match (users:{l_user})-[r1:{r_used_hashtag}]-(hashtags:{l_hashtag}) where hashtags.text = '{hashtag}' return users").data()])
# Out:
# Execute command below on neo4j Browser to visualize the selected subgraph:
#
# -----(Start >)-----
# match (users:user)-[r1:used_hashtag]-(hashtags:hashtag) where hashtags.text = 'airpollution'
#     CALL apoc.path.subgraphAll(users, {maxLevel: 1}) YIELD nodes, relationships
#     return nodes,relationships
# -----( < End )-----
#
# The 5th most common hashtag: 'airpollution'
#
# Users that used the 5th most common hashtag:
# [{'community': 20344,
#   'followers_count': 13220,
#   'screen_name': 'JeanLambertLDN'},
#  {'community': 18484,
#   'followers_count': 2589,
#   'screen_name': 'DanWils42696605'},
#  {'community': 2542, 'followers_count': 0, 'screen_name': 'Tunieej'},
#  {'community': 10714, 'followers_count': 19832, 'screen_name': 'rstatstweet'},
#  {'community': 10714, 'followers_count': 1660, 'screen_name': 'Lala35539674'},
#  {'community': 10714, 'followers_count': 3429, 'screen_name': 'ImNickHuber'},
#  {'community': 10714, 'followers_count': 483, 'screen_name': 'protontypes'},
#  {'community': 20486, 'followers_count': 362, 'screen_name': 'Anecdata_org'},
#  {'community': 4750, 'followers_count': 3622, 'screen_name': 'physicsgirluk'},
#  {'community': 20486, 'followers_count': 1909, 'screen_name': 'CitSciMonth'},
#  {'community': 20486, 'followers_count': 7148, 'screen_name': 'raultoran'},
#  {'community': 6246, 'followers_count': 1172, 'screen_name': 'GeoMedeelel'},
#  {'community': 4456, 'followers_count': 1466, 'screen_name': 'ISPRS_IJGI'},
#  {'community': 5705, 'followers_count': 211, 'screen_name': 'inter_3_Berlin'},
#  {'community': 4368, 'followers_count': 421, 'screen_name': 'xalexopoulos'},
#  {'community': 20486, 'followers_count': 1943, 'screen_name': 'CitieSHealthEU'},
#  {'community': 2433, 'followers_count': 103, 'screen_name': 'WeCOMPAIR'},
#  {'community': 2542, 'followers_count': 1435, 'screen_name': 'Gdgayan78'},
#  {'community': 2542, 'followers_count': 103, 'screen_name': 'biankoniglio'},
#  {'community': 2542, 'followers_count': 23, 'screen_name': 'VladKO7777777'},
#  {'community': 2542, 'followers_count': 40, 'screen_name': 'ShaolinGameMonk'},
#  {'community': 2542, 'followers_count': 3241, 'screen_name': 'Alphonsobwjr'},
#  {'community': 2542, 'followers_count': 30, 'screen_name': 'Crimsonrage9'},
#  {'community': 2542, 'followers_count': 25, 'screen_name': 'proanimalrightz'},
#  {'community': 2542, 'followers_count': 130, 'screen_name': 'CBarrozziP'},
#  {'community': 2542, 'followers_count': 37, 'screen_name': 'riccardo19811'},
#  {'community': 2542, 'followers_count': 1388, 'screen_name': 'Escritordefutu1'},
#  {'community': 2542, 'followers_count': 1470, 'screen_name': 'ReVeldes_VdV'},
#  {'community': 2542, 'followers_count': 2667, 'screen_name': 'natisthecure3'},
#  {'community': 2542, 'followers_count': 2720, 'screen_name': 'newfxfs'},
#  {'community': 2542, 'followers_count': 0, 'screen_name': 'GeorgiA28277670'},
#  {'community': 2542, 'followers_count': 733, 'screen_name': 'SeeTheAirBot'},
#  {'community': 2542, 'followers_count': 2524, 'screen_name': 'GaiaPluto'},
#  {'community': 2542, 'followers_count': 22, 'screen_name': 'jonnyno89'},
#  {'community': 2542, 'followers_count': 9, 'screen_name': 'JosRaposo7'},
#  {'community': 2542, 'followers_count': 0, 'screen_name': 'mRperfEcttttty'},
#  {'community': 2542, 'followers_count': 26592, 'screen_name': 'PlanetWatchsas'},
#  {'community': 19254, 'followers_count': 3229, 'screen_name': 'OpenSciTalk'},
#  {'community': 20425, 'followers_count': 25, 'screen_name': 'Aalst_Waalre'},
#  {'community': 9683, 'followers_count': 1556, 'screen_name': 'globalhealthbot'}]
